# %% [markdown]
# # Data fetcher for flags
#
# Gets data from different places and combines/saves them in a single file. In order to support OsuWorld

# %%
import requests
from bs4 import BeautifulSoup
import json
import copy
import urllib.parse

# %%
def fetchData(api_url):
    try:
        response = requests.get(api_url)

        if response.status_code == 200:

            data = response.json()
            return data
        else:
            print(f"Request failed with status code: {response.status_code}")
    except requests.exceptions.RequestException as e:
        print("An error occurred:", e)

# %% [markdown]
# # Wikimedia flags Fetcher
#
# Retrieves the flags from: https://commons.wikimedia.org/wiki/Flags_of_country_subdivisions

# %%
url = "https://commons.wikimedia.org/wiki/Flags_of_country_subdivisions"

# %%
def parseUrl(url):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, "html.parser")
        return soup

    else:
        print("Failed to fetch the webpage")

# %%
parsed = parseUrl(url)

# %%
content = parsed.find(id="mw-content-text").find("div")

flagsRaw = {

}
country = ""
for element in content.children:

    if element.name == "h2":
        titleText = element.find("span").text
        if titleText == "" or titleText == "See also":
            continue
        country = titleText
        flagsRaw[country] = []
    elif element.name == "table":
        if country == "":
            continue
        flagsAnchor = element.findAll(class_="mw-file-description")
        for flagAnchor in flagsAnchor:
            name = flagAnchor.attrs['title']
            flagImg = flagAnchor.find(class_="mw-file-element")
            flagRaw = flagImg.attrs['src']
            flag: str = flagRaw.replace("thumb/", "")

            matchEnd = ".svg"
            svgIndex = flag.find(matchEnd)
            if svgIndex == -1:
                flag = flagRaw
            else:
                flag = flag[:svgIndex+len(matchEnd)]

            flag = {
                "name": name,
                "flag": flag,
                "flagRaw": flagRaw
            }

            flagsRaw[country].append(flag)

# %% [markdown]
# ## Check the svg links status

# %%
json_data = json.dumps(flagsRaw, indent=4, ensure_ascii=False).encode('utf8').decode()
flagsRaw = "out/flags_raw.json"
with open(flagsRaw, "w") as json_file:
    json_file.write(json_data)

print("JSON data has been saved to", file_path)
# Out:
# JSON data has been saved to out/flags_raw.json

# %%
flagsRaw = "out/flags_raw.json"

with open(flagsRaw, "r", encoding="utf-8") as json_file:
    flagsRaw = json.load(json_file)

# %%
flags = {
    country: [
        {key: value for key, value in county.items() if key != 'flagRaw'}
        for county in counties
    ]
    for country, counties in flagsRaw.items()
}

# %% [markdown]
# ## Convert names to ISO 3166 codes

# %%
countriesJsonPath = "./in/countries.json"

with open(countriesJsonPath, "r", encoding="utf-8") as json_file:
    countriesJson = json.load(json_file)

# %%
FlagsCodes = {}

for country, regions in flags.items():
    code = None
    for countryJson in countriesJson:
        countryName: str = countryJson["name"]
        if countryName.find(country) != -1 or country.find(countryName) != -1:
            code = countryJson["alpha-2"]
            break
        
    if code is None:
        print(f"Country {country} not found in countries.json")
        continue

    FlagsCodes[code] = {
        "name": country,
        "regions": regions
    }

# %%
flags = FlagsCodes

# %%
json_data = json.dumps(FlagsCodes, indent=4, ensure_ascii=False).encode('utf8').decode()
with open("out/flags_codes.json", "w") as json_file:
    json_file.write(json_data)

# %% [markdown]
# ## Add Native name to countries

# %%
countriesNativeJson = fetchData(
    "https://raw.githubusercontent.com/tomeralmog/zipcode-kml/master/countries.json")

# %%
for countryCode, country in flags.items():
    countryName = country["name"]
    nativeCountryRows = [
        countryRow for countryRow in countriesNativeJson if countryRow["countryName"] == countryName]

    if len(nativeCountryRows) == 0:
        # Fix Netherlands and The Netherlands mismatch exception
        exceptionCountries = {"NL": "The Netherlands",
                              "PT": "Portugual", "HR": "Czechia", "DO": "Dominica Republic"}
        if countryCode in exceptionCountries.keys():
            countryName = exceptionCountries[countryCode]
            nativeCountryRows = [
                countryRow for countryRow in countriesNativeJson if countryRow["countryName"] == countryName]
        else:
            print(
                f"Country {countryCode} {countryName} not found in countries.json")
            continue

    nativeCountryRow = nativeCountryRows[0]
    nativeCountryName: str = nativeCountryRow["nativeCountryName"]
    nativeCountryName = nativeCountryName.split(",")[0].split("|")[0]
    country["nativeName"] = nativeCountryName
    # Reorder regions to appear after nativeName
    regCopy = country["regions"]
    del country["regions"]
    country["regions"] = regCopy
# Out:
# Country AQ Antarctica not found in countries.json
# Country CZ Czech Republic not found in countries.json
# Country DM Dominican Republic not found in countries.json
# Country LR Liberia not found in countries.json
# Country SR Suriname not found in countries.json

# %% [markdown]
# ## Add ISO 3166-2 codes to regions
#
# Using Open Street Maps API: https://nominatim.openstreetmap.org/ui/search.html

# %%
urlSearch = "https://nominatim.openstreetmap.org/search.php?q=$1&countrycodes=$2&format=jsonv2"


def getRegionURL(regionName, countryCode):
    return urlSearch.replace("$1", regionName).replace("$2", countryCode)


urlReverseId = "https://nominatim.openstreetmap.org/details.php?osmtype=R&osmid=$1&format=json"


def getReverseIdURL(id):
    return urlReverseId.replace("$1", id)

# %%
flagsRegionCodes = copy.deepcopy(FlagsCodes)


def addResult(regionsMap, region, name, matchData):
    id = matchData['osm_id']
    detailsUrl = getReverseIdURL(str(id))
    print(id)
    detailsData = fetchData(detailsUrl)

    if detailsData is None:
        print("No details data")
        print(region)
        return False

    isoCode = detailsData['names'].get('ISO3166-2')

    if isoCode is None:
        print("No ISO Code")
        print(region)
        return False

    nativeName = detailsData['names'].get('name')

    if isoCode in regionsMap:
        print("ISO code already exists ISO: " + isoCode)
        print(region)
        return False

    regionsMap[isoCode] = {
        "name": name,
        "nativeName": nativeName,
        "flag": region['flag']
    }
    return True


for countryCode, country in FlagsCodes.items():
    print(countryCode)
    regionsMap = {}

    for region in country['regions']:
        name = region['name']
        api_url = getRegionURL(name, countryCode)

        data = fetchData(api_url)
        if data:
            it = (d for d in data if d.get("type") == "administrative")

            matchData = next(it, None)

            while matchData:
                suceed = addResult(regionsMap, region, name, matchData)
                if not suceed:
                    matchData = next(it, None)
                    if matchData is not None:
                        print("Trying next match")
                else:
                    matchData = None

        else:
            print("No match data")

    flagsRegionCodes[countryCode]['regions'] = regionsMap
# Out:
# AL
# 1252289
# 1249872
# 1250609
# 1252589
# 1759889
# 1250098
# 1255521
# AD
# 2804753
# 2804754
# 2804755
# 2804756
# 2804757
# 2804758
# No match data
# AQ
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# AR
# 1224652
# 4683201
# No ISO Code
# {'name': 'Buenos Aires Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/15/Bandera_de_la_Provincia_de_Buenos_Aires.svg'}
# 6587642
# No ISO Code
# {'name': 'Chaco Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/33/Bandera_de_la_Provincia_del_Chaco.svg'}
# 153548
# 153551
# 6413250
# No ISO Code
# {'name': 'Misiones Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/ce/Bandera_de_la_Provincia_de_Misiones.svg'}
# 1606727
# 153547
# 5836465
# No ISO Code
# {'name': 'San Juan Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Bandera_de_la_Provincia_de_San_Juan.svg'}
# Trying next match
# 9561511
# No ISO Code
# {'name': 'San Juan Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Bandera_de_la_Provincia_de_San_Juan.svg'}
# Trying next match
# 12015555
# No ISO Code
# {'name': 'San Juan Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Bandera_de_la_Provincia_de_San_Juan.svg'}
# Trying next match
# 13458434
# No ISO Code
# {'name': 'San Juan Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Bandera_de_la_Provincia_de_San_Juan.svg'}
# Trying next match
# 4764377
# No ISO Code
# {'name': 'San Juan Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Bandera_de_la_Provincia_de_San_Juan.svg'}
# Trying next match
# 16155061
# No ISO Code
# {'name': 'San Juan Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Bandera_de_la_Provincia_de_San_Juan.svg'}
# Trying next match
# 15755048
# No ISO Code
# {'name': 'San Juan Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Bandera_de_la_Provincia_de_San_Juan.svg'}
# 16214600
# No ISO Code
# {'name': 'San Luis Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/0e/Bandera_de_la_Provincia_de_San_Luis.svg'}
# 153549
# 153550
# AU
# 2316593
# 2316595
# 2316596
# 2369652
# 2316741
# 2316598
# 2354197
# 2316594
# 2177207
# No ISO Code
# {'name': 'Christmas Island', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/67/Flag_of_Christmas_Island.svg'}
# Trying next match
# 11716751
# No ISO Code
# {'name': 'Christmas Island', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/67/Flag_of_Christmas_Island.svg'}
# 82636
# No ISO Code
# {'name': 'Cocos (Keeling) Islands', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/74/Flag_of_the_Cocos_%28Keeling%29_Islands.svg'}
# Trying next match
# 11716757
# No ISO Code
# {'name': 'Cocos (Keeling) Islands', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/74/Flag_of_the_Cocos_%28Keeling%29_Islands.svg'}
# 2574988
# No ISO Code
# {'name': 'Norfolk Island', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/48/Flag_of_Norfolk_Island.svg'}
# AT
# 76909
# 52345
# 77189
# 86538
# No ISO Code
# {'name': 'Salzburg', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b5/Flag_of_Salzburg_%28state%29.svg'}
# Trying next match
# 86539
# 35183
# 52343
# 102303
# 109166
# 74942
# BH
# 3028094
# 3028095
# No match data
# No match data
# BY
# 59189
# 163244
# No ISO Code
# {'name': 'Gomel Region', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/49/Flag_of_Homyel_Voblast.svg'}
# 59275
# 59752
# 59162
# 59506
# 59195
# BE
# 53134
# 90348
# 58274
# No ISO Code
# {'name': 'Brussels', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/bc/Flag_of_the_Brussels-Capital_Region.svg'}
# Trying next match
# 2404021
# No ISO Code
# {'name': 'Brussels', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/bc/Flag_of_the_Brussels-Capital_Region.svg'}
# BO
# 405935
# 396197
# 4503297
# No ISO Code
# {'name': 'Cochabamba', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f0/Flag_of_Cochabamba.svg'}
# Trying next match
# 393562
# 4499870
# No ISO Code
# {'name': 'La Paz', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/fb/Flag_of_La_paz.svg'}
# Trying next match
# 400473
# 395910
# 3358584
# 4509552
# 3360565
# 396198
# BA
# No match data
# 2528145
# 2528143
# BR
# 326266
# 303781
# 331463
# 332476
# 362413
# 302635
# 54882
# 334443
# 332924
# 333597
# 334051
# 315173
# 185579
# 301464
# 297640
# 303702
# 302819
# 2697338
# No ISO Code
# {'name': 'Rio de Janeiro', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/73/Bandeira_do_estado_do_Rio_de_Janeiro.svg'}
# Trying next match
# 57963
# 301079
# 242620
# 325866
# 326287
# 296584
# 298285
# No ISO Code
# {'name': 'São Paulo', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/2b/Bandeira_do_estado_de_S%C3%A3o_Paulo.svg'}
# Trying next match
# 298204
# 303940
# 336819
# 421151
# CA
# 391186
# 390867
# 390841
# 68942
# 391196
# 390558
# 68841
# 391115
# 61549
# 391178
# 391220
# 390840
# 391455
# CL
# 240932
# 296378
# 269826
# No ISO Code
# {'name': 'Arica y Parinacota Region', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/fa/Flag_of_Arica_y_Parinacota%2C_Chile.svg'}
# 271889
# 305693
# 252891
# 231672
# 274991
# 274988
# 239882
# 198848
# 7421025
# 206487
# 238393
# 198847
# CN
# 10264792
# No ISO Code
# {'name': 'Hong Kong', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/5b/Flag_of_Hong_Kong.svg'}
# Trying next match
# 913110
# 1867188
# No match data
# No match data
# No match data
# No match data
# 9636531
# No ISO Code
# {'name': 'Tainan', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/7d/Flag_of_Tainan_City.svg'}
# 3152417
# No ISO Code
# {'name': 'Taoyuan', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f1/Flag_of_Taoyuan_City.svg'}
# Trying next match
# 13544218
# No ISO Code
# {'name': 'Taoyuan', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f1/Flag_of_Taoyuan_City.svg'}
# Trying next match
# 13294117
# No ISO Code
# {'name': 'Taoyuan', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f1/Flag_of_Taoyuan_City.svg'}
# Trying next match
# 15676664
# No ISO Code
# {'name': 'Taoyuan', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f1/Flag_of_Taoyuan_City.svg'}
# Trying next match
# 15875647
# No ISO Code
# {'name': 'Taoyuan', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f1/Flag_of_Taoyuan_City.svg'}
# Trying next match
# 15904244
# No ISO Code
# {'name': 'Taoyuan', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f1/Flag_of_Taoyuan_City.svg'}
# 14034737
# No ISO Code
# {'name': 'Changhua County', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/3b/Flag_of_Changhua_County.svg'}
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# 2755765
# No ISO Code
# {'name': 'Yilan County', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b4/Flag_of_Yilan_County.svg'}
# No match data
# No match data
# CO
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# 1387968
# No ISO Code
# {'name': 'Bogotá', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/9e/Flag_of_Bogot%C3%A1.svg'}
# Trying next match
# 12893646
# KM
# 2955050
# 2955051
# 2955018
# CG
# 3947631
# CR
# 3222933
# 3223054
# 6336200
# No ISO Code
# {'name': 'Guanacaste Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/04/Bandera_de_la_Provincia_de_Guanacaste.svg'}
# 3221947
# 3223056
# 3223028
# 3223004
# HR
# 224165
# 222861
# 226750
# 226351
# 226271
# 226209
# 226223
# 226465
# 224183
# 222646
# 222870
# 226452
# 224139
# 226749
# 226741
# 226210
# 222869
# 222649
# 226726
# 226241
# 226224
# CZ
# 435515
# No ISO Code
# {'name': 'Central Bohemia', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/06/Flag_of_Central_Bohemian_Region.svg'}
# 439071
# No ISO Code
# {'name': 'Hradec Králové', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/bc/Flag_of_Hradec_Kralove_Region.svg'}
# 439482
# No ISO Code
# {'name': 'Karlovy Vary', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/0b/Flag_of_Karlovy_Vary_Region.svg'}
# 439073
# No ISO Code
# {'name': 'Liberec', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/45/Flag_of_Liberec_Region.svg'}
# 435512
# No ISO Code
# {'name': 'Moravia-Silesia', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f3/Flag_of_Moravian-Silesian_Region.svg'}
# 437057
# No ISO Code
# {'name': 'Olomouc', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/66/Flag_of_Olomouc_Region.svg'}
# 440145
# No ISO Code
# {'name': 'Pardubice', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c7/Flag_of_Pardubice_Region.svg'}
# Trying next match
# 442460
# 438344
# No ISO Code
# {'name': 'Plzeň', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4b/Flag_of_Plzen_Region.svg'}
# 435514
# 440166
# No ISO Code
# {'name': 'Ústí nad Labem', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/13/Flag_of_Usti_nad_Labem_Region.svg'}
# Trying next match
# 434262
# No ISO Code
# {'name': 'Ústí nad Labem', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/13/Flag_of_Usti_nad_Labem_Region.svg'}
# 442453
# 440910
# No ISO Code
# {'name': 'Zlín', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/84/Flag_of_Zlin_Region.svg'}
# Trying next match
# 442449
# DK
# No match data
# 1320608
# 1319935
# 1319936
# 1320370
# 1319978
# DM
# No match data
# No match data
# No match data
# No match data
# No match data
# EC
# 107886
# 108899
# 108720
# 114048
# 108860
# 963072
# 958681
# 113237
# 1628150
# 109468
# 113982
# 108088
# 109248
# 112910
# 108521
# 114276
# 114245
# 113869
# 113722
# 109441
# 113721
# 114574
# 113442
# 108326
# EG
# 3061846
# 3061757
# 3726184
# 3824513
# 3726170
# 4103336
# 4103403
# 4103404
# 3726124
# 3584607
# 3824206
# 3062184
# 4103405
# 3726211
# 3061826
# 3726175
# 3824207
# 3061827
# 3060792
# 4103406
# 4103337
# 3726189
# 3061758
# 4103407
# 3726186
# 3060793
# 3062185
# SV
# 3623374
# 3624451
# 3624440
# 3624439
# 7369049
# No ISO Code
# {'name': 'La Libertad', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/ae/Flag_of_La_Libertad_Department_%28El_Salvador%29.svg'}
# No match data
# 6553270
# No ISO Code
# {'name': 'La Unión', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/af/Departamento_de_La_Uni%C3%B3n.svg'}
# 3625421
# 6462027
# No ISO Code
# {'name': 'San Salvador', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d8/Bandera_de_San_Salvador_%282021%29.svg'}
# 6074004
# No ISO Code
# {'name': 'Santa Ana', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d9/Bandera_de_Santa_Ana%2C_El_Salvador.svg'}
# 7011532
# No ISO Code
# {'name': 'Sonsonate', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/de/Bandera_de_sonsonate.png/167px-Bandera_de_sonsonate.png'}
# Trying next match
# 13128797
# No ISO Code
# {'name': 'Sonsonate', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/de/Bandera_de_sonsonate.png/167px-Bandera_de_sonsonate.png'}
# Trying next match
# 3624092
# 3625389
# GQ
# EE
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# ET
# 1707249
# 1707264
# 1707653
# 1707655
# 1707700
# 1707656
# 3306775
# 1707658
# 13509372
# 1707148
# 1707699
# 13422225
# No ISO Code
# {'name': 'Dire Dawa', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Flag_of_Dire_Dawa.png/150px-Flag_of_Dire_Dawa.png'}
# Trying next match
# 1707654
# FI
# 2375171
# 1701740
# 1702330
# 1997164
# 1473990
# 1999428
# 918898
# 1703362
# 2000361
# 1702263
# 918897
# 37355
# FR
# 3792877
# 3792878
# 102740
# 8640
# 76910
# 3792876
# 4217435
# 8649
# 3793170
# 3792880
# 3792883
# 8650
# 8654
# 1401835
# 2502058
# 2470060
# 1891495
# 1363069
# GA
# 1243584
# 1243580
# 1243586
# 1243583
# 1243587
# 1243581
# 1243588
# 1243589
# 1243582
# GE
# 1152720
# 1995970
# DE
# 62611
# No match data
# 62422
# 62504
# 62559
# No ISO Code
# {'name': 'Bremen', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/0e/Flag_of_Bremen.svg'}
# Trying next match
# 62718
# 62782
# 62650
# 62771
# 28322
# 62761
# 62341
# 62372
# 62467
# 62607
# 51529
# 62366
# GT
# 214695
# 214712
# 214715
# 214702
# 4469376
# No ISO Code
# {'name': 'Escuintla', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/12/Flag_of_Escuintla_Department.gif/150px-Flag_of_Escuintla_Department.gif'}
# Trying next match
# 214714
# 1521463
# No ISO Code
# {'name': 'Guatemala', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/47/Bandera_del_Departamento_Guatemala.svg'}
# Trying next match
# 214704
# 214708
# 214705
# 214706
# 214716
# 214699
# 4476252
# No ISO Code
# {'name': 'Quetzaltenango', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/39/Vlagquetzaltenango.gif/150px-Vlagquetzaltenango.gif'}
# Trying next match
# 214710
# 214700
# 214711
# 214703
# 214707
# 9565597
# 214713
# 214696
# 214709
# 214698
# GY
# 7105826
# 7108866
# 7105917
# 7109048
# 7108958
# 7105874
# 7108941
# 7109155
# 7108944
# HN
# No match data
# 4627315
# 12113927
# 4627390
# 10559532
# No ISO Code
# {'name': 'Ocotepeque', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/e2/Bandera_de_Ocotepeque.svg'}
# Trying next match
# 4627394
# 4627317
# 16095620
# No ISO Code
# {'name': 'Santa Bárbara', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d7/Bandera_de_Santa_Barbara_Honduras.svg'}
# Trying next match
# 4627395
# HU
# 37244
# ID
# 2390836
# 1615621
# 3797243
# 2388356
# 2390837
# 2388357
# 2388613
# 2388664
# 3438227
# 5449459
# 2396778
# 2388665
# 14309176
# 2390838
# 2390839
# 7225996
# 5449460
# 2396796
# 2388666
# 2390843
# 4521144
# 2390840
# 3797244
# 2388668
# 2388615
# 2388667
# 2390842
# 2388361
# 2388616
# 1615622
# 4521145
# 2388669
# 2390841
# 5616105
# 6362934
# IQ
# 5392650
# No ISO Code
# {'name': 'Kurdistan Region', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/35/Flag_of_Kurdistan.svg'}
# 3242292
# 3244378
# 3244379
# 3242294
# 2969732
# 2969788
# 2969789
# 3242295
# IE
# 278721
# 278746
# 278750
# 14419962
# IT
# 45155
# 179296
# 7361997
# 39152
# 45757
# 53937
# 40095
# 40137
# 1783980
# 40218
# 42611
# 40784
# 301482
# 44879
# 53060
# 41256
# 44874
# 41977
# 42004
# 43648
# JP
# 3560336
# 3791413
# 1834655
# 2679957
# 3795063
# 357112
# 1553735
# 1800608
# 760746
# 1851649
# 3218753
# 3795658
# 356912
# 2682940
# 3794726
# 3792412
# 3795064
# 1842186
# 2689487
# 3795031
# 1842185
# 2137477
# 812190
# 3790801
# 1842184
# 3560284
# 1842151
# 358631
# 3559887
# 356911
# No match data
# 3794962
# 3795635
# 341906
# 1842150
# 1768185
# 357800
# 3346137
# 3793581
# 1800742
# 3795000
# No match data
# 1543125
# No match data
# 3285636
# 3793529
# 908959
# 3790869
# 4016543
# 3578391
# KE
# 3495537
# 14649074
# 3486321
# 11981582
# 3486017
# 3495544
# 3495545
# 3495548
# 3495549
# 3492707
# 3495551
# 3495552
# 3495553
# 3495554
# 9721587
# No ISO Code
# {'name': 'Nairobi', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/84/Flag_of_Nairobi.svg'}
# Trying next match
# 3492709
# 3495556
# 3495557
# 3495559
# 3495560
# 11981571
# KR
# 2297418
# 2396450
# 2395674
# 2349984
# 2399220
# 2297419
# 2395867
# 2327258
# 2327259
# 2308426
# 2306392
# 2304454
# 2393403
# 2355168
# 2398104
# 2398560
# KW
# 4579477
# 4579482
# KG
# 178019
# 178026
# 178025
# 178024
# 1251542
# 178020
# 178023
# 8493930
# 8496351
# LV
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# LR
# 3320948
# 3320949
# 3320950
# 3320951
# 3320952
# 3315297
# 3315170
# 3320953
# 3320954
# 3315051
# 3320955
# 3320773
# 3315299
# 3315298
# 3315211
# LI
# LT
# 1076930
# 1069509
# 1189583
# 974211
# 1028503
# 1256237
# 1307305
# 1211025
# 966958
# 977317
# MY
# 2939653
# 4444908
# 4443571
# 2939673
# 2939674
# 4444595
# 4445131
# 4445076
# 4444918
# 3879783
# 3879784
# 2932285
# 4444411
# 2939672
# 15974635
# No ISO Code
# {'name': 'Labuan', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/69/Flag_of_Labuan.svg'}
# Trying next match
# 4521286
# 4443881
# MT
# No match data
# No match data
# No match data
# No match data
# MX
# 2610002
# 2589601
# 2589611
# 2568834
# 2556679
# 1673425
# 1661524
# 2340912
# 2399740
# 2340909
# 2439316
# 1376490
# 2340910
# 114686
# No ISO Code
# {'name': 'Mexico', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b7/Flag_of_the_State_of_Mexico.svg'}
# Trying next match
# 1376330
# 1376330
# ISO code already exists ISO: MX-CMX
# {'name': 'Mexico City', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b3/Flag_of_Mexico_City%2C_Mexico.svg'}
# 2340636
# 1376332
# 7695827
# 1661523
# 2529822
# 1376491
# 2340903
# 2614434
# 4086617
# 2455086
# 1673426
# 2556680
# 2415518
# 1375274
# 2415761
# 2614435
# 2399704
# FM
# 3819480
# MD
# 1692078
# 1104136
# 1699034
# 58988
# 65343
# 1211126
# 1692126
# 59007
# 1693907
# 1692123
# 59000
# 58984
# 1693874
# 1692518
# No ISO Code
# {'name': 'Hîncești District', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Hincesti_rajon_flag.gif/148px-Hincesti_rajon_flag.gif'}
# 1691800
# 1699023
# 58990
# 59005
# 1692172
# 1435790
# 1693908
# 58996
# 1693561
# 1693523
# 65344
# 85827
# 1699033
# 58993
# 58985
# 1699032
# MC
# No match data
# MN
# 270075
# 3382266
# 270052
# 270073
# 270091
# 269886
# 270050
# 270054
# 270095
# 269885
# 270055
# 7304614
# No ISO Code
# {'name': 'Khövsgöl Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/72/Mn_flag_kh%C3%B6vsg%C3%B6l_aimag_2014.svg'}
# 270051
# 270092
# 270074
# 270089
# 269874
# 3382267
# 270059
# 4074177
# 270090
# ME
# 8881697
# No ISO Code
# {'name': 'Bar', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/07/Flag_of_Bar%2C_Montenegro.svg'}
# 12434568
# No ISO Code
# {'name': 'Bijelo Polje', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/61/Flag_of_Bijelo_Polje.png/200px-Flag_of_Bijelo_Polje.png'}
# Trying next match
# 12512551
# No ISO Code
# {'name': 'Bijelo Polje', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/61/Flag_of_Bijelo_Polje.png/200px-Flag_of_Bijelo_Polje.png'}
# 2187904
# No ISO Code
# {'name': 'Herceg Novi', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Flag_of_Herceg_Novi.jpg/150px-Flag_of_Herceg_Novi.jpg'}
# 11497014
# No ISO Code
# {'name': 'Nikšić', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e2/Flag_of_Nik%C5%A1i%C4%87.gif/200px-Flag_of_Nik%C5%A1i%C4%87.gif'}
# 2319536
# 8882104
# No ISO Code
# {'name': 'Podgorica', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/65/Flag_of_Podgorica%2C_Montenegro.svg'}
# 2319539
# 12492506
# No ISO Code
# {'name': 'Tivat', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/ff/Flag_of_Tivat.svg'}
# 3750229
# No ISO Code
# {'name': 'Tuzi', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/fc/Flag_of_Tuzi.svg'}
# MM
# 5996473
# 5996474
# 5996479
# 5996480
# 5996484
# 5996486
# 5996487
# 5996475
# 5996476
# 5996477
# 5996478
# 5996481
# 5996485
# 5996482
# 7200536
# No ISO Code
# {'name': 'Danu Self-Administered Zone', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/e8/Flag_of_the_Danu_people.svg'}
# 6833794
# No ISO Code
# {'name': 'Kokang Self-Administered Zone', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/41/Flag_of_Kokang_Self-Administered_Zone.svg'}
# 7183862
# No ISO Code
# {'name': 'Naga Self-Administered Zone', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/01/Flag_of_Naga_Self-Administered_Zone.png/160px-Flag_of_Naga_Self-Administered_Zone.png'}
# 7200810
# No ISO Code
# {'name': 'Pa Laung Self-Administered Zone', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/e3/Flag_of_the_Palaung_people.svg'}
# 7200537
# No ISO Code
# {'name': "Pa'O Self-Administered Zone", 'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/28/Flag_of_the_Pa-O_National_Organisation.svg'}
# 7160199
# No ISO Code
# {'name': 'Wa Self-Administered Division', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/48/Flag_of_Wa_State.svg'}
# NL
# 1231749
# 1216719
# 47796
# No ISO Code
# {'name': 'Netherlands', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/20/Flag_of_the_Netherlands.svg'}
# Trying next match
# 2323309
# No ISO Code
# {'name': 'Netherlands', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/20/Flag_of_the_Netherlands.svg'}
# 1231790
# 47540
# 47407
# 47381
# 47554
# 409863
# No ISO Code
# {'name': 'Groningen', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/01/Flag_Groningen.svg'}
# Trying next match
# 47826
# 47793
# 47696
# 47654
# 47608
# 47772
# 419203
# No ISO Code
# {'name': 'Utrecht', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4b/Utrecht_%28province%29-Flag.svg'}
# Trying next match
# 1433619
# No ISO Code
# {'name': 'Utrecht', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4b/Utrecht_%28province%29-Flag.svg'}
# Trying next match
# 47667
# 47806
# 2324450
# 2324451
# 2324452
# NZ
# 2647558
# NI
# 2194862
# 3634063
# 2194907
# 2194866
# 2194930
# 3634064
# 2196713
# 2194905
# 2194929
# 5835475
# 3634065
# 2194958
# 2194941
# 3634066
# 2194832
# 2195034
# 2195081
# NE
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# NO
# 406868
# 408105
# 406091
# 405836
# 406567
# 10487008
# PK
# 3780130
# 357968
# 3780131
# 357988
# 357981
# PW
# 3825286
# 3825287
# 3825288
# 3825289
# 3825302
# 3825290
# 3825291
# 3825292
# 3825293
# 3825294
# 3825296
# 3825297
# 3825295
# 3825298
# 3825299
# 3825300
# PA
# 8394593
# No ISO Code
# {'name': 'Bocas del Toro', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4d/Bandera_de_la_Provincia_de_Bocas_del_Toro.svg'}
# Trying next match
# 3420383
# 8406812
# No ISO Code
# {'name': 'Chiriquí', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d4/Bandera_de_la_Provincia_de_Chiriqu%C3%AD.svg'}
# Trying next match
# 5740681
# 9360936
# No ISO Code
# {'name': 'Coclé', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/6b/Bandera_de_la_Provincia_de_Cocl%C3%A9.svg'}
# Trying next match
# 5748368
# 8421155
# No ISO Code
# {'name': 'Colón', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/ee/Bandera_de_la_Provincia_de_Col%C3%B3n.svg'}
# Trying next match
# 5740655
# 5740656
# 5740659
# 8434756
# No ISO Code
# {'name': 'Los Santos', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/9f/Bandera_de_la_Provincia_de_Los_Santos.svg'}
# Trying next match
# 5740662
# 5740664
# 5740666
# 5740658
# 5740663
# 13458933
# No match data
# GN
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# PY
# 389882
# 389891
# 389886
# 3654543
# 389883
# 389890
# 389897
# 389888
# 389892
# 389885
# 389889
# 389894
# 389898
# 389896
# 389895
# 14699517
# No ISO Code
# {'name': 'Paraguarí', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Bandera_del_Departamento_de_Paraguar%C3%AD.JPG/150px-Bandera_del_Departamento_de_Paraguar%C3%AD.JPG'}
# Trying next match
# 389893
# 389884
# 389887
# PE
# 1973462
# 1953170
# 1929522
# 1879287
# 1930901
# 1896111
# 1944657
# 1933551
# 1954493
# 1899013
# 1948258
# 1967959
# 1969722
# 1944659
# 1994077
# 1891287
# 1875889
# 1948452
# 1986151
# 1907899
# 1971661
# 1874307
# 1986974
# 1921996
# PH
# 52299
# 1507282
# 52297
# 1506745
# 1504625
# 1506746
# 52296
# 1504662
# 1513281
# 1504680
# 1506352
# 1504427
# 52304
# 1506424
# 1550487
# 48393
# 1504656
# 1504756
# 1504550
# 1504551
# 1552824
# 1550483
# 1506351
# 1503544
# 12455830
# No ISO Code
# {'name': 'Cebu', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/11/Flag_of_Cebu_%28province%29.svg'}
# Trying next match
# 1506936
# 1513151
# 1507283
# 1507313
# 1513050
# 3304098
# 1507095
# 1507007
# 1506373
# 1506802
# 52303
# 1504744
# 1504724
# 1506774
# 1504761
# 52300
# 1504722
# 1503483
# 1513179
# 1513166
# 1506532
# 1506331
# 1506350
# 1513208
# 1513190
# 52301
# 1506913
# 1506914
# 1506364
# 52306
# 52305
# 1506320
# 1506328
# 1506669
# 1504669
# 1504701
# 1504500
# 52302
# 1504641
# 1506343
# 1506416
# 1513098
# 3604058
# 1504631
# 1513131
# 1506605
# 1513160
# 1513292
# 1507031
# 1507067
# 52307
# 1513298
# 1504691
# 1513211
# 1513233
# 1513227
# PL
# 130971
# 223407
# 224459
# 224458
# 224457
# 130919
# 130969
# 130935
# 224460
# 224461
# 130975
# 224462
# 130957
# 130914
# 223408
# 104401
# PT
# 1629146
# 1629145
# RO
# No match data
# No match data
# 377733
# No match data
# No match data
# No match data
# No match data
# No match data
# RU
# 253256
# 145194
# 77677
# 145729
# 109876
# No match data
# 253252
# 109879
# 108083
# 109878
# 393980
# 115136
# No match data
# No match data
# No match data
# 115114
# 72196
# 110032
# 79374
# 145195
# 115134
# 190911
# 109877
# 80513
# 151234
# 144764
# 145730
# 151233
# 108082
# 190090
# 115135
# 151225
# 108081
# 151223
# 147166
# 140337
# 112819
# 83184
# 81997
# 72197
# 77665
# 115106
# 72181
# No match data
# 85617
# 145454
# 103906
# 81995
# 144763
# 115100
# 85963
# 140290
# 72223
# 176095
# 72169
# 151228
# 51490
# 2099216
# 72195
# 89331
# 140294
# 140292
# 77669
# 72224
# 72182
# 155262
# 85606
# 71950
# 72194
# 72193
# 394235
# 79379
# 81996
# 72180
# 2095259
# 140295
# 81993
# 140291
# 72192
# No match data
# 77687
# 81994
# 102269
# 337422
# No match data
# 147167
# 274048
# 140296
# 151231
# 191706
# SK
# 2265296
# No ISO Code
# {'name': 'Banská Bystrica', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/ff/Banskobystricky_vlajka.svg'}
# Trying next match
# 2265245
# No ISO Code
# {'name': 'Banská Bystrica', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/ff/Banskobystricky_vlajka.svg'}
# 1702499
# No ISO Code
# {'name': 'Bratislava', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4c/Bratislavsky_vlajka.svg'}
# 1690324
# No ISO Code
# {'name': 'Košice', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/32/Kosicky_vlajka.svg'}
# 2210192
# No ISO Code
# {'name': 'Nitra', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/ea/Nitriansky_vlajka.svg'}
# Trying next match
# 388268
# 2320257
# No ISO Code
# {'name': 'Prešov', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4d/Presovsky_vlajka.svg'}
# Trying next match
# 2320148
# No ISO Code
# {'name': 'Prešov', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4d/Presovsky_vlajka.svg'}
# 1799254
# No ISO Code
# {'name': 'Trenčín', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/51/Trenciansky_vlajka.svg'}
# Trying next match
# 388267
# 2204009
# No ISO Code
# {'name': 'Trnava', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d4/Trnavsky_vlajka.svg'}
# Trying next match
# 2203958
# No ISO Code
# {'name': 'Trnava', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d4/Trnavsky_vlajka.svg'}
# 1859537
# No ISO Code
# {'name': 'Žilina', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d8/Zilinsky_vlajka.svg'}
# Trying next match
# 388269
# SB
# 2536258
# 2536259
# 11916914
# 2536261
# 2536262
# 2536263
# 2536264
# 2536265
# 11916824
# 2536278
# SO
# 14278313
# 13702729
# No ISO Code
# {'name': 'Galmudug', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/9b/Flag_of_Galmudug_State_of_Somalia_%282015%29.svg'}
# 13702730
# No ISO Code
# {'name': 'Hirshabelle', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/18/Hirshabeelle.png/179px-Hirshabeelle.png'}
# 13702732
# No ISO Code
# {'name': 'Jubaland', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/a6/Flag_of_Jubaland_%28Somalia%29.svg'}
# 13702728
# No ISO Code
# {'name': 'Puntland', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/7a/Flag_of_Puntland.svg'}
# 13702731
# No ISO Code
# {'name': 'South West', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/8b/Flag_of_South_West_State_of_Somalia.svg'}
# 3586169
# No ISO Code
# {'name': 'Somaliland', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4d/Flag_of_Somaliland.svg'}
# ZA
# 349556
# SS
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# ES
# 349044
# 349045
# 349033
# 348981
# 349042
# 349048
# 6426101
# 349052
# 349041
# 349053
# 349050
# 349036
# 6426654
# 349055
# 349047
# 349027
# 349043
# 1822781
# No ISO Code
# {'name': 'Ceuta', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/fd/Flag_Ceuta.svg'}
# Trying next match
# 1154756
# 7523933
# No ISO Code
# {'name': 'Melilla', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f7/Flag_of_Melilla.svg'}
# Trying next match
# 1154757
# LK
# 4630835
# 4630810
# 4630836
# 4630837
# 3237344
# 4630838
# 4630839
# 4630840
# 4630841
# SR
# No match data
# SE
# 54413
# 52834
# 941530
# 52832
# 54403
# 52826
# 54374
# 54417
# 54412
# 52824
# 54409
# 54391
# 54386
# 54220
# 54223
# 52825
# 52827
# 54221
# 54367
# 54222
# 940675
# CH
# 1686359
# 1686649
# 1686666
# 1686366
# 1699639
# 1682378
# No ISO Code
# {'name': 'Bern', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/30/Flag_of_Canton_of_Bern.svg'}
# Trying next match
# 1686344
# 1698314
# 1685488
# No ISO Code
# {'name': 'Geneva', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/83/Flag_of_Canton_of_Geneva.svg'}
# Trying next match
# 1702419
# 1685673
# 1686631
# 1697347
# 1682891
# No ISO Code
# {'name': 'Lucerne', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/db/Flag_of_Canton_of_Lucerne.svg'}
# Trying next match
# 1685677
# 1685519
# No ISO Code
# {'name': 'Neuchâtel', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/57/Flag_of_Canton_of_Neuch%C3%A2tel.svg'}
# Trying next match
# 1702420
# 1686449
# 1686448
# 1683703
# No ISO Code
# {'name': 'Schaffhausen', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b0/Flag_of_Canton_of_Schaffhausen.svg'}
# Trying next match
# 1696112
# 1688583
# 1701133
# 1683941
# No ISO Code
# {'name': 'St. Gallen', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/a1/Flag_of_Canton_of_Sankt_Gallen.svg'}
# Trying next match
# 1687006
# 1693811
# 1687730
# 1693971
# 1686699
# 1702421
# 1686447
# 1682248
# No ISO Code
# {'name': 'Zürich', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/9b/Flag_of_Canton_of_Z%C3%BCrich.svg'}
# Trying next match
# 1690227
# TH
# 2746948
# 1908765
# 92277
# 2934602
# 1908766
# 1908767
# 1908768
# 1908769
# 1908770
# 1908771
# 1908772
# 1908773
# 1908774
# 1908775
# 1908776
# 1908777
# 1908778
# 1908779
# 1908781
# 1908782
# 1908783
# 1908784
# 1908785
# 1908786
# 2934603
# 1908787
# 1908788
# 1908789
# 1908790
# 1908791
# 1908792
# 1908793
# 1908794
# 1925819
# 1908795
# 1908796
# 1908797
# 1908798
# 1908799
# 1908800
# 1908801
# 1908802
# 1908803
# 1908804
# 1908805
# 1908806
# 1908807
# 2934604
# 1908808
# 1908809
# 1908810
# 1908811
# 1908812
# 1908813
# 2934605
# 1908814
# 1908815
# 1908816
# 1908817
# 1908818
# 1908819
# 1908820
# 1908821
# 1908822
# 1908823
# 1908824
# 1908825
# 1908826
# 1908827
# 1908828
# 1908829
# 1908830
# 1908831
# 2934606
# 1908832
# 1908872
# 1908873
# UA
# 91278
# 71249
# 72526
# 101746
# 71973
# 72488
# 71254
# 71022
# 90742
# 101859
# 71248
# 71971
# 72380
# 72635
# 72634
# 91294
# 71236
# 71250
# 72525
# 90726
# 71064
# 72489
# 30719657
# Request failed with status code: 404
# No details data
# {'name': 'Zaporizhzhia Oblast', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b8/Flag_of_Zaporizhia_Oblast.svg'}
# 71245
# 421866
# 1574364
# 72639
# AE
# 3766481
# 3766482
# 3766484
# 3766485
# 3766486
# 3766487
# GB
# 58447
# 58446
# 58437
# US
# 161950
# 1116270
# 162018
# 161646
# 165475
# 161961
# 165794
# 162110
# 162050
# 161957
# 166563
# 162116
# 122586
# 161816
# 161650
# 161644
# 161655
# 224922
# 63512
# 162112
# 61315
# 165789
# 165471
# 161943
# 161638
# 162115
# 161648
# 165473
# 67213
# 224951
# 162014
# 175905
# No ISO Code
# {'name': 'New York', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/1a/Flag_of_New_York.svg'}
# Trying next match
# 61320
# 224045
# 161653
# 162061
# 161645
# 165476
# 162109
# 392915
# 224040
# 161652
# 161838
# 114690
# 161993
# 60759
# 224042
# 5396194
# No ISO Code
# {'name': 'Washington', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/54/Flag_of_Washington.svg'}
# Trying next match
# 165479
# 162068
# 165466
# 161991
# 5396194
# No ISO Code
# {'name': 'Washington, D.C.', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d4/Flag_of_the_District_of_Columbia.svg'}
# 2177187
# 306001
# 306004
# 4422604
# 286898
# UY
# 1617618
# 1625171
# 1656175
# 1650769
# 1646018
# 1645684
# 1635164
# 1635124
# 2473675
# No ISO Code
# {'name': 'Maldonado', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/52/Flag_of_Maldonado_Department.png/150px-Flag_of_Maldonado_Department.png'}
# Trying next match
# 1635117
# 1662387
# 1662476
# 1627812
# 1653142
# 1614733
# 1635189
# 1646600
# 1640982
# UZ
# 196241
# VU
# 3765629
# 3765606
# 3765591
# 3765630
# 3765631
# 3765596
# VE
# 2269815
# 2267150
# 3395162
# 272746
# 3763132
# 2269155
# 272745
# 272662
# 272669
# 2269792
# 272663
# 272744
# 272635
# 272673
# 272670
# 2269770
# 272661
# 272671
# 272633
# 272634
# 2442704
# 272743
# 272632
# 2444378
# No match data
# YE
# No match data
# No match data
# No match data
# No match data
# No match data
# ZW
# 3337019
# 318467

# %% [markdown]
# ## Save final auto flags

# %%
json_data = json.dumps(
    flags, indent=4, ensure_ascii=False).encode('utf8').decode()
file_path = "out/flags_auto.json"
with open(file_path, "w") as json_file:
    json_file.write(json_data)

print("JSON data has been saved to", file_path)
# Out:
# JSON data has been saved to out/flags_auto.json

# %% [markdown]
# ## Clean flags auto leaving only the regions in osu world

# %%
flagsPathAuto = "./out/flags_auto.json"

with open(flagsPathAuto, "r", encoding="utf-8") as json_file:
    flagsAuto = json.load(json_file)

# %% [markdown]
# Add countries from osuworld

# %%
countries: dict = fetchData("https://osuworld.octo.moe/locales/en/countries.json")

# %%
for countryCode, country in countries.items():
    if countryCode not in flagsAuto:
        flagsAuto[countryCode] = {}
        flagsAuto[countryCode]['name'] = country
        flagsAuto[countryCode]['regions'] = {}
        print(f"Country {country} not found in flagsAuto.json")
# Out:
# Country Kazakhstan not found in flagsAuto.json
# Country Singapore not found in flagsAuto.json
# Country Turkey not found in flagsAuto.json
# Country Taiwan not found in flagsAuto.json
# Country Vietnam not found in flagsAuto.json

# %% [markdown]
# add regions from osu world

# %%
regions: dict = fetchData("https://osuworld.octo.moe/locales/en/regions.json")

# %%
flags: dict = copy.deepcopy(flagsAuto)

for countryCode, country in flagsAuto.items():
    osuWorldRegions: dict = regions.get(countryCode)
    if osuWorldRegions is None:
        flags.pop(countryCode, None)
        continue

    for regionCode, region in country['regions'].items():
        osuWorldRegionKeys = osuWorldRegions.keys()
        if regionCode in osuWorldRegionKeys:
            region['name'] = osuWorldRegions[regionCode]
        else:
            flags[countryCode]['regions'].pop(regionCode, None)

    for osuWorldRegion in osuWorldRegions:
        if osuWorldRegion not in country['regions']:
            flags[countryCode]['regions'][osuWorldRegion] = {
                "name": osuWorldRegions[osuWorldRegion],
                "nativeName": "",
                "flag": ""
            }

# %% [markdown]
# Save

# %%
json_data = json.dumps(
    flags, indent=4, ensure_ascii=False).encode('utf8').decode()
file_path = "out/flags.json"
with open(file_path, "w") as json_file:
    json_file.write(json_data)

print("JSON data has been saved to", file_path)
# Out:
# JSON data has been saved to out/flags.json

# %% [markdown]
# Reload data

# %%
flagsPath = "./out/flags.json"

with open(flagsPath, "r", encoding="utf-8") as json_file:
    flags = json.load(json_file)

# %% [markdown]
# ## Add Manual changes to the automatic flags

# %%
flagsAdditionsPath = "./in/flags_additions.json"

with open(flagsAdditionsPath, "r", encoding="utf-8") as json_file:
    flagsAdditions = json.load(json_file)

# %%
import collections.abc

def update(d, u):
    for k, v in u.items():
        if isinstance(v, collections.abc.Mapping):
            d[k] = update(d.get(k, {}), v)
        else:
            d[k] = v
    return d

# %%
update(flags, flagsAdditions)
# Out:
# {'AR': {'name': 'Argentina',
#   'nativeName': 'Argentina',
#   'regions': {'AR-C': {'name': 'Buenos Aires',
#     'nativeName': 'Buenos Aires',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f5/Bandera_de_la_Ciudad_de_Buenos_Aires.svg'},
#    'AR-U': {'name': 'Chubut Province',
#     'nativeName': 'Chubut',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/88/Bandera_de_la_Provincia_del_Chubut.svg'},
#    'AR-E': {'name': 'Entre Ríos Province',
#     'nativeName': 'Entre Ríos',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/5b/Bandera_de_la_Provincia_de_Entre_Ríos.svg'},
#    'AR-Q': {'name': 'Neuquén Province',
#     'nativeName': 'Neuquén',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/bc/Bandera_de_la_Provincia_de_Neuquén.svg'},
#    'AR-R': {'name': 'Río Negro Province',
#     'nativeName': 'Río Negro',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/5d/Bandera_de_la_Provincia_del_Río_Negro.svg'},
#    'AR-Z': {'name': 'Santa Cruz Province',
#     'nativeName': 'Santa Cruz',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/45/Bandera_de_la_Provincia_de_Santa_Cruz.svg'},
#    'AR-V': {'name': 'Tierra del Fuego Province',
#     'nativeName': 'Tierra del Fuego',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/94/Bandera_de_la_Provincia_de_Tierra_del_Fuego.svg'},
#    'AR-A': {'name': 'Salta Province', 'nativeName': 'Salta', 'flag': ''},
#    'AR-B': {'name': 'Buenos Aires Province',
#     'nativeName': 'Buenos Aires',
#     'flag': ''},
#    'AR-D': {'name': 'San Luis Province', 'nativeName': 'San Luis', 'flag': ''},
#    'AR-F': {'name': 'La Rioja Province', 'nativeName': 'La Rioja', 'flag': ''},
#    'AR-G': {'name': 'Santiago del Estero Province',
#     'nativeName': 'Santiago del Estero',
#     'flag': ''},
#    'AR-H': {'name': 'Chaco Province', 'nativeName': 'Chaco', 'flag': ''},
#    'AR-J': {'name': 'San Juan Province', 'nativeName': 'San Juan', 'flag': ''},
#    'AR-K': {'name': 'Catamarca Province',
#     'nativeName': 'Catamarca',
#     'flag': ''},
#    'AR-L': {'name': 'La Pampa Province', 'nativeName': 'La Pampa', 'flag': ''},
#    'AR-M': {'name': 'Mendoza Province', 'nativeName': 'Mendoza', 'flag': ''},
#    'AR-N': {'name': 'Misiones Province', 'nativeName': 'Misiones', 'flag': ''},
#    'AR-P': {'name': 'Formosa Province', 'nativeName': 'Formosa', 'flag': ''},
#    'AR-S': {'name': 'Santa Fe Province', 'nativeName': 'Santa Fe', 'flag': ''},
#    'AR-T': {'name': 'Tucumán Province', 'nativeName': 'Tucumán', 'flag': ''},
#    'AR-W': {'name': 'Corrientes Province',
#     'nativeName': 'Corrientes',
#     'flag': ''},
#    'AR-X': {'name': 'Córdoba Province', 'nativeName': 'Córdoba', 'flag': ''},
#    'AR-Y': {'name': 'Jujuy Province', 'nativeName': 'Jujuy', 'flag': ''}}},
#  'AU': {'name': 'Australia',
#   'nativeName': 'Australia',
#   'regions': {'AU-NSW': {'name': 'New South Wales',
#     'nativeName': 'New South Wales',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/00/Flag_of_New_South_Wales.svg'},
#    'AU-QLD': {'name': 'Queensland',
#     'nativeName': 'Queensland',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/04/Flag_of_Queensland.svg'},
#    'AU-SA': {'name': 'South Australia',
#     'nativeName': 'South Australia',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/fd/Flag_of_South_Australia.svg'},
#    'AU-TAS': {'name': 'Tasmania',
#     'nativeName': 'Tasmania',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/46/Flag_of_Tasmania.svg'},
#    'AU-VIC': {'name': 'Victoria',
#     'nativeName': 'Victoria',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/08/Flag_of_Victoria_(Australia).svg'},
#    'AU-WA': {'name': 'Western Australia',
#     'nativeName': 'Western Australia',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/a5/Flag_of_Western_Australia.svg'},
#    'AU-ACT': {'name': 'Australian Capital Territory',
#     'nativeName': 'Australian Capital Territory',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/8c/Flag_of_the_Australian_Capital_Territory.svg'},
#    'AU-NT': {'name': 'Northern Territory',
#     'nativeName': 'Northern Territory',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b7/Flag_of_the_Northern_Territory.svg'}}},
#  'AT': {'name': 'Austria',
#   'nativeName': 'Österreich',
#   'regions': {'AT-1': {'name': 'Burgenland',
#     'nativeName': 'Burgenland',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/95/Flag_of_Burgenland_(state).svg'},
#    'AT-2': {'name': 'Carinthia',
#     'nativeName': 'Kärnten',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/84/Flag_of_Carinthia_(state).svg'},
#    'AT-3': {'name': 'Lower Austria',
#     'nativeName': 'Niederösterreich',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b1/Flag_of_Lower_Austria_(state).svg'},
#    'AT-5': {'name': 'Salzburg',
#     'nativeName': 'Salzburg',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b5/Flag_of_Salzburg_(state).svg'},
#    'AT-6': {'name': 'Styria',
#     'nativeName': 'Steiermark',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/57/Flag_of_Styria_(state).svg'},
#    'AT-7': {'name': 'Tyrol',
#     'nativeName': 'Tirol',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/25/Flag_of_Tirol_(state).svg'},
#    'AT-4': {'name': 'Upper Austria',
#     'nativeName': 'Oberösterreich',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/58/Flag_of_Upper_Austria_(state).svg'},
#    'AT-9': {'name': 'Vienna',
#     'nativeName': 'Wien',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/48/Flag_of_Vienna_(state).svg'},
#    'AT-8': {'name': 'Vorarlberg',
#     'nativeName': 'Vorarlberg',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/a7/Flag_of_Vorarlberg_(state).svg'}}},
#  'BY': {'name': 'Belarus',
#   'nativeName': 'Bielaruś',
#   'regions': {'BY-BR': {'name': 'Brest Region',
#     'nativeName': 'Брэсцкая вобласць',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/ec/Flag_of_Brest_Voblast,_Belarus.svg'},
#    'BY-HR': {'name': 'Grodno Region',
#     'nativeName': 'Гродзенская вобласць',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f8/Flag_of_Hrodna_Voblasts.svg'},
#    'BY-MI': {'name': 'Minsk Region',
#     'nativeName': 'Мінская вобласць',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/2e/Flag_of_Minsk_Voblast.svg'},
#    'BY-MA': {'name': 'Mogilev Region',
#     'nativeName': 'Магілёўская вобласць',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/ba/Flag_of_Mahilyow_Voblast.svg'},
#    'BY-VI': {'name': 'Vitebsk Region',
#     'nativeName': 'Віцебская вобласць',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/2d/Flag_of_Vitsebsk_region.svg'},
#    'BY-HO': {'name': 'Homyel Region',
#     'nativeName': 'Гомельская вобласць',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/49/Flag_of_Homyel_Voblast.svg'}}},
#  'BE': {'name': 'Belgium',
#   'nativeName': 'België',
#   'regions': {'BE-VAN': {'name': 'Antwerp',
#     'nativeName': 'Antwerpen',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/10/Flag_of_Antwerp.svg'},
#    'BE-BRU': {'name': 'Brussels-Capital',
#     'nativeName': 'Gewest',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/bc/Flag_of_the_Brussels-Capital_Region.svg'},
#    'BE-VOV': {'name': 'East Flanders',
#     'nativeName': 'Oost-Vlaanderen',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/eb/Flag_of_Oost-Vlaanderen.svg'},
#    'BE-VBR': {'name': 'Flemish Brabant',
#     'nativeName': 'Vlaams-Brabant',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/bd/Flag_of_Flemish_Brabant.svg'},
#    'BE-WHT': {'name': 'Hainaut',
#     'nativeName': 'Hainaut',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/1f/Flag_of_Hainaut.svg'},
#    'BE-VLI': {'name': 'Limburg',
#     'nativeName': 'Limburg',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/70/Flag_of_Limburg_%28Belgium%29.svg'},
#    'BE-WLG': {'name': 'Liège',
#     'nativeName': 'Liège',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/bc/Flag_of_the_Province_of_Li%C3%A8ge.svg'},
#    'BE-WLX': {'name': 'Luxembourg',
#     'nativeName': 'Luxembourg',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/06/Official_flag_of_the_Province_of_Luxembourg.svg'},
#    'BE-WNA': {'name': 'Namur',
#     'nativeName': 'BE-WNA',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/00/Flag_of_Namur_Province.svg'},
#    'BE-WBR': {'name': 'Walloon Brabant',
#     'nativeName': 'Brabant wallon',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/47/Drapeau_Province_BE_Brabant_Wallon.svg'},
#    'BE-VWV': {'name': 'West Flanders',
#     'nativeName': 'West-Vlaanderen',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c2/Flag_of_West_Flanders.svg'}}},
#  'BR': {'name': 'Brazil',
#   'nativeName': 'Brasil',
#   'regions': {'BR-AC': {'name': 'Acre',
#     'nativeName': 'Acre',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4c/Bandeira_do_Acre.svg'},
#    'BR-AL': {'name': 'Alagoas',
#     'nativeName': 'Alagoas',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/88/Bandeira_de_Alagoas.svg'},
#    'BR-AP': {'name': 'Amapá',
#     'nativeName': 'Amapá',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/0c/Bandeira_do_Amapá.svg'},
#    'BR-AM': {'name': 'Amazonas',
#     'nativeName': 'Amazonas',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/6b/Bandeira_do_Amazonas.svg'},
#    'BR-BA': {'name': 'Bahia',
#     'nativeName': 'Bahia',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/28/Bandeira_da_Bahia.svg'},
#    'BR-CE': {'name': 'Ceará',
#     'nativeName': 'Ceará',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/2e/Bandeira_do_Ceará.svg'},
#    'BR-ES': {'name': 'Espírito Santo',
#     'nativeName': 'Espírito Santo',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/43/Bandeira_do_Espírito_Santo.svg'},
#    'BR-GO': {'name': 'Goiás',
#     'nativeName': 'Goiás',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/be/Flag_of_Goiás.svg'},
#    'BR-MA': {'name': 'Maranhão',
#     'nativeName': 'Maranhão',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/45/Bandeira_do_Maranhão.svg'},
#    'BR-MT': {'name': 'Mato Grosso',
#     'nativeName': 'Mato Grosso',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/0b/Bandeira_de_Mato_Grosso.svg'},
#    'BR-MS': {'name': 'Mato Grosso do Sul',
#     'nativeName': 'Mato Grosso do Sul',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/64/Bandeira_de_Mato_Grosso_do_Sul.svg'},
#    'BR-MG': {'name': 'Minas Gerais',
#     'nativeName': 'Minas Gerais',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f4/Bandeira_de_Minas_Gerais.svg'},
#    'BR-PA': {'name': 'Pará',
#     'nativeName': 'Pará',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/02/Bandeira_do_Pará.svg'},
#    'BR-PB': {'name': 'Paraíba',
#     'nativeName': 'Paraíba',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/bb/Bandeira_da_Paraíba.svg'},
#    'BR-PR': {'name': 'Paraná',
#     'nativeName': 'Paraná',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/93/Bandeira_do_Paraná.svg'},
#    'BR-PE': {'name': 'Pernambuco',
#     'nativeName': 'Pernambuco',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/59/Bandeira_de_Pernambuco.svg'},
#    'BR-PI': {'name': 'Piauí',
#     'nativeName': 'Piauí',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/33/Bandeira_do_Piauí.svg'},
#    'BR-RJ': {'name': 'Rio de Janeiro',
#     'nativeName': 'Rio de Janeiro',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/73/Bandeira_do_estado_do_Rio_de_Janeiro.svg'},
#    'BR-RN': {'name': 'Rio Grande do Norte',
#     'nativeName': 'Rio Grande do Norte',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/30/Bandeira_do_Rio_Grande_do_Norte.svg'},
#    'BR-RS': {'name': 'Rio Grande do Sul',
#     'nativeName': 'Rio Grande do Sul',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/63/Bandeira_do_Rio_Grande_do_Sul.svg'},
#    'BR-RO': {'name': 'Rondônia',
#     'nativeName': 'Rondônia',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/fa/Bandeira_de_Rondônia.svg'},
#    'BR-RR': {'name': 'Roraima',
#     'nativeName': 'Roraima',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/98/Bandeira_de_Roraima.svg'},
#    'BR-SC': {'name': 'Santa Catarina',
#     'nativeName': 'Santa Catarina',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/1a/Bandeira_de_Santa_Catarina.svg'},
#    'BR-SP': {'name': 'São Paulo',
#     'nativeName': 'São Paulo',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/2b/Bandeira_do_estado_de_São_Paulo.svg'},
#    'BR-SE': {'name': 'Sergipe',
#     'nativeName': 'Sergipe',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/be/Bandeira_de_Sergipe.svg'},
#    'BR-TO': {'name': 'Tocantins',
#     'nativeName': 'Tocantins',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/ff/Bandeira_do_Tocantins.svg'},
#    'BR-DF': {'name': 'Federal District',
#     'nativeName': 'Distrito Federal',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/3c/Bandeira_do_Distrito_Federal_(Brasil).svg'}}},
#  'CA': {'name': 'Canada',
#   'nativeName': 'Canada',
#   'regions': {'CA-AB': {'name': 'Alberta',
#     'nativeName': 'Alberta',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f5/Flag_of_Alberta.svg'},
#    'CA-BC': {'name': 'British Columbia',
#     'nativeName': 'British Columbia',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b8/Flag_of_British_Columbia.svg'},
#    'CA-MB': {'name': 'Manitoba',
#     'nativeName': 'Manitoba',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c4/Flag_of_Manitoba.svg'},
#    'CA-NB': {'name': 'New Brunswick',
#     'nativeName': 'New Brunswick / Nouveau-Brunswick',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/fb/Flag_of_New_Brunswick.svg'},
#    'CA-NL': {'name': 'Newfoundland and Labrador',
#     'nativeName': 'Newfoundland and Labrador',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/dd/Flag_of_Newfoundland_and_Labrador.svg'},
#    'CA-NS': {'name': 'Nova Scotia',
#     'nativeName': 'Nova Scotia',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c0/Flag_of_Nova_Scotia.svg'},
#    'CA-ON': {'name': 'Ontario',
#     'nativeName': 'Ontario',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/88/Flag_of_Ontario.svg'},
#    'CA-PE': {'name': 'Prince Edward Island',
#     'nativeName': 'Prince Edward Island',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d7/Flag_of_Prince_Edward_Island.svg'},
#    'CA-QC': {'name': 'Quebec',
#     'nativeName': 'Québec',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/5f/Flag_of_Quebec.svg'},
#    'CA-SK': {'name': 'Saskatchewan',
#     'nativeName': 'Saskatchewan',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/bb/Flag_of_Saskatchewan.svg'},
#    'CA-NT': {'name': 'Northwest Territories',
#     'nativeName': 'Northwest Territories',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Flag_of_the_Northwest_Territories.svg'},
#    'CA-NU': {'name': 'Nunavut',
#     'nativeName': 'ᓄᓇᕗᑦ Nunavut',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/90/Flag_of_Nunavut.svg'},
#    'CA-YT': {'name': 'Yukon',
#     'nativeName': 'Yukon',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/69/Flag_of_Yukon.svg'}}},
#  'CL': {'name': 'Chile',
#   'nativeName': 'Chile',
#   'regions': {'CL-AN': {'name': 'Antofagasta Region',
#     'nativeName': 'Región de Antofagasta',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/cc/Flag_of_Antofagasta_Region,_Chile.svg'},
#    'CL-AR': {'name': 'Araucanía Region',
#     'nativeName': 'Región de la Araucanía',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/fd/Flag_of_La_Araucanía_Region.svg'},
#    'CL-AT': {'name': 'Atacama Region',
#     'nativeName': 'Región de Atacama',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/38/Flag_of_Atacama,_Chile.svg'},
#    'CL-AI': {'name': 'Aysén Region',
#     'nativeName': 'Región Aysén del General Carlos Ibáñez del Campo',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/0d/Flag_of_Aysen,_Chile.svg'},
#    'CL-BI': {'name': 'Biobío Region',
#     'nativeName': 'Región del Biobío',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/cd/Flag_of_Biobío_Region,_Chile.svg'},
#    'CL-CO': {'name': 'Coquimbo Region',
#     'nativeName': 'Región de Coquimbo',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d7/Flag_of_Coquimbo_Region,_Chile.svg'},
#    'CL-LL': {'name': 'Los Lagos Region',
#     'nativeName': 'Región de Los Lagos',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/16/Flag_of_Los_Lagos_Region,_Chile.svg'},
#    'CL-LR': {'name': 'Los Ríos Region',
#     'nativeName': 'Región de Los Ríos',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/ac/Flag_of_Los_Ríos,_Chile.svg'},
#    'CL-ML': {'name': 'Maule Region',
#     'nativeName': 'Región del Maule',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/6a/Flag_of_Maule,_Chile.svg'},
#    'CL-RM': {'name': 'Santiago Metropolitan Region',
#     'nativeName': 'Región Metropolitana de Santiago',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/8d/Flag_of_the_Metropolitan_Region,_Chile.svg'},
#    'CL-NB': {'name': 'Ñuble Region',
#     'nativeName': 'Región de Ñuble',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/30/Flag_of_Ñuble_Region,_Chile.svg'},
#    'CL-LI': {'name': "O'Higgins Region",
#     'nativeName': "Región del Libertador General Bernardo O'Higgins",
#     'flag': "https://upload.wikimedia.org/wikipedia/commons/2/26/Flag_of_O'Higgins_Region,_Chile.svg"},
#    'CL-TA': {'name': 'Tarapacá Region',
#     'nativeName': 'Región de Tarapacá',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/87/Flag_of_Tarapaca,_Chile.svg'},
#    'CL-VS': {'name': 'Valparaíso Region',
#     'nativeName': 'Región de Valparaíso',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/50/Flag_of_Valparaiso_Region,_Chile.svg'},
#    'CL-AP': {'name': 'Arica and Parinacota Region',
#     'nativeName': 'Región de Arica y Parinacota',
#     'flag': ''},
#    'CL-MA': {'name': 'Region of Magallanes and Chilean Antarctica',
#     'nativeName': 'Región de Magallanes y de la Antártica Chilena',
#     'flag': ''}}},
#  'CN': {'name': 'China',
#   'nativeName': 'Zhōngguó 中国',
#   'regions': {'CN-AH': {'name': 'Anhui', 'nativeName': '安徽省', 'flag': ''},
#    'CN-BJ': {'name': 'Beijing', 'nativeName': '北京市', 'flag': ''},
#    'CN-CQ': {'name': 'Chongqing', 'nativeName': '重庆市', 'flag': ''},
#    'CN-FJ': {'name': 'Fujian', 'nativeName': '福建省', 'flag': ''},
#    'CN-GS': {'name': 'Gansu', 'nativeName': '甘肃省', 'flag': ''},
#    'CN-GD': {'name': 'Guangdong Province', 'nativeName': '广东省', 'flag': ''},
#    'CN-GX': {'name': 'Guangxi', 'nativeName': '广西壮族自治区', 'flag': ''},
#    'CN-GZ': {'name': 'Guizhou', 'nativeName': '贵州省', 'flag': ''},
#    'CN-HI': {'name': 'Hainan Province', 'nativeName': '海南省', 'flag': ''},
#    'CN-HE': {'name': 'Hebei', 'nativeName': '河北省', 'flag': ''},
#    'CN-HL': {'name': 'Heilongjiang', 'nativeName': '黑龙江省', 'flag': ''},
#    'CN-HA': {'name': 'Henan', 'nativeName': '河南省', 'flag': ''},
#    'CN-HB': {'name': 'Hubei', 'nativeName': '湖北省', 'flag': ''},
#    'CN-HN': {'name': 'Hunan', 'nativeName': '湖南省', 'flag': ''},
#    'CN-NM': {'name': 'Inner Mongolia',
#     'nativeName': '内蒙古自治区 ᠦᠪᠦᠷ ᠮᠣᠩᠭᠤᠯ ᠤᠨ ᠥᠪᠡᠷᠲᠡᠭᠡᠨ ᠵᠠᠰᠠᠬᠣ ᠣᠷᠣᠨ',
#     'flag': ''},
#    'CN-JS': {'name': 'Jiangsu', 'nativeName': '江苏省', 'flag': ''},
#    'CN-JX': {'name': 'Jiangxi', 'nativeName': '江西省', 'flag': ''},
#    'CN-JL': {'name': 'Jilin', 'nativeName': '吉林省', 'flag': ''},
#    'CN-LN': {'name': 'Liaoning', 'nativeName': '辽宁省', 'flag': ''},
#    'CN-NX': {'name': 'Ningxia', 'nativeName': '宁夏回族自治区', 'flag': ''},
#    'CN-QH': {'name': 'Qinghai', 'nativeName': '青海省', 'flag': ''},
#    'CN-SN': {'name': 'Shaanxi', 'nativeName': '陕西省', 'flag': ''},
#    'CN-SD': {'name': 'Shandong', 'nativeName': '山东省', 'flag': ''},
#    'CN-SH': {'name': 'Shanghai', 'nativeName': '上海市', 'flag': ''},
#    'CN-SX': {'name': 'Shanxi', 'nativeName': '山西省', 'flag': ''},
#    'CN-SC': {'name': 'Sichuan', 'nativeName': '四川省', 'flag': ''},
#    'CN-TJ': {'name': 'Tianjin', 'nativeName': '天津市', 'flag': ''},
#    'CN-XZ': {'name': 'Tibet',
#     'nativeName': '西藏自治区 བོད་རང་སྐྱོང་ལྗོངས།',
#     'flag': ''},
#    'CN-XJ': {'name': 'Xinjiang',
#     'nativeName': '新疆维吾尔自治区 شىنجاڭ ئۇيغۇر ئاپتونوم رايونی',
#     'flag': ''},
#    'CN-YN': {'name': 'Yunnan', 'nativeName': '云南省', 'flag': ''},
#    'CN-ZJ': {'name': 'Zhejiang', 'nativeName': '浙江省', 'flag': ''}}},
#  'CO': {'name': 'Colombia',
#   'nativeName': 'Colombia',
#   'regions': {'CO-DC': {'name': 'Bogotá',
#     'nativeName': 'Bogotá, Distrito Capital',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/9e/Flag_of_Bogotá.svg'},
#    'CO-AMA': {'name': 'Amazonas', 'nativeName': 'Amazonas', 'flag': ''},
#    'CO-ANT': {'name': 'Antioquia', 'nativeName': 'Antioquia', 'flag': ''},
#    'CO-ARA': {'name': 'Arauca', 'nativeName': 'Arauca', 'flag': ''},
#    'CO-ATL': {'name': 'Atlántico', 'nativeName': 'Atlántico', 'flag': ''},
#    'CO-BOL': {'name': 'Bolívar', 'nativeName': 'Bolívar', 'flag': ''},
#    'CO-BOY': {'name': 'Boyacá', 'nativeName': 'Boyacá', 'flag': ''},
#    'CO-CAL': {'name': 'Caldas', 'nativeName': 'Caldas', 'flag': ''},
#    'CO-CAQ': {'name': 'Caquetá', 'nativeName': 'Caquetá', 'flag': ''},
#    'CO-CAS': {'name': 'Casanare', 'nativeName': 'Casanare', 'flag': ''},
#    'CO-CAU': {'name': 'Cauca', 'nativeName': 'Cauca', 'flag': ''},
#    'CO-CES': {'name': 'Cesar', 'nativeName': 'Cesar', 'flag': ''},
#    'CO-CHO': {'name': 'Chocó', 'nativeName': 'Chocó', 'flag': ''},
#    'CO-COR': {'name': 'Córdoba', 'nativeName': 'Córdoba', 'flag': ''},
#    'CO-CUN': {'name': 'Cundinamarca',
#     'nativeName': 'Cundinamarca',
#     'flag': ''},
#    'CO-GUA': {'name': 'Guainía', 'nativeName': 'Guainía', 'flag': ''},
#    'CO-GUV': {'name': 'Guaviare', 'nativeName': 'Guaviare', 'flag': ''},
#    'CO-HUI': {'name': 'Huila', 'nativeName': 'Huila', 'flag': ''},
#    'CO-LAG': {'name': 'La Guajira', 'nativeName': 'La Guajira', 'flag': ''},
#    'CO-MAG': {'name': 'Magdalena', 'nativeName': 'Magdalena', 'flag': ''},
#    'CO-MET': {'name': 'Meta', 'nativeName': 'Meta', 'flag': ''},
#    'CO-NAR': {'name': 'Nariño', 'nativeName': 'Nariño', 'flag': ''},
#    'CO-NSA': {'name': 'Norte de Santander',
#     'nativeName': 'Norte de Santander',
#     'flag': ''},
#    'CO-PUT': {'name': 'Putumayo', 'nativeName': 'Putumayo', 'flag': ''},
#    'CO-QUI': {'name': 'Quindío', 'nativeName': 'Quindío', 'flag': ''},
#    'CO-RIS': {'name': 'Risaralda', 'nativeName': 'Risaralda', 'flag': ''},
#    'CO-SAN': {'name': 'Santander', 'nativeName': 'Santander', 'flag': ''},
#    'CO-SAP': {'name': 'San Andrés and Providencia',
#     'nativeName': 'Archipelago of Saint Andrew, Providence and Saint Catherine',
#     'flag': ''},
#    'CO-SUC': {'name': 'Sucre', 'nativeName': 'Sucre', 'flag': ''},
#    'CO-TOL': {'name': 'Tolima', 'nativeName': 'Tolima', 'flag': ''},
#    'CO-VAC': {'name': 'Valle del Cauca',
#     'nativeName': 'Valle del Cauca',
#     'flag': ''},
#    'CO-VAU': {'name': 'Vaupés', 'nativeName': 'Vaupés', 'flag': ''},
#    'CO-VID': {'name': 'Vichada', 'nativeName': 'Vichada', 'flag': ''}}},
#  'CZ': {'name': 'Czech Republic',
#   'regions': {'CZ-53': {'name': 'Pardubice',
#     'nativeName': 'Pardubický kraj',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c7/Flag_of_Pardubice_Region.svg'},
#    'CZ-10': {'name': 'Prague',
#     'nativeName': 'Hlavní město Praha',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d2/Flag_of_Prague.svg'},
#    'CZ-63': {'name': 'Vysočina',
#     'nativeName': 'Kraj Vysočina',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/14/Flag_of_Vysocina_Region.svg'},
#    'CZ-72': {'name': 'Zlín',
#     'nativeName': 'Zlínský kraj',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/84/Flag_of_Zlin_Region.svg'},
#    'CZ-31': {'name': 'South Bohemia',
#     'nativeName': 'Jihočeský kraj',
#     'flag': ''},
#    'CZ-64': {'name': 'South Moravia',
#     'nativeName': 'Jihomoravský kraj',
#     'flag': ''},
#    'CZ-41': {'name': 'Karlovy Vary',
#     'nativeName': 'Karlovarský kraj',
#     'flag': ''},
#    'CZ-52': {'name': 'Hradec Králové',
#     'nativeName': 'Královéhradecký kraj',
#     'flag': ''},
#    'CZ-51': {'name': 'Liberec', 'nativeName': 'Liberecký kraj', 'flag': ''},
#    'CZ-80': {'name': 'Moravia-Silesia',
#     'nativeName': 'Moravskoslezský kraj',
#     'flag': ''},
#    'CZ-71': {'name': 'Olomouc', 'nativeName': 'Olomoucký kraj', 'flag': ''},
#    'CZ-32': {'name': 'Plzeň', 'nativeName': 'Plzeňský kraj', 'flag': ''},
#    'CZ-20': {'name': 'Central Bohemia',
#     'nativeName': 'Středočeský kraj',
#     'flag': ''},
#    'CZ-42': {'name': 'Ústí nad Labem',
#     'nativeName': 'Ústecký kraj',
#     'flag': ''}}},
#  'FI': {'name': 'Finland',
#   'nativeName': 'Suomi',
#   'regions': {'FI-01': {'name': 'Åland',
#     'nativeName': 'Landskapet Åland',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/52/Flag_of_Åland.svg'},
#    'FI-08': {'name': 'Central Finland',
#     'nativeName': 'Keski-Suomi',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/9a/Keski-suomi_lippu.svg'},
#    'FI-07': {'name': 'Central Ostrobothnia',
#     'nativeName': 'Keski-Pohjanmaa',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/64/Keski-Pohjanmaa.lippu.svg'},
#    'FI-05': {'name': 'Kainuu',
#     'nativeName': 'Kainuu',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/5d/Flag_of_Kainuu.svg'},
#    'FI-06': {'name': 'Kanta-Häme',
#     'nativeName': 'Kanta-Häme',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/bd/Flag_of_Tavastia_Proper.svg'},
#    'FI-13': {'name': 'North Karelia',
#     'nativeName': 'Pohjois-Karjala',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/e0/North_karelia_flag.svg'},
#    'FI-15': {'name': 'North Savo',
#     'nativeName': 'Pohjois-Savo',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/85/Flag_of_Northern_Savonia.svg'},
#    'FI-16': {'name': 'Päijät-Häme',
#     'nativeName': 'Päijät-Häme',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/18/Päijät-Häme.lippu.svg'},
#    'FI-17': {'name': 'Satakunta',
#     'nativeName': 'Satakunta',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/78/Satakunta-flag.svg'},
#    'FI-03': {'name': 'South Ostrobothnia',
#     'nativeName': 'Etelä-Pohjanmaa',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/30/Flag_of_Southern_Ostrobothnia.svg'},
#    'FI-04': {'name': 'South Savo',
#     'nativeName': 'Etelä-Savo',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b1/Flag_of_South_Savonia.svg'},
#    'FI-18': {'name': 'Uusimaa',
#     'nativeName': 'Uusimaa',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c8/Flag_of_Uusimaa.svg'},
#    'FI-02': {'name': 'South Karelia',
#     'nativeName': 'Etelä-Karjala',
#     'flag': ''},
#    'FI-09': {'name': 'Kymenlaakso', 'nativeName': 'Kymenlaakso', 'flag': ''},
#    'FI-10': {'name': 'Lapland', 'nativeName': 'Lappi', 'flag': ''},
#    'FI-11': {'name': 'Pirkanmaa', 'nativeName': 'Pirkanmaa', 'flag': ''},
#    'FI-12': {'name': 'Ostrobothnia', 'nativeName': 'Österbotten', 'flag': ''},
#    'FI-14': {'name': 'North Ostrobothnia',
#     'nativeName': 'Pohjois-Pohjanmaa',
#     'flag': ''},
#    'FI-19': {'name': 'Southwest Finland',
#     'nativeName': 'Varsinais-Suomi',
#     'flag': ''}}},
#  'FR': {'name': 'France',
#   'nativeName': 'France',
#   'regions': {'FR-ARA': {'name': 'Auvergne-Rhône-Alpes',
#     'nativeName': 'Auvergne-Rhône-Alpes',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/85/Flag_of_the_region_Auvergne-Rhône-Alpes.svg'},
#    'FR-BFC': {'name': 'Bourgogne-Franche-Comté',
#     'nativeName': 'Bourgogne-Franche-Comté',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/28/Flag_of_the_region_Bourgogne-Franche-Comté.svg'},
#    'FR-BRE': {'name': 'Brittany',
#     'nativeName': 'Bretagne',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/29/Flag_of_Brittany_(Gwenn_ha_du).svg'},
#    'FR-CVL': {'name': 'Centre-Val de Loire',
#     'nativeName': 'Centre-Val de Loire',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d5/Flag_of_Centre-Val_de_Loire.svg'},
#    'FR-20R': {'name': 'Corsica',
#     'nativeName': 'Corse',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/7c/Flag_of_Corsica.svg'},
#    'FR-GES': {'name': 'Grand Est',
#     'nativeName': 'Grand Est',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/39/Flag_of_the_Region_of_Grand_Est_(Variant_1).svg'},
#    'FR-HDF': {'name': 'Hauts-de-France',
#     'nativeName': 'Hauts-de-France',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c9/Flag_of_the_Region_of_Hauts-de-France.svg'},
#    'FR-IDF': {'name': 'Île-de-France',
#     'nativeName': 'Île-de-France',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/ab/IDF_flag.svg'},
#    'FR-NOR': {'name': 'Normandy',
#     'nativeName': 'Normandie',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/41/Flag_of_Normandie.svg'},
#    'FR-NAQ': {'name': 'Nouvelle-Aquitaine',
#     'nativeName': 'Nouvelle-Aquitaine',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b6/Flag_of_Nouvelle-Aquitaine.svg'},
#    'FR-OCC': {'name': 'Occitania',
#     'nativeName': 'Occitanie',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/1d/Flag_of_Région_Occitanie_(symbol_only).svg'},
#    'FR-PDL': {'name': 'Pays de la Loire',
#     'nativeName': 'Pays de la Loire',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/65/Unofficial_flag_of_Pays-de-la-Loire.svg'},
#    'FR-PAC': {'name': "Provence-Alpes-Côte d'Azur",
#     'nativeName': "Provence-Alpes-Côte d'Azur",
#     'flag': "https://upload.wikimedia.org/wikipedia/commons/9/94/Flag_of_Provence-Alpes-Côte_d'Azur.svg"}}},
#  'DE': {'name': 'Germany',
#   'nativeName': 'Deutschland',
#   'regions': {'DE-BW': {'name': 'Baden-Württemberg',
#     'nativeName': 'Baden-Württemberg',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/5c/Flag_of_Baden-Württemberg.svg'},
#    'DE-BE': {'name': 'Berlin',
#     'nativeName': 'Berlin',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/ec/Flag_of_Berlin.svg'},
#    'DE-BB': {'name': 'Brandenburg',
#     'nativeName': 'Brandenburg',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/01/Flag_of_Brandenburg.svg'},
#    'DE-HB': {'name': 'Bremen',
#     'nativeName': 'Bremen',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/0e/Flag_of_Bremen.svg'},
#    'DE-HH': {'name': 'Hamburg',
#     'nativeName': 'Hamburg',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/74/Flag_of_Hamburg.svg'},
#    'DE-HE': {'name': 'Hesse',
#     'nativeName': 'Hessen',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f7/Flag_of_Hesse.svg'},
#    'DE-NI': {'name': 'Lower Saxony',
#     'nativeName': 'Niedersachsen',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/81/Flag_of_Lower_Saxony.svg'},
#    'DE-MV': {'name': 'Mecklenburg-Vorpommern',
#     'nativeName': 'Mecklenburg-Vorpommern',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/ce/Flag_of_Mecklenburg-Western_Pomerania.svg'},
#    'DE-NW': {'name': 'North Rhine-Westphalia',
#     'nativeName': 'Nordrhein-Westfalen',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/84/Flag_of_North_Rhine-Westphalia.svg'},
#    'DE-RP': {'name': 'Rhineland-Palatinate',
#     'nativeName': 'Rheinland-Pfalz',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b7/Flag_of_Rhineland-Palatinate.svg'},
#    'DE-SL': {'name': 'Saarland',
#     'nativeName': 'Saarland',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f7/Flag_of_Saarland.svg'},
#    'DE-SN': {'name': 'Saxony',
#     'nativeName': 'Sachsen',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/fd/Flag_of_Saxony.svg'},
#    'DE-ST': {'name': 'Saxony-Anhalt',
#     'nativeName': 'Sachsen-Anhalt',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c2/Flag_of_Saxony-Anhalt_(state).svg'},
#    'DE-SH': {'name': 'Schleswig-Holstein',
#     'nativeName': 'Schleswig-Holstein',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b4/Flag_of_Schleswig-Holstein.svg'},
#    'DE-TH': {'name': 'Thuringia',
#     'nativeName': 'Thüringen',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/bd/Flag_of_Thuringia.svg'},
#    'DE-BY': {'name': 'Bavaria', 'nativeName': 'Bayern', 'flag': ''}}},
#  'HU': {'name': 'Hungary',
#   'nativeName': 'Magyarország',
#   'regions': {'HU-BU': {'name': 'Budapest',
#     'nativeName': 'Budapest',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d5/Flag_of_Budapest_(2011-).svg'},
#    'HU-BA': {'name': 'Baranya', 'nativeName': 'Baranya vármegye', 'flag': ''},
#    'HU-BZ': {'name': 'Borsod-Abaúj-Zemplén',
#     'nativeName': 'Borsod-Abaúj-Zemplén vármegye',
#     'flag': ''},
#    'HU-BK': {'name': 'Bács-Kiskun',
#     'nativeName': 'Bács-Kiskun vármegye',
#     'flag': ''},
#    'HU-BE': {'name': 'Békés', 'nativeName': 'Békés vármegye', 'flag': ''},
#    'HU-CS': {'name': 'Csongrád-Csanád',
#     'nativeName': 'Csongrád-Csanád vármegye',
#     'flag': ''},
#    'HU-FE': {'name': 'Fejér', 'nativeName': 'Fejér vármegye', 'flag': ''},
#    'HU-GS': {'name': 'Győr-Moson-Sopron',
#     'nativeName': 'Győr-Moson-Sopron vármegye',
#     'flag': ''},
#    'HU-HB': {'name': 'Hajdú-Bihar',
#     'nativeName': 'Hajdú-Bihar vármegye',
#     'flag': ''},
#    'HU-HE': {'name': 'Heves', 'nativeName': 'Heves vármegye', 'flag': ''},
#    'HU-JN': {'name': 'Jász-Nagykun-Szolnok',
#     'nativeName': 'Jász-Nagykun-Szolnok vármegye',
#     'flag': ''},
#    'HU-KE': {'name': 'Komárom-Esztergom',
#     'nativeName': 'Komárom-Esztergom vármegye',
#     'flag': ''},
#    'HU-NO': {'name': 'Nógrád', 'nativeName': 'Nógrád vármegye', 'flag': ''},
#    'HU-PE': {'name': 'Pest', 'nativeName': 'Pest vármegye', 'flag': ''},
#    'HU-SO': {'name': 'Somogy', 'nativeName': 'Somogy vármegye', 'flag': ''},
#    'HU-SZ': {'name': 'Szabolcs-Szatmár-Bereg',
#     'nativeName': 'Szabolcs-Szatmár-Bereg vármegye',
#     'flag': ''},
#    'HU-TO': {'name': 'Tolna', 'nativeName': 'Tolna vármegye', 'flag': ''},
#    'HU-VA': {'name': 'Vas', 'nativeName': 'Vas vármegye', 'flag': ''},
#    'HU-VE': {'name': 'Veszprém',
#     'nativeName': 'Veszprém vármegye',
#     'flag': ''},
#    'HU-ZA': {'name': 'Zala', 'nativeName': 'Zala vármegye', 'flag': ''}}},
#  'ID': {'name': 'Indonesia',
#   'nativeName': 'Indonesia',
#   'regions': {'ID-AC': {'name': 'Aceh',
#     'nativeName': 'Aceh',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/36/Flag_of_Aceh,_Indonesia.svg'},
#    'ID-BA': {'name': 'Bali',
#     'nativeName': 'Bali',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/a3/Flag_of_Bali.svg'},
#    'ID-BB': {'name': 'Bangka Belitung Islands',
#     'nativeName': 'Kepulauan Bangka Belitung',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/1d/Flag_of_Bangka-Belitung.svg'},
#    'ID-BT': {'name': 'Banten',
#     'nativeName': 'Banten',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/88/Flag_of_Banten,_Indonesia.svg'},
#    'ID-BE': {'name': 'Bengkulu',
#     'nativeName': 'Bengkulu',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/ec/Flag_of_Bengkulu.svg'},
#    'ID-JT': {'name': 'Central Java',
#     'nativeName': 'Jawa Tengah',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/2d/Flag_of_Central_Java.svg'},
#    'ID-KT': {'name': 'Central Kalimantan',
#     'nativeName': 'Kalimantan Tengah',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/9c/Flag_of_Central_Kalimantan.svg'},
#    'ID-ST': {'name': 'Central Sulawesi',
#     'nativeName': 'Sulawesi Tengah',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f1/Flag_of_Central_Sulawesi.svg'},
#    'ID-JI': {'name': 'East Java',
#     'nativeName': 'Jawa Timur',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/3d/Flag_of_East_Java.svg'},
#    'ID-KI': {'name': 'East Kalimantan',
#     'nativeName': 'Kalimantan Timur',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/88/Flag_of_East_Kalimantan.svg'},
#    'ID-NT': {'name': 'East Nusa Tenggara',
#     'nativeName': 'Nusa Tenggara Timur',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/57/Flag_of_East_Nusa_Tenggara.svg'},
#    'ID-GO': {'name': 'Gorontalo',
#     'nativeName': 'Gorontalo',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/8f/Flag_of_Gorontalo.svg'},
#    'ID-PE': {'name': 'Highland Papua',
#     'nativeName': 'Papua Pegunungan',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Flag_of_Highland_Papua_Province.png/143px-Flag_of_Highland_Papua_Province.png'},
#    'ID-JA': {'name': 'Jambi',
#     'nativeName': 'Jambi',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/8d/Flag_of_Jambi.svg'},
#    'ID-LA': {'name': 'Lampung',
#     'nativeName': 'Lampung',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/09/Flag_of_Lampung.svg'},
#    'ID-KU': {'name': 'North Kalimantan',
#     'nativeName': 'Kalimantan Utara',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4b/Flag_of_North_Kalimantan.svg'},
#    'ID-MU': {'name': 'North Maluku',
#     'nativeName': 'Maluku Utara',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f2/Flag_of_North_Maluku.svg'},
#    'ID-SA': {'name': 'North Sulawesi',
#     'nativeName': 'Sulawesi Utara',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/ba/Flag_of_North_Sulawesi.svg'},
#    'ID-SU': {'name': 'North Sumatra',
#     'nativeName': 'Sumatera Utara',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f3/Flag_of_North_Sumatra.svg'},
#    'ID-PA': {'name': 'Papua',
#     'nativeName': 'Papua',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/ec/Flag_of_Papua_2.svg'},
#    'ID-RI': {'name': 'Riau',
#     'nativeName': 'Riau',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/a8/Flag_of_Riau.svg'},
#    'ID-KR': {'name': 'Riau Islands',
#     'nativeName': 'Kepulauan Riau',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/aa/Flag_of_Riau_Islands.svg'},
#    'ID-SG': {'name': 'Southeast Sulawesi',
#     'nativeName': 'Sulawesi Tenggara',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/ac/Flag_of_Southeast_Sulawesi.svg'},
#    'ID-KS': {'name': 'South Kalimantan',
#     'nativeName': 'Kalimantan Selatan',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/31/Flag_of_South_Kalimantan.svg'},
#    'ID-SN': {'name': 'South Sulawesi',
#     'nativeName': 'Sulawesi Selatan',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/8d/Flag_of_South_Sulawesi.svg'},
#    'ID-SS': {'name': 'South Sumatra',
#     'nativeName': 'Sumatera Selatan',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/ab/Flag_of_South_Sumatra_(vectorised).svg'},
#    'ID-JB': {'name': 'West Java',
#     'nativeName': 'Jawa Barat',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/41/Flag_of_West_Java_(vectorised).svg'},
#    'ID-KB': {'name': 'West Kalimantan',
#     'nativeName': 'Kalimantan Barat',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/8b/Flag_of_West_Kalimantan.svg'},
#    'ID-NB': {'name': 'West Nusa Tenggara',
#     'nativeName': 'Nusa Tenggara Barat',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/1f/Flag_of_West_Nusa_Tenggara.svg'},
#    'ID-PB': {'name': 'West Papua',
#     'nativeName': 'Papua Barat',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/01/Flag_of_West_Papua_(vectorised).svg'},
#    'ID-SR': {'name': 'West Sulawesi',
#     'nativeName': 'Sulawesi Barat',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/95/Flag_of_West_Sulawesi.svg'},
#    'ID-SB': {'name': 'West Sumatra',
#     'nativeName': 'Sumatera Barat',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/64/Flag_of_West_Sumatra.svg'},
#    'ID-YO': {'name': 'Special Region of Yogyakarta',
#     'nativeName': 'Daerah Istimewa Yogyakarta',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/70/Flag_of_Yogyakarta.svg'},
#    'ID-JK': {'name': 'Jakarta',
#     'nativeName': 'Daerah Khusus Ibukota Jakarta',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/8e/Flag_of_Jakarta_(vectorised).svg'},
#    'ID-PT': {'name': 'Central Papua',
#     'nativeName': 'Papua Tengah',
#     'flag': ''},
#    'ID-MA': {'name': 'Maluku Islands', 'nativeName': 'Maluku', 'flag': ''},
#    'ID-PS': {'name': 'South Papua', 'nativeName': 'Papua Selatan', 'flag': ''},
#    'ID-PSW': {'name': 'Southwest Papua',
#     'nativeName': 'Papua Barat Daya',
#     'flag': ''}}},
#  'IT': {'name': 'Italy',
#   'nativeName': 'Italia',
#   'regions': {'IT-23': {'name': 'Aosta Valley',
#     'nativeName': "Valle d'Aosta / Vallée d'Aoste",
#     'flag': "https://upload.wikimedia.org/wikipedia/commons/9/90/Flag_of_Valle_d'Aosta.svg"},
#    'IT-36': {'name': 'Friuli Venezia Giulia',
#     'nativeName': 'Friuli-Venezia Giulia',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/55/Flag_of_Friuli-Venezia_Giulia.svg'},
#    'IT-88': {'name': 'Sardinia',
#     'nativeName': 'Sardigna/Sardegna',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4e/Flag_of_Sardinia,_Italy.svg'},
#    'IT-82': {'name': 'Sicily',
#     'nativeName': 'Sicilia',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/84/Sicilian_Flag.svg'},
#    'IT-32': {'name': 'Trentino-Alto Adige/Südtirol',
#     'nativeName': 'Trentino-Alto Adige/Südtirol',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/7f/Flag_of_Trentino-South_Tyrol.svg'},
#    'IT-65': {'name': 'Abruzzo',
#     'nativeName': 'Abruzzo',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/45/Flag_of_Abruzzo.svg'},
#    'IT-75': {'name': 'Apulia',
#     'nativeName': 'Puglia',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b8/Flag_of_Apulia.svg'},
#    'IT-77': {'name': 'Basilicata',
#     'nativeName': 'Basilicata',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/8e/Flag_of_Basilicata.svg'},
#    'IT-78': {'name': 'Calabria',
#     'nativeName': 'Calabria',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/8b/Flag_of_Calabria.svg'},
#    'IT-72': {'name': 'Campania',
#     'nativeName': 'Campania',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c5/Flag_of_Campania.svg'},
#    'IT-45': {'name': 'Emilia-Romagna',
#     'nativeName': 'Emilia-Romagna',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/77/Flag_of_Emilia-Romagna_(de_facto).svg'},
#    'IT-62': {'name': 'Lazio',
#     'nativeName': 'Lazio',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/e1/Flag_of_Lazio.svg'},
#    'IT-42': {'name': 'Liguria',
#     'nativeName': 'Liguria',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/88/Flag_of_Liguria.svg'},
#    'IT-25': {'name': 'Lombardy',
#     'nativeName': 'Lombardia',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/ea/Flag_of_Lombardy.svg'},
#    'IT-57': {'name': 'Marche',
#     'nativeName': 'Marche',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/07/Flag_of_Marche.svg'},
#    'IT-67': {'name': 'Molise',
#     'nativeName': 'Molise',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/84/Flag_of_Molise.svg'},
#    'IT-21': {'name': 'Piedmont',
#     'nativeName': 'Piemonte',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b9/Flag_of_Piedmont.svg'},
#    'IT-52': {'name': 'Tuscany',
#     'nativeName': 'Toscana',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f2/Flag_of_Tuscany.svg'},
#    'IT-55': {'name': 'Umbria',
#     'nativeName': 'Umbria',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/cc/Flag_of_Umbria.svg'},
#    'IT-34': {'name': 'Veneto',
#     'nativeName': 'Veneto',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d5/Flag_of_Veneto.svg'}}},
#  'JP': {'name': 'Japan',
#   'nativeName': 'Nippon 日本',
#   'regions': {'JP-23': {'name': 'Aichi Prefecture',
#     'nativeName': '愛知県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/02/Flag_of_Aichi_Prefecture.svg'},
#    'JP-05': {'name': 'Akita Prefecture',
#     'nativeName': '秋田県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/84/Flag_of_Akita_Prefecture.svg'},
#    'JP-02': {'name': 'Aomori Prefecture',
#     'nativeName': '青森県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/30/Flag_of_Aomori_Prefecture.svg'},
#    'JP-12': {'name': 'Chiba Prefecture',
#     'nativeName': '千葉県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/0a/Flag_of_Chiba_Prefecture.svg'},
#    'JP-38': {'name': 'Ehime Prefecture',
#     'nativeName': '愛媛県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/2d/Flag_of_Ehime_Prefecture.svg'},
#    'JP-18': {'name': 'Fukui Prefecture',
#     'nativeName': '福井県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/56/Flag_of_Fukui_Prefecture.svg'},
#    'JP-40': {'name': 'Fukuoka Prefecture',
#     'nativeName': '福岡県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/71/Flag_of_Fukuoka_Prefecture.svg'},
#    'JP-07': {'name': 'Fukushima Prefecture',
#     'nativeName': '福島県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4b/Flag_of_Fukushima_Prefecture.svg'},
#    'JP-21': {'name': 'Gifu Prefecture',
#     'nativeName': '岐阜県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/3e/Flag_of_Gifu_Prefecture.svg'},
#    'JP-10': {'name': 'Gunma Prefecture',
#     'nativeName': '群馬県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/ba/Flag_of_Gunma_Prefecture.svg'},
#    'JP-34': {'name': 'Hiroshima Prefecture',
#     'nativeName': '広島県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/ed/Flag_of_Hiroshima_Prefecture.svg'},
#    'JP-01': {'name': 'Hokkaido',
#     'nativeName': '北海道',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/22/Flag_of_Hokkaido_Prefecture.svg'},
#    'JP-28': {'name': 'Hyōgo Prefecture',
#     'nativeName': '兵庫県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/74/Flag_of_Hyogo_Prefecture.svg'},
#    'JP-08': {'name': 'Ibaraki Prefecture',
#     'nativeName': '茨城県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/a8/Flag_of_Ibaraki_Prefecture.svg'},
#    'JP-17': {'name': 'Ishikawa Prefecture',
#     'nativeName': '石川県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/6a/Flag_of_Ishikawa_Prefecture.svg'},
#    'JP-03': {'name': 'Iwate Prefecture',
#     'nativeName': '岩手県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/a9/Flag_of_Iwate_Prefecture.svg'},
#    'JP-37': {'name': 'Kagawa Prefecture',
#     'nativeName': '香川県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/29/Flag_of_Kagawa_Prefecture.svg'},
#    'JP-46': {'name': 'Kagoshima Prefecture',
#     'nativeName': '鹿児島県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c5/Flag_of_Kagoshima_Prefecture.svg'},
#    'JP-14': {'name': 'Kanagawa Prefecture',
#     'nativeName': '神奈川県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/a7/Flag_of_Kanagawa_Prefecture.svg'},
#    'JP-39': {'name': 'Kōchi Prefecture',
#     'nativeName': '高知県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/50/Flag_of_Kochi_Prefecture.svg'},
#    'JP-43': {'name': 'Kumamoto Prefecture',
#     'nativeName': '熊本県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f7/Flag_of_Kumamoto_Prefecture.svg'},
#    'JP-26': {'name': 'Kyoto Prefecture',
#     'nativeName': '京都府',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/06/Flag_of_Kyoto_Prefecture.svg'},
#    'JP-24': {'name': 'Mie Prefecture',
#     'nativeName': '三重県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/8c/Flag_of_Mie_Prefecture.svg'},
#    'JP-04': {'name': 'Miyagi Prefecture',
#     'nativeName': '宮城県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c7/Flag_of_Miyagi_Prefecture.svg'},
#    'JP-45': {'name': 'Miyazaki Prefecture',
#     'nativeName': '宮崎県',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/0b/Flag_of_Miyazaki_Prefecture.svg'},
# ...
#    'US-MN': {'name': 'Minnesota',
#     'nativeName': 'Minnesota',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b9/Flag_of_Minnesota.svg'},
#    'US-MS': {'name': 'Mississippi',
#     'nativeName': 'Mississippi',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/42/Flag_of_Mississippi.svg'},
#    'US-MO': {'name': 'Missouri',
#     'nativeName': 'Missouri',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/5a/Flag_of_Missouri.svg'},
#    'US-MT': {'name': 'Montana',
#     'nativeName': 'Montana',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/cb/Flag_of_Montana.svg'},
#    'US-NE': {'name': 'Nebraska',
#     'nativeName': 'Nebraska',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4d/Flag_of_Nebraska.svg'},
#    'US-NV': {'name': 'Nevada',
#     'nativeName': 'Nevada',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f1/Flag_of_Nevada.svg'},
#    'US-NH': {'name': 'New Hampshire',
#     'nativeName': 'New Hampshire',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/28/Flag_of_New_Hampshire.svg'},
#    'US-NJ': {'name': 'New Jersey',
#     'nativeName': 'New Jersey',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/92/Flag_of_New_Jersey.svg'},
#    'US-NM': {'name': 'New Mexico',
#     'nativeName': 'New Mexico',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c3/Flag_of_New_Mexico.svg'},
#    'US-NY': {'name': 'New York',
#     'nativeName': 'New York',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/1a/Flag_of_New_York.svg'},
#    'US-NC': {'name': 'North Carolina',
#     'nativeName': 'North Carolina',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/bb/Flag_of_North_Carolina.svg'},
#    'US-ND': {'name': 'North Dakota',
#     'nativeName': 'North Dakota',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/ee/Flag_of_North_Dakota.svg'},
#    'US-OH': {'name': 'Ohio',
#     'nativeName': 'Ohio',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4c/Flag_of_Ohio.svg'},
#    'US-OK': {'name': 'Oklahoma',
#     'nativeName': 'Oklahoma',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/6e/Flag_of_Oklahoma.svg'},
#    'US-OR': {'name': 'Oregon',
#     'nativeName': 'Oregon',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b9/Flag_of_Oregon.svg'},
#    'US-PA': {'name': 'Pennsylvania',
#     'nativeName': 'Pennsylvania',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f7/Flag_of_Pennsylvania.svg'},
#    'US-RI': {'name': 'Rhode Island',
#     'nativeName': 'Rhode Island',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f3/Flag_of_Rhode_Island.svg'},
#    'US-SC': {'name': 'South Carolina',
#     'nativeName': 'South Carolina',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/69/Flag_of_South_Carolina.svg'},
#    'US-SD': {'name': 'South Dakota',
#     'nativeName': 'South Dakota',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/1a/Flag_of_South_Dakota.svg'},
#    'US-TN': {'name': 'Tennessee',
#     'nativeName': 'Tennessee',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/9e/Flag_of_Tennessee.svg'},
#    'US-TX': {'name': 'Texas',
#     'nativeName': 'Texas',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f7/Flag_of_Texas.svg'},
#    'US-UT': {'name': 'Utah',
#     'nativeName': 'Utah',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f6/Flag_of_Utah.svg'},
#    'US-VT': {'name': 'Vermont',
#     'nativeName': 'Vermont',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/49/Flag_of_Vermont.svg'},
#    'US-VA': {'name': 'Virginia',
#     'nativeName': 'Virginia',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/47/Flag_of_Virginia.svg'},
#    'US-WA': {'name': 'Washington',
#     'nativeName': 'Washington',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/54/Flag_of_Washington.svg'},
#    'US-WV': {'name': 'West Virginia',
#     'nativeName': 'West Virginia',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/22/Flag_of_West_Virginia.svg'},
#    'US-WI': {'name': 'Wisconsin',
#     'nativeName': 'Wisconsin',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/22/Flag_of_Wisconsin.svg'},
#    'US-WY': {'name': 'Wyoming',
#     'nativeName': 'Wyoming',
#     'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/bc/Flag_of_Wyoming.svg'},
#    'US-WADC': {'name': 'Washington, D.C.',
#     'nativeName': 'Washington',
#     'flag': ''}}},
#  'KZ': {'name': 'Kazakhstan',
#   'regions': {'KZ-10': {'name': 'Abay Region',
#     'nativeName': 'Абай облысы',
#     'flag': ''},
#    'KZ-11': {'name': 'Akmola Region',
#     'nativeName': 'Ақмола облысы',
#     'flag': ''},
#    'KZ-19': {'name': 'Almaty Region',
#     'nativeName': 'Алматы облысы',
#     'flag': ''},
#    'KZ-75': {'name': 'Almaty', 'nativeName': 'Алматы', 'flag': ''},
#    'KZ-15': {'name': 'Aqtöbe region',
#     'nativeName': 'Ақтөбе облысы',
#     'flag': ''},
#    'KZ-71': {'name': 'Astana', 'nativeName': 'Астана', 'flag': ''},
#    'KZ-23': {'name': 'Atyrau Region',
#     'nativeName': 'Атырау облысы',
#     'flag': ''},
#    'KZ-63': {'name': 'East Kazakhstan Region',
#     'nativeName': 'Шығыс Қазақстан облысы',
#     'flag': ''},
#    'KZ-31': {'name': 'Jambyl Region',
#     'nativeName': 'Жамбыл облысы',
#     'flag': ''},
#    'KZ-33': {'name': 'Jetisu Region',
#     'nativeName': 'Жетісу облысы',
#     'flag': ''},
#    'KZ-35': {'name': 'Karaganda Region',
#     'nativeName': 'Қарағанды облысы',
#     'flag': ''},
#    'KZ-39': {'name': 'Kostanay Region',
#     'nativeName': 'Қостанай облысы',
#     'flag': ''},
#    'KZ-43': {'name': 'Kyzylorda Region',
#     'nativeName': 'Қызылорда облысы',
#     'flag': ''},
#    'KZ-47': {'name': 'Mangystau Region',
#     'nativeName': 'Маңғыстау облысы',
#     'flag': ''},
#    'KZ-59': {'name': 'North Kazakhstan Region',
#     'nativeName': 'Солтүстік Қазақстан облысы',
#     'flag': ''},
#    'KZ-55': {'name': 'Pavlodar Region',
#     'nativeName': 'Павлодар облысы',
#     'flag': ''},
#    'KZ-79': {'name': 'Shymkent', 'nativeName': 'Шымкент', 'flag': ''},
#    'KZ-61': {'name': 'Turkistan Region',
#     'nativeName': 'Түркістан облысы',
#     'flag': ''},
#    'KZ-62': {'name': 'Ulytau Region',
#     'nativeName': 'Ұлытау облысы',
#     'flag': ''},
#    'KZ-27': {'name': 'West Kazakhstan Region',
#     'nativeName': 'Батыс Қазақстан облысы',
#     'flag': ''}}},
#  'SG': {'name': 'Singapore',
#   'regions': {'SG-01': {'name': 'Central Singapore',
#     'nativeName': 'Central Singapore',
#     'flag': 'https://static.wikia.nocookie.net/vexillology/images/c/c5/Flag_of_Central_Region%2C_Singapore.png/revision/latest/scale-to-width-down/150?cb=20230826215418'},
#    'SG-02': {'name': 'Northeast Singapore',
#     'nativeName': 'Northeast Singapore',
#     'flag': 'https://static.wikia.nocookie.net/vexillology/images/b/b0/Flag_of_North-East_Region%2C_Singapore.png/revision/latest/scale-to-width-down/150?cb=20230826215655'},
#    'SG-03': {'name': 'Northwest Singapore',
#     'nativeName': 'Northwest Singapore',
#     'flag': 'https://static.wikia.nocookie.net/vexillology/images/6/6e/Flag_of_North_Region%2C_Singapore.png/revision/latest/scale-to-width-down/150?cb=20230826215625'},
#    'SG-04': {'name': 'Southeast Singapore',
#     'nativeName': 'Southeast Singapore',
#     'flag': 'https://static.wikia.nocookie.net/vexillology/images/b/b1/Flag_of_East_Region%2C_Singapore.png/revision/latest/scale-to-width-down/150?cb=20230826215512'},
#    'SG-05': {'name': 'Southwest Singapore',
#     'nativeName': 'Southwest Singapore',
#     'flag': 'https://static.wikia.nocookie.net/vexillology/images/d/d9/Flag_of_West_Region%2C_Singapore.png/revision/latest/scale-to-width-down/150?cb=20230826215841'}}},
#  'TR': {'name': 'Turkey',
#   'regions': {'TR-EGE': {'name': 'Aegean Region',
#     'nativeName': 'Ege Bölgesi',
#     'flag': ''},
#    'TR-KAR': {'name': 'Black Sea Region',
#     'nativeName': 'Karadeniz Bölgesi',
#     'flag': ''},
#    'TR-ICA': {'name': 'Central Anatolia Region',
#     'nativeName': 'İç Anadolu Bölgesi',
#     'flag': ''},
#    'TR-DOA': {'name': 'Eastern Anatolia Region',
#     'nativeName': 'Doğu Anadolu Bölgesi',
#     'flag': ''},
#    'TR-MRM': {'name': 'Marmara Region',
#     'nativeName': 'Marmara Bölgesi',
#     'flag': ''},
#    'TR-AKD': {'name': 'Mediterranean Region',
#     'nativeName': 'Akdeniz Bölgesi',
#     'flag': ''},
#    'TR-GUA': {'name': 'Southeastern Anatolia Region',
#     'nativeName': 'Güneydoğu Anadolu Bölgesi',
#     'flag': ''}}},
#  'TW': {'name': 'Taiwan',
#   'regions': {'TW-CHA': {'name': 'Changhua County',
#     'nativeName': '彰化縣',
#     'flag': ''},
#    'TW-CYQ': {'name': 'Chiayi County', 'nativeName': '嘉義縣', 'flag': ''},
#    'TW-CYI': {'name': 'Chiayi', 'nativeName': '嘉義市', 'flag': ''},
#    'TW-HSQ': {'name': 'Hsinchu County', 'nativeName': '新竹縣', 'flag': ''},
#    'TW-HSZ': {'name': 'Hsinchu', 'nativeName': '新竹市', 'flag': ''},
#    'TW-HUA': {'name': 'Hualien County', 'nativeName': '花蓮縣', 'flag': ''},
#    'TW-KHH': {'name': 'Kaohsiung', 'nativeName': '高雄市', 'flag': ''},
#    'TW-KEE': {'name': 'Keelung', 'nativeName': '基隆市', 'flag': ''},
#    'TW-KIN': {'name': 'Kinmen', 'nativeName': '金門縣', 'flag': ''},
#    'TW-LIE': {'name': 'Lienchiang County', 'nativeName': '連江縣', 'flag': ''},
#    'TW-MIA': {'name': 'Miaoli County', 'nativeName': '苗栗縣', 'flag': ''},
#    'TW-NAN': {'name': 'Nantou County', 'nativeName': '南投縣', 'flag': ''},
#    'TW-NWT': {'name': 'New Taipei', 'nativeName': '新北市', 'flag': ''},
#    'TW-PEN': {'name': 'Penghu', 'nativeName': '澎湖縣', 'flag': ''},
#    'TW-PIF': {'name': 'Pingtung County', 'nativeName': '屏東縣', 'flag': ''},
#    'TW-TXG': {'name': 'Taichung', 'nativeName': '臺中市', 'flag': ''},
#    'TW-TNN': {'name': 'Tainan', 'nativeName': '臺南市', 'flag': ''},
#    'TW-TPE': {'name': 'Taipei', 'nativeName': '臺北市', 'flag': ''},
#    'TW-TTT': {'name': 'Taitung County', 'nativeName': '臺東縣', 'flag': ''},
#    'TW-TAO': {'name': 'Taoyuan City', 'nativeName': '桃園市', 'flag': ''},
#    'TW-ILA': {'name': 'Yilan County', 'nativeName': '宜蘭縣', 'flag': ''},
#    'TW-YUN': {'name': 'Yunlin County', 'nativeName': '雲林縣', 'flag': ''}}},
#  'VN': {'name': 'Vietnam',
#   'regions': {'VN-44': {'name': 'An Giang Province',
#     'nativeName': 'Tỉnh An Giang',
#     'flag': ''},
#    'VN-43': {'name': 'Bà Rịa - Vũng Tàu Province',
#     'nativeName': 'Tỉnh Bà Rịa - Vũng Tàu',
#     'flag': ''},
#    'VN-57': {'name': 'Bình Dương Province',
#     'nativeName': 'Tỉnh Bình Dương',
#     'flag': ''},
#    'VN-58': {'name': 'Bình Phước Province',
#     'nativeName': 'Tỉnh Bình Phước',
#     'flag': ''},
#    'VN-40': {'name': 'Bình Thuận Province',
#     'nativeName': 'Tỉnh Bình Thuận',
#     'flag': ''},
#    'VN-31': {'name': 'Bình Định Province',
#     'nativeName': 'Tỉnh Bình Định',
#     'flag': ''},
#    'VN-55': {'name': 'Bạc Liêu Province',
#     'nativeName': 'Tỉnh Bạc Liêu',
#     'flag': ''},
#    'VN-54': {'name': 'Bắc Giang Province',
#     'nativeName': 'Tỉnh Bắc Giang',
#     'flag': ''},
#    'VN-53': {'name': 'Bắc Kạn Province',
#     'nativeName': 'Tỉnh Bắc Kạn',
#     'flag': ''},
#    'VN-56': {'name': 'Bắc Ninh province',
#     'nativeName': 'Tỉnh Bắc Ninh',
#     'flag': ''},
#    'VN-50': {'name': 'Bến Tre Province',
#     'nativeName': 'Tỉnh Bến Tre',
#     'flag': ''},
#    'VN-04': {'name': 'Cao Bằng Province',
#     'nativeName': 'Tỉnh Cao Bằng',
#     'flag': ''},
#    'VN-59': {'name': 'Cà Mau Province',
#     'nativeName': 'Tỉnh Cà Mau',
#     'flag': ''},
#    'VN-CT': {'name': 'Cần Thơ', 'nativeName': 'Thành phố Cần Thơ', 'flag': ''},
#    'VN-30': {'name': 'Gia Lai Province',
#     'nativeName': 'Tỉnh Gia Lai',
#     'flag': ''},
#    'VN-14': {'name': 'Hoà Bình province',
#     'nativeName': 'Tỉnh Hòa Bình',
#     'flag': ''},
#    'VN-03': {'name': 'Hà Giang Province',
#     'nativeName': 'Tỉnh Hà Giang',
#     'flag': ''},
#    'VN-63': {'name': 'Hà Nam Province',
#     'nativeName': 'Tỉnh Hà Nam',
#     'flag': ''},
#    'VN-HN': {'name': 'Hà Nội', 'nativeName': 'Thành phố Hà Nội', 'flag': ''},
#    'VN-23': {'name': 'Hà Tĩnh Province',
#     'nativeName': 'Tỉnh Hà Tĩnh',
#     'flag': ''},
#    'VN-66': {'name': 'Hưng Yên Province',
#     'nativeName': 'Tỉnh Hưng Yên',
#     'flag': ''},
#    'VN-61': {'name': 'Hải Dương Province',
#     'nativeName': 'Tỉnh Hải Dương',
#     'flag': ''},
#    'VN-HP': {'name': 'Hải Phòng',
#     'nativeName': 'Thành phố Hải Phòng',
#     'flag': ''},
#    'VN-73': {'name': 'Hậu Giang Province',
#     'nativeName': 'Tỉnh Hậu Giang',
#     'flag': ''},
#    'VN-SG': {'name': 'Hồ Chí Minh City',
#     'nativeName': 'Thành phố Hồ Chí Minh',
#     'flag': ''},
#    'VN-34': {'name': 'Khánh Hòa Province',
#     'nativeName': 'Tỉnh Khánh Hòa',
#     'flag': ''},
#    'VN-47': {'name': 'Kiên Giang Province',
#     'nativeName': 'Tỉnh Kiên Giang',
#     'flag': ''},
#    'VN-28': {'name': 'Kon Tum Province',
#     'nativeName': 'Tỉnh Kon Tum',
#     'flag': ''},
#    'VN-01': {'name': 'Lai Châu Province',
#     'nativeName': 'Tỉnh Lai Châu',
#     'flag': ''},
#    'VN-41': {'name': 'Long An Province',
#     'nativeName': 'Tỉnh Long An',
#     'flag': ''},
#    'VN-02': {'name': 'Lào Cai Province',
#     'nativeName': 'Tỉnh Lào Cai',
#     'flag': ''},
#    'VN-35': {'name': 'Lâm Đồng Province',
#     'nativeName': 'Tỉnh Lâm Đồng',
#     'flag': ''},
#    'VN-09': {'name': 'Lạng Sơn Province',
#     'nativeName': 'Tỉnh Lạng Sơn',
#     'flag': ''},
#    'VN-67': {'name': 'Nam Định Province',
#     'nativeName': 'Tỉnh Nam Định',
#     'flag': ''},
#    'VN-22': {'name': 'Nghệ An Province',
#     'nativeName': 'Tỉnh Nghệ An',
#     'flag': ''},
#    'VN-18': {'name': 'Ninh Bình Province',
#     'nativeName': 'Tỉnh Ninh Bình',
#     'flag': ''},
#    'VN-36': {'name': 'Ninh Thuận Province',
#     'nativeName': 'Tỉnh Ninh Thuận',
#     'flag': ''},
#    'VN-68': {'name': 'Phú Thọ Province',
#     'nativeName': 'Tỉnh Phú Thọ',
#     'flag': ''},
#    'VN-32': {'name': 'Phú Yên Province',
#     'nativeName': 'Tỉnh Phú Yên',
#     'flag': ''},
#    'VN-24': {'name': 'Quảng Bình Province',
#     'nativeName': 'Tỉnh Quảng Bình',
#     'flag': ''},
#    'VN-27': {'name': 'Quảng Nam Province',
#     'nativeName': 'Tỉnh Quảng Nam',
#     'flag': ''},
#    'VN-29': {'name': 'Quảng Ngãi Province',
#     'nativeName': 'Tỉnh Quảng Ngãi',
#     'flag': ''},
#    'VN-13': {'name': 'Quảng Ninh Province',
#     'nativeName': 'Tỉnh Quảng Ninh',
#     'flag': ''},
#    'VN-25': {'name': 'Quảng Trị Province',
#     'nativeName': 'Tỉnh Quảng Trị',
#     'flag': ''},
#    'VN-52': {'name': 'Sóc Trăng Province',
#     'nativeName': 'Tỉnh Sóc Trăng',
#     'flag': ''},
#    'VN-05': {'name': 'Sơn La Province',
#     'nativeName': 'Tỉnh Sơn La',
#     'flag': ''},
#    'VN-21': {'name': 'Thanh Hoá Province',
#     'nativeName': 'Tỉnh Thanh Hóa',
#     'flag': ''},
#    'VN-20': {'name': 'Thái Bình Province',
#     'nativeName': 'Tỉnh Thái Bình',
#     'flag': ''},
#    'VN-69': {'name': 'Thái Nguyên Province',
#     'nativeName': 'Tỉnh Thái Nguyên',
#     'flag': ''},
#    'VN-26': {'name': 'Thừa Thiên Huế Province',
#     'nativeName': 'Tỉnh Thừa Thiên Huế',
#     'flag': ''},
#    'VN-46': {'name': 'Tiền Giang Province',
#     'nativeName': 'Tỉnh Tiền Giang',
#     'flag': ''},
#    'VN-51': {'name': 'Trà Vinh Province',
#     'nativeName': 'Tỉnh Trà Vinh',
#     'flag': ''},
#    'VN-07': {'name': 'Tuyên Quang Province',
#     'nativeName': 'Tỉnh Tuyên Quang',
#     'flag': ''},
#    'VN-37': {'name': 'Tây Ninh Province',
#     'nativeName': 'Tỉnh Tây Ninh',
#     'flag': ''},
#    'VN-49': {'name': 'Vĩnh Long Province',
#     'nativeName': 'Tỉnh Vĩnh Long',
#     'flag': ''},
#    'VN-70': {'name': 'Vĩnh Phúc Province',
#     'nativeName': 'Tỉnh Vĩnh Phúc',
#     'flag': ''},
#    'VN-06': {'name': 'Yên Bái Province',
#     'nativeName': 'Tỉnh Yên Bái',
#     'flag': ''},
#    'VN-71': {'name': 'Điện Biên Province',
#     'nativeName': 'Tỉnh Điện Biên',
#     'flag': ''},
#    'VN-DN': {'name': 'Đà Nẵng', 'nativeName': 'Thành phố Đà Nẵng', 'flag': ''},
#    'VN-33': {'name': 'Đăk Lăk Province',
#     'nativeName': 'Tỉnh Đăk Lăk',
#     'flag': ''},
#    'VN-72': {'name': 'Đăk Nông Province',
#     'nativeName': 'Tỉnh Đăk Nông',
#     'flag': ''},
#    'VN-39': {'name': 'Đồng Nai Province',
#     'nativeName': 'Tỉnh Đồng Nai',
#     'flag': ''},
#    'VN-45': {'name': 'Đồng Tháp Province',
#     'nativeName': 'Tỉnh Đồng Tháp',
#     'flag': ''}}}}

# %% [markdown]
# ## Unescape characters in flags links

# %%
for country in flags:
    regions = flags[country]['regions']
    for region in regions.values():
        flag = region['flag']
        region['flag'] = urllib.parse.unquote(flag)

# %% [markdown]
# Save again

# %%
json_data = json.dumps(
    flags, indent=4, ensure_ascii=False).encode('utf8').decode()
file_path = "out/flags.json"
with open(file_path, "w") as json_file:
    json_file.write(json_data)

print("JSON data has been saved to", file_path)
# Out:
# JSON data has been saved to out/flags.json

# %% [markdown]
# ## Fill native names
#
# Using Open Street Maps API: https://nominatim.openstreetmap.org/ui/search.html

# %%
urlSearch = "https://nominatim.openstreetmap.org/search.php?q=$1&countrycodes=$2&format=jsonv2"


def getRegionURL(regionName, countryCode):
    return urlSearch.replace("$1", regionName).replace("$2", countryCode)


urlReverseId = "https://nominatim.openstreetmap.org/details.php?osmtype=R&osmid=$1&format=json"


def getReverseIdURL(id):
    return urlReverseId.replace("$1", id)

# %%
def addResult(region, matchData):
    localName = matchData['name']
    if not localName:
        return False

    region["nativeName"] = localName
    print(localName)
    return True


def handleSearch(region, data):
    if data:
        it = (d for d in data if d.get("type") == "administrative")

        matchData = next(it, None)

        while matchData:
            suceed = addResult(region, matchData)
            if not suceed:
                matchData = next(it, None)
                if matchData is not None:
                    print("Trying next match")
            else:
                matchData = None
                return True

    else:
        print("No match data")
    return False


for countryCode, country in flags.items():
    print(countryCode)

    for regionCode, region in country['regions'].items():
        if region['nativeName'] != "":
            continue

        api_url = getRegionURL(regionCode, countryCode)
        data = fetchData(api_url)
        searchHandleResult = handleSearch(region, data)
        if not searchHandleResult:
            name = region['name']
            api_url = getRegionURL(name, countryCode)
            data = fetchData(api_url)
            searchHandleResult = handleSearch(region, data)
# Out:
# AR
# Salta
# Buenos Aires
# San Luis
# La Rioja
# Santiago del Estero
# Chaco
# San Juan
# Catamarca
# La Pampa
# Mendoza
# Misiones
# Formosa
# Santa Fe
# Tucumán
# Corrientes
# Córdoba
# Jujuy
# AU
# AT
# BY
# BE
# BR
# CA
# CL
# Región de Arica y Parinacota
# Región de Magallanes y de la Antártica Chilena
# CN
# 安徽省
# 北京市
# 重庆市
# 福建省
# 甘肃省
# 广东省
# 广西壮族自治区
# 贵州省
# 海南省
# 河北省
# 黑龙江省
# 河南省
# 湖北省
# 湖南省
# 内蒙古自治区 ᠦᠪᠦᠷ ᠮᠣᠩᠭᠤᠯ ᠤᠨ ᠥᠪᠡᠷᠲᠡᠭᠡᠨ ᠵᠠᠰᠠᠬᠣ ᠣᠷᠣᠨ
# 江苏省
# 江西省
# 吉林省
# 辽宁省
# 宁夏回族自治区
# 青海省
# 陕西省
# 山东省
# 上海市
# 山西省
# 四川省
# 天津市
# 西藏自治区 བོད་རང་སྐྱོང་ལྗོངས།
# 新疆维吾尔自治区 شىنجاڭ ئۇيغۇر ئاپتونوم رايونی
# 云南省
# 浙江省
# CO
# Amazonas
# Antioquia
# Arauca
# Atlántico
# Bolívar
# Boyacá
# Caldas
# Caquetá
# Casanare
# Cauca
# Cesar
# Chocó
# Córdoba
# Cundinamarca
# Guainía
# Guaviare
# Huila
# La Guajira
# Magdalena
# Meta
# Nariño
# Norte de Santander
# Putumayo
# Quindío
# Risaralda
# Santander
# Archipelago of Saint Andrew, Providence and Saint Catherine
# Sucre
# Tolima
# Valle del Cauca
# Vaupés
# Vichada
# CZ
# Jihočeský kraj
# Jihomoravský kraj
# Karlovarský kraj
# Královéhradecký kraj
# Liberecký kraj
# Moravskoslezský kraj
# Olomoucký kraj
# Plzeňský kraj
# Středočeský kraj
# Ústecký kraj
# FI
# Etelä-Karjala
# Kymenlaakso
# Lappi
# Pirkanmaa
# Österbotten
# Pohjois-Pohjanmaa
# Varsinais-Suomi
# FR
# DE
# Bayern
# HU
# Baranya vármegye
# Borsod-Abaúj-Zemplén vármegye
# Bács-Kiskun vármegye
# Békés vármegye
# Csongrád-Csanád vármegye
# Fejér vármegye
# Győr-Moson-Sopron vármegye
# Hajdú-Bihar vármegye
# Heves vármegye
# Jász-Nagykun-Szolnok vármegye
# Komárom-Esztergom vármegye
# Nógrád vármegye
# Pest vármegye
# Somogy vármegye
# Szabolcs-Szatmár-Bereg vármegye
# Tolna vármegye
# Vas vármegye
# Veszprém vármegye
# Zala vármegye
# ID
# Papua Tengah
# Maluku
# Papua Selatan
# Papua Barat Daya
# IT
# JP
# KR
# 세종
# LV
# Kurzeme
# Latgale
# Vidzeme
# Zemgale
# MY
# MX
# Estado de México
# NL
# NO
# Viken
# Innlandet
# Agder
# Vestland
# Troms og Finnmark
# PE
# Cusco
# PH
# Bangsamoro
# Bicol Region
# Cagayan Valley
# Calabarzon
# Caraga
# Central Luzon
# Central Visayas
# Cordillera Administrative Region
# Davao Region
# Eastern Visayas
# Ilocos Region
# Metro Manila
# Mimaropa
# Northern Mindanao
# Soccsksargen
# Western Visayas
# Zamboanga Peninsula
# PL
# PT
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# Açores
# No match data
# Madeira
# RO
# Alba
# Arad
# Argeș
# Bacău
# Bihor
# Bistrița-Năsăud
# Botoșani
# Brașov
# Brăila
# Buzău
# Caraș-Severin
# Cluj
# Constanța
# Covasna
# Călărași
# Dolj
# Dâmbovița
# Galați
# Giurgiu
# Gorj
# Harghita
# Hunedoara
# Ialomița
# Iași
# Ilfov
# Maramureș
# Mehedinți
# Mureș
# Neamț
# Olt
# Prahova
# Satu Mare
# Sibiu
# Suceava
# Sălaj
# Teleorman
# Timiș
# Tulcea
# Vaslui
# Vrancea
# Vâlcea
# RU
# ES
# SE
# TH
# UA
# Запорізька область
# US
# Washington
# KZ
# Абай облысы
# Ақмола облысы
# Алматы облысы
# Алматы
# Ақтөбе облысы
# Астана
# Атырау облысы
# Шығыс Қазақстан облысы
# Жамбыл облысы
# Жетісу облысы
# Қарағанды облысы
# Қостанай облысы
# Қызылорда облысы
# Маңғыстау облысы
# Солтүстік Қазақстан облысы
# Павлодар облысы
# Шымкент
# Түркістан облысы
# Ұлытау облысы
# Батыс Қазақстан облысы
# SG
# Central
# Northeast
# Northwest
# Southeast
# Southwest
# TR
# Ege Bölgesi
# Karadeniz Bölgesi
# İç Anadolu Bölgesi
# Doğu Anadolu Bölgesi
# No match data
# Marmara Bölgesi
# Akdeniz Bölgesi
# No match data
# Güneydoğu Anadolu Bölgesi
# TW
# 彰化縣
# 嘉義縣
# 嘉義市
# 新竹縣
# 新竹市
# 花蓮縣
# 高雄市
# 基隆市
# 金門縣
# 連江縣
# 苗栗縣
# 南投縣
# 新北市
# 澎湖縣
# 屏東縣
# 臺中市
# 臺南市
# 臺北市
# 臺東縣
# 桃園市
# 宜蘭縣
# 雲林縣
# VN
# Tỉnh An Giang
# Tỉnh Bà Rịa - Vũng Tàu
# Tỉnh Bình Dương
# Tỉnh Bình Phước
# Tỉnh Bình Thuận
# Tỉnh Bình Định
# Tỉnh Bạc Liêu
# Tỉnh Bắc Giang
# Tỉnh Bắc Kạn
# Tỉnh Bắc Ninh
# Tỉnh Bến Tre
# Tỉnh Cao Bằng
# Tỉnh Cà Mau
# Thành phố Cần Thơ
# Tỉnh Gia Lai
# Tỉnh Hòa Bình
# Tỉnh Hà Giang
# Tỉnh Hà Nam
# Thành phố Hà Nội
# Tỉnh Hà Tĩnh
# Tỉnh Hưng Yên
# Tỉnh Hải Dương
# Thành phố Hải Phòng
# Tỉnh Hậu Giang
# Thành phố Hồ Chí Minh
# Tỉnh Khánh Hòa
# Tỉnh Kiên Giang
# Tỉnh Kon Tum
# Tỉnh Lai Châu
# Tỉnh Long An
# Tỉnh Lào Cai
# Tỉnh Lâm Đồng
# Tỉnh Lạng Sơn
# Tỉnh Nam Định
# Tỉnh Nghệ An
# Tỉnh Ninh Bình
# Tỉnh Ninh Thuận
# Tỉnh Phú Thọ
# Tỉnh Phú Yên
# Tỉnh Quảng Bình
# Tỉnh Quảng Nam
# Tỉnh Quảng Ngãi
# Tỉnh Quảng Ninh
# Tỉnh Quảng Trị
# Tỉnh Sóc Trăng
# Tỉnh Sơn La
# Tỉnh Thanh Hóa
# Tỉnh Thái Bình
# Tỉnh Thái Nguyên
# Tỉnh Thừa Thiên Huế
# Tỉnh Tiền Giang
# Tỉnh Trà Vinh
# Tỉnh Tuyên Quang
# Tỉnh Tây Ninh
# Tỉnh Vĩnh Long
# Tỉnh Vĩnh Phúc
# Tỉnh Yên Bái
# Tỉnh Điện Biên
# Thành phố Đà Nẵng
# Tỉnh Đăk Lăk
# Tỉnh Đăk Nông
# Tỉnh Đồng Nai
# Tỉnh Đồng Tháp

# %%
json_data = json.dumps(
    flags, indent=4, ensure_ascii=False).encode('utf8').decode()
file_path = "out/flags.json"
with open(file_path, "w") as json_file:
    json_file.write(json_data)

print("JSON data has been saved to", file_path)
# Out:
# JSON data has been saved to out/flags.json

# %% [markdown]
# ## Reload data

# %%
flagsPath = "./out/flags.json"

with open(flagsPath, "r", encoding="utf-8") as json_file:
    flags = json.load(json_file)

# %%
[region['name'] for region in flags["ES"]["regions"].values()]
# Out:
# ['Andalusia',
#  'Aragon',
#  'Asturias',
#  'Basque Country',
#  'Canary Islands',
#  'Castilla–La Mancha',
#  'Castile and León',
#  'Catalonia',
#  'Extremadura',
#  'Galicia',
#  'Community of Madrid',
#  'Region of Murcia',
#  'Navarre',
#  'Valencian Community',
#  'Ceuta',
#  'Melilla',
#  'Balearic Islands',
#  'Cantabria',
#  'La Rioja']

# %% [markdown]
# Countries missing regions

# %%
printJsons = True

for countryCode, country in flags.items():
    regions = country["regions"]
    flagsFilter = [region['flag'] for region in regions.values()]
    containsEmptyFlag = any(flag == "" for flag in flagsFilter)
    if containsEmptyFlag:
        print("-", country["name"])
        if printJsons:
            print(json.dumps(country, indent=4, ensure_ascii=False))
# Out:
# - Argentina
# {
#     "name": "Argentina",
#     "nativeName": "Argentina",
#     "regions": {
#         "AR-C": {
#             "name": "Buenos Aires",
#             "nativeName": "Buenos Aires",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/f/f5/Bandera_de_la_Ciudad_de_Buenos_Aires.svg"
#         },
#         "AR-U": {
#             "name": "Chubut Province",
#             "nativeName": "Chubut",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/88/Bandera_de_la_Provincia_del_Chubut.svg"
#         },
#         "AR-E": {
#             "name": "Entre Ríos Province",
#             "nativeName": "Entre Ríos",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/5/5b/Bandera_de_la_Provincia_de_Entre_Ríos.svg"
#         },
#         "AR-Q": {
#             "name": "Neuquén Province",
#             "nativeName": "Neuquén",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/b/bc/Bandera_de_la_Provincia_de_Neuquén.svg"
#         },
#         "AR-R": {
#             "name": "Río Negro Province",
#             "nativeName": "Río Negro",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/5/5d/Bandera_de_la_Provincia_del_Río_Negro.svg"
#         },
#         "AR-Z": {
#             "name": "Santa Cruz Province",
#             "nativeName": "Santa Cruz",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/4/45/Bandera_de_la_Provincia_de_Santa_Cruz.svg"
#         },
#         "AR-V": {
#             "name": "Tierra del Fuego Province",
#             "nativeName": "Tierra del Fuego",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/9/94/Bandera_de_la_Provincia_de_Tierra_del_Fuego.svg"
#         },
#         "AR-A": {
#             "name": "Salta Province",
#             "nativeName": "Salta",
#             "flag": ""
#         },
#         "AR-B": {
#             "name": "Buenos Aires Province",
#             "nativeName": "Buenos Aires",
#             "flag": ""
#         },
#         "AR-D": {
#             "name": "San Luis Province",
#             "nativeName": "San Luis",
#             "flag": ""
#         },
#         "AR-F": {
#             "name": "La Rioja Province",
#             "nativeName": "La Rioja",
#             "flag": ""
#         },
#         "AR-G": {
#             "name": "Santiago del Estero Province",
#             "nativeName": "Santiago del Estero",
#             "flag": ""
#         },
#         "AR-H": {
#             "name": "Chaco Province",
#             "nativeName": "Chaco",
#             "flag": ""
#         },
#         "AR-J": {
#             "name": "San Juan Province",
#             "nativeName": "San Juan",
#             "flag": ""
#         },
#         "AR-K": {
#             "name": "Catamarca Province",
#             "nativeName": "Catamarca",
#             "flag": ""
#         },
#         "AR-L": {
#             "name": "La Pampa Province",
#             "nativeName": "La Pampa",
#             "flag": ""
#         },
#         "AR-M": {
#             "name": "Mendoza Province",
#             "nativeName": "Mendoza",
#             "flag": ""
#         },
#         "AR-N": {
#             "name": "Misiones Province",
#             "nativeName": "Misiones",
#             "flag": ""
#         },
#         "AR-P": {
#             "name": "Formosa Province",
#             "nativeName": "Formosa",
#             "flag": ""
#         },
#         "AR-S": {
#             "name": "Santa Fe Province",
#             "nativeName": "Santa Fe",
#             "flag": ""
#         },
#         "AR-T": {
#             "name": "Tucumán Province",
#             "nativeName": "Tucumán",
#             "flag": ""
#         },
#         "AR-W": {
#             "name": "Corrientes Province",
#             "nativeName": "Corrientes",
#             "flag": ""
#         },
#         "AR-X": {
#             "name": "Córdoba Province",
#             "nativeName": "Córdoba",
#             "flag": ""
#         },
#         "AR-Y": {
#             "name": "Jujuy Province",
#             "nativeName": "Jujuy",
#             "flag": ""
#         }
#     }
# }
# - Chile
# {
#     "name": "Chile",
#     "nativeName": "Chile",
#     "regions": {
#         "CL-AN": {
#             "name": "Antofagasta Region",
#             "nativeName": "Región de Antofagasta",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/c/cc/Flag_of_Antofagasta_Region,_Chile.svg"
#         },
#         "CL-AR": {
#             "name": "Araucanía Region",
#             "nativeName": "Región de la Araucanía",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/f/fd/Flag_of_La_Araucanía_Region.svg"
#         },
#         "CL-AT": {
#             "name": "Atacama Region",
#             "nativeName": "Región de Atacama",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/3/38/Flag_of_Atacama,_Chile.svg"
#         },
#         "CL-AI": {
#             "name": "Aysén Region",
#             "nativeName": "Región Aysén del General Carlos Ibáñez del Campo",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/0/0d/Flag_of_Aysen,_Chile.svg"
#         },
#         "CL-BI": {
#             "name": "Biobío Region",
#             "nativeName": "Región del Biobío",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/c/cd/Flag_of_Biobío_Region,_Chile.svg"
#         },
#         "CL-CO": {
#             "name": "Coquimbo Region",
#             "nativeName": "Región de Coquimbo",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/d/d7/Flag_of_Coquimbo_Region,_Chile.svg"
#         },
#         "CL-LL": {
#             "name": "Los Lagos Region",
#             "nativeName": "Región de Los Lagos",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/1/16/Flag_of_Los_Lagos_Region,_Chile.svg"
#         },
#         "CL-LR": {
#             "name": "Los Ríos Region",
#             "nativeName": "Región de Los Ríos",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/a/ac/Flag_of_Los_Ríos,_Chile.svg"
#         },
#         "CL-ML": {
#             "name": "Maule Region",
#             "nativeName": "Región del Maule",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/6/6a/Flag_of_Maule,_Chile.svg"
#         },
#         "CL-RM": {
#             "name": "Santiago Metropolitan Region",
#             "nativeName": "Región Metropolitana de Santiago",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/8d/Flag_of_the_Metropolitan_Region,_Chile.svg"
#         },
#         "CL-NB": {
#             "name": "Ñuble Region",
#             "nativeName": "Región de Ñuble",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/3/30/Flag_of_Ñuble_Region,_Chile.svg"
#         },
#         "CL-LI": {
#             "name": "O'Higgins Region",
#             "nativeName": "Región del Libertador General Bernardo O'Higgins",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/2/26/Flag_of_O'Higgins_Region,_Chile.svg"
#         },
#         "CL-TA": {
#             "name": "Tarapacá Region",
#             "nativeName": "Región de Tarapacá",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/87/Flag_of_Tarapaca,_Chile.svg"
#         },
#         "CL-VS": {
#             "name": "Valparaíso Region",
#             "nativeName": "Región de Valparaíso",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/5/50/Flag_of_Valparaiso_Region,_Chile.svg"
#         },
#         "CL-AP": {
#             "name": "Arica and Parinacota Region",
#             "nativeName": "Región de Arica y Parinacota",
#             "flag": ""
#         },
#         "CL-MA": {
#             "name": "Region of Magallanes and Chilean Antarctica",
#             "nativeName": "Región de Magallanes y de la Antártica Chilena",
#             "flag": ""
#         }
#     }
# }
# - China
# {
#     "name": "China",
#     "nativeName": "Zhōngguó 中国",
#     "regions": {
#         "CN-AH": {
#             "name": "Anhui",
#             "nativeName": "安徽省",
#             "flag": ""
#         },
#         "CN-BJ": {
#             "name": "Beijing",
#             "nativeName": "北京市",
#             "flag": ""
#         },
#         "CN-CQ": {
#             "name": "Chongqing",
#             "nativeName": "重庆市",
#             "flag": ""
#         },
#         "CN-FJ": {
#             "name": "Fujian",
#             "nativeName": "福建省",
#             "flag": ""
#         },
#         "CN-GS": {
#             "name": "Gansu",
#             "nativeName": "甘肃省",
#             "flag": ""
#         },
#         "CN-GD": {
#             "name": "Guangdong Province",
#             "nativeName": "广东省",
#             "flag": ""
#         },
#         "CN-GX": {
#             "name": "Guangxi",
#             "nativeName": "广西壮族自治区",
#             "flag": ""
#         },
#         "CN-GZ": {
#             "name": "Guizhou",
#             "nativeName": "贵州省",
#             "flag": ""
#         },
#         "CN-HI": {
#             "name": "Hainan Province",
#             "nativeName": "海南省",
#             "flag": ""
#         },
#         "CN-HE": {
#             "name": "Hebei",
#             "nativeName": "河北省",
#             "flag": ""
#         },
#         "CN-HL": {
#             "name": "Heilongjiang",
#             "nativeName": "黑龙江省",
#             "flag": ""
#         },
#         "CN-HA": {
#             "name": "Henan",
#             "nativeName": "河南省",
#             "flag": ""
#         },
#         "CN-HB": {
#             "name": "Hubei",
#             "nativeName": "湖北省",
#             "flag": ""
#         },
#         "CN-HN": {
#             "name": "Hunan",
#             "nativeName": "湖南省",
#             "flag": ""
#         },
#         "CN-NM": {
#             "name": "Inner Mongolia",
#             "nativeName": "内蒙古自治区 ᠦᠪᠦᠷ ᠮᠣᠩᠭᠤᠯ ᠤᠨ ᠥᠪᠡᠷᠲᠡᠭᠡᠨ ᠵᠠᠰᠠᠬᠣ ᠣᠷᠣᠨ",
#             "flag": ""
#         },
#         "CN-JS": {
#             "name": "Jiangsu",
#             "nativeName": "江苏省",
#             "flag": ""
#         },
#         "CN-JX": {
#             "name": "Jiangxi",
#             "nativeName": "江西省",
#             "flag": ""
#         },
#         "CN-JL": {
#             "name": "Jilin",
#             "nativeName": "吉林省",
#             "flag": ""
#         },
#         "CN-LN": {
#             "name": "Liaoning",
#             "nativeName": "辽宁省",
#             "flag": ""
#         },
#         "CN-NX": {
#             "name": "Ningxia",
#             "nativeName": "宁夏回族自治区",
#             "flag": ""
#         },
#         "CN-QH": {
#             "name": "Qinghai",
#             "nativeName": "青海省",
#             "flag": ""
#         },
#         "CN-SN": {
#             "name": "Shaanxi",
#             "nativeName": "陕西省",
#             "flag": ""
#         },
#         "CN-SD": {
#             "name": "Shandong",
#             "nativeName": "山东省",
#             "flag": ""
#         },
#         "CN-SH": {
#             "name": "Shanghai",
#             "nativeName": "上海市",
#             "flag": ""
#         },
#         "CN-SX": {
#             "name": "Shanxi",
#             "nativeName": "山西省",
#             "flag": ""
#         },
#         "CN-SC": {
#             "name": "Sichuan",
#             "nativeName": "四川省",
#             "flag": ""
#         },
#         "CN-TJ": {
#             "name": "Tianjin",
#             "nativeName": "天津市",
#             "flag": ""
#         },
#         "CN-XZ": {
#             "name": "Tibet",
#             "nativeName": "西藏自治区 བོད་རང་སྐྱོང་ལྗོངས།",
#             "flag": ""
#         },
#         "CN-XJ": {
#             "name": "Xinjiang",
#             "nativeName": "新疆维吾尔自治区 شىنجاڭ ئۇيغۇر ئاپتونوم رايونی",
#             "flag": ""
#         },
#         "CN-YN": {
#             "name": "Yunnan",
#             "nativeName": "云南省",
#             "flag": ""
#         },
#         "CN-ZJ": {
#             "name": "Zhejiang",
#             "nativeName": "浙江省",
#             "flag": ""
#         }
#     }
# }
# - Colombia
# {
#     "name": "Colombia",
#     "nativeName": "Colombia",
#     "regions": {
#         "CO-DC": {
#             "name": "Bogotá",
#             "nativeName": "Bogotá, Distrito Capital",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/9/9e/Flag_of_Bogotá.svg"
#         },
#         "CO-AMA": {
#             "name": "Amazonas",
#             "nativeName": "Amazonas",
#             "flag": ""
#         },
#         "CO-ANT": {
#             "name": "Antioquia",
#             "nativeName": "Antioquia",
#             "flag": ""
#         },
#         "CO-ARA": {
#             "name": "Arauca",
#             "nativeName": "Arauca",
#             "flag": ""
#         },
#         "CO-ATL": {
#             "name": "Atlántico",
#             "nativeName": "Atlántico",
#             "flag": ""
#         },
#         "CO-BOL": {
#             "name": "Bolívar",
#             "nativeName": "Bolívar",
#             "flag": ""
#         },
#         "CO-BOY": {
#             "name": "Boyacá",
#             "nativeName": "Boyacá",
#             "flag": ""
#         },
#         "CO-CAL": {
#             "name": "Caldas",
#             "nativeName": "Caldas",
#             "flag": ""
#         },
#         "CO-CAQ": {
#             "name": "Caquetá",
#             "nativeName": "Caquetá",
#             "flag": ""
#         },
#         "CO-CAS": {
#             "name": "Casanare",
#             "nativeName": "Casanare",
#             "flag": ""
#         },
#         "CO-CAU": {
#             "name": "Cauca",
#             "nativeName": "Cauca",
#             "flag": ""
#         },
#         "CO-CES": {
#             "name": "Cesar",
#             "nativeName": "Cesar",
#             "flag": ""
#         },
#         "CO-CHO": {
#             "name": "Chocó",
#             "nativeName": "Chocó",
#             "flag": ""
#         },
#         "CO-COR": {
#             "name": "Córdoba",
#             "nativeName": "Córdoba",
#             "flag": ""
#         },
#         "CO-CUN": {
#             "name": "Cundinamarca",
#             "nativeName": "Cundinamarca",
#             "flag": ""
#         },
#         "CO-GUA": {
#             "name": "Guainía",
#             "nativeName": "Guainía",
#             "flag": ""
#         },
#         "CO-GUV": {
#             "name": "Guaviare",
#             "nativeName": "Guaviare",
#             "flag": ""
#         },
#         "CO-HUI": {
#             "name": "Huila",
#             "nativeName": "Huila",
#             "flag": ""
#         },
#         "CO-LAG": {
#             "name": "La Guajira",
#             "nativeName": "La Guajira",
#             "flag": ""
#         },
#         "CO-MAG": {
#             "name": "Magdalena",
#             "nativeName": "Magdalena",
#             "flag": ""
#         },
#         "CO-MET": {
#             "name": "Meta",
#             "nativeName": "Meta",
#             "flag": ""
#         },
#         "CO-NAR": {
#             "name": "Nariño",
#             "nativeName": "Nariño",
#             "flag": ""
#         },
#         "CO-NSA": {
#             "name": "Norte de Santander",
#             "nativeName": "Norte de Santander",
#             "flag": ""
#         },
#         "CO-PUT": {
#             "name": "Putumayo",
#             "nativeName": "Putumayo",
#             "flag": ""
#         },
#         "CO-QUI": {
#             "name": "Quindío",
#             "nativeName": "Quindío",
#             "flag": ""
#         },
#         "CO-RIS": {
#             "name": "Risaralda",
#             "nativeName": "Risaralda",
#             "flag": ""
#         },
#         "CO-SAN": {
#             "name": "Santander",
#             "nativeName": "Santander",
#             "flag": ""
#         },
#         "CO-SAP": {
#             "name": "San Andrés and Providencia",
#             "nativeName": "Archipelago of Saint Andrew, Providence and Saint Catherine",
#             "flag": ""
#         },
#         "CO-SUC": {
#             "name": "Sucre",
#             "nativeName": "Sucre",
#             "flag": ""
#         },
#         "CO-TOL": {
#             "name": "Tolima",
#             "nativeName": "Tolima",
#             "flag": ""
#         },
#         "CO-VAC": {
#             "name": "Valle del Cauca",
#             "nativeName": "Valle del Cauca",
#             "flag": ""
#         },
#         "CO-VAU": {
#             "name": "Vaupés",
#             "nativeName": "Vaupés",
#             "flag": ""
#         },
#         "CO-VID": {
#             "name": "Vichada",
#             "nativeName": "Vichada",
#             "flag": ""
#         }
#     }
# }
# - Czech Republic
# {
#     "name": "Czech Republic",
#     "regions": {
#         "CZ-53": {
#             "name": "Pardubice",
#             "nativeName": "Pardubický kraj",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Flag_of_Pardubice_Region.svg"
#         },
#         "CZ-10": {
#             "name": "Prague",
#             "nativeName": "Hlavní město Praha",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/d/d2/Flag_of_Prague.svg"
#         },
#         "CZ-63": {
#             "name": "Vysočina",
#             "nativeName": "Kraj Vysočina",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/1/14/Flag_of_Vysocina_Region.svg"
#         },
#         "CZ-72": {
#             "name": "Zlín",
#             "nativeName": "Zlínský kraj",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/84/Flag_of_Zlin_Region.svg"
#         },
#         "CZ-31": {
#             "name": "South Bohemia",
#             "nativeName": "Jihočeský kraj",
#             "flag": ""
#         },
#         "CZ-64": {
#             "name": "South Moravia",
#             "nativeName": "Jihomoravský kraj",
#             "flag": ""
#         },
#         "CZ-41": {
#             "name": "Karlovy Vary",
#             "nativeName": "Karlovarský kraj",
#             "flag": ""
#         },
#         "CZ-52": {
#             "name": "Hradec Králové",
#             "nativeName": "Královéhradecký kraj",
#             "flag": ""
#         },
#         "CZ-51": {
#             "name": "Liberec",
#             "nativeName": "Liberecký kraj",
#             "flag": ""
#         },
#         "CZ-80": {
#             "name": "Moravia-Silesia",
#             "nativeName": "Moravskoslezský kraj",
#             "flag": ""
#         },
#         "CZ-71": {
#             "name": "Olomouc",
#             "nativeName": "Olomoucký kraj",
#             "flag": ""
#         },
#         "CZ-32": {
#             "name": "Plzeň",
#             "nativeName": "Plzeňský kraj",
#             "flag": ""
#         },
#         "CZ-20": {
#             "name": "Central Bohemia",
#             "nativeName": "Středočeský kraj",
#             "flag": ""
#         },
#         "CZ-42": {
#             "name": "Ústí nad Labem",
#             "nativeName": "Ústecký kraj",
#             "flag": ""
#         }
#     }
# }
# - Finland
# {
#     "name": "Finland",
#     "nativeName": "Suomi",
#     "regions": {
#         "FI-01": {
#             "name": "Åland",
#             "nativeName": "Landskapet Åland",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/5/52/Flag_of_Åland.svg"
#         },
#         "FI-08": {
#             "name": "Central Finland",
#             "nativeName": "Keski-Suomi",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/9/9a/Keski-suomi_lippu.svg"
#         },
#         "FI-07": {
#             "name": "Central Ostrobothnia",
#             "nativeName": "Keski-Pohjanmaa",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/6/64/Keski-Pohjanmaa.lippu.svg"
#         },
#         "FI-05": {
#             "name": "Kainuu",
#             "nativeName": "Kainuu",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/5/5d/Flag_of_Kainuu.svg"
#         },
#         "FI-06": {
#             "name": "Kanta-Häme",
#             "nativeName": "Kanta-Häme",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/b/bd/Flag_of_Tavastia_Proper.svg"
#         },
#         "FI-13": {
#             "name": "North Karelia",
#             "nativeName": "Pohjois-Karjala",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/e/e0/North_karelia_flag.svg"
#         },
#         "FI-15": {
#             "name": "North Savo",
#             "nativeName": "Pohjois-Savo",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/85/Flag_of_Northern_Savonia.svg"
#         },
#         "FI-16": {
#             "name": "Päijät-Häme",
#             "nativeName": "Päijät-Häme",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/1/18/Päijät-Häme.lippu.svg"
#         },
#         "FI-17": {
#             "name": "Satakunta",
#             "nativeName": "Satakunta",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/7/78/Satakunta-flag.svg"
#         },
#         "FI-03": {
#             "name": "South Ostrobothnia",
#             "nativeName": "Etelä-Pohjanmaa",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/3/30/Flag_of_Southern_Ostrobothnia.svg"
#         },
#         "FI-04": {
#             "name": "South Savo",
#             "nativeName": "Etelä-Savo",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/b/b1/Flag_of_South_Savonia.svg"
#         },
#         "FI-18": {
#             "name": "Uusimaa",
#             "nativeName": "Uusimaa",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/c/c8/Flag_of_Uusimaa.svg"
#         },
#         "FI-02": {
#             "name": "South Karelia",
#             "nativeName": "Etelä-Karjala",
#             "flag": ""
#         },
#         "FI-09": {
#             "name": "Kymenlaakso",
#             "nativeName": "Kymenlaakso",
#             "flag": ""
#         },
#         "FI-10": {
#             "name": "Lapland",
#             "nativeName": "Lappi",
#             "flag": ""
#         },
#         "FI-11": {
#             "name": "Pirkanmaa",
#             "nativeName": "Pirkanmaa",
#             "flag": ""
#         },
#         "FI-12": {
#             "name": "Ostrobothnia",
#             "nativeName": "Österbotten",
#             "flag": ""
#         },
#         "FI-14": {
#             "name": "North Ostrobothnia",
#             "nativeName": "Pohjois-Pohjanmaa",
#             "flag": ""
#         },
#         "FI-19": {
#             "name": "Southwest Finland",
#             "nativeName": "Varsinais-Suomi",
#             "flag": ""
#         }
#     }
# }
# - Germany
# {
#     "name": "Germany",
#     "nativeName": "Deutschland",
#     "regions": {
#         "DE-BW": {
#             "name": "Baden-Württemberg",
#             "nativeName": "Baden-Württemberg",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/5/5c/Flag_of_Baden-Württemberg.svg"
#         },
#         "DE-BE": {
#             "name": "Berlin",
#             "nativeName": "Berlin",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/e/ec/Flag_of_Berlin.svg"
#         },
#         "DE-BB": {
#             "name": "Brandenburg",
#             "nativeName": "Brandenburg",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/0/01/Flag_of_Brandenburg.svg"
#         },
#         "DE-HB": {
#             "name": "Bremen",
#             "nativeName": "Bremen",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/0/0e/Flag_of_Bremen.svg"
#         },
#         "DE-HH": {
#             "name": "Hamburg",
#             "nativeName": "Hamburg",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/7/74/Flag_of_Hamburg.svg"
#         },
#         "DE-HE": {
#             "name": "Hesse",
#             "nativeName": "Hessen",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/f/f7/Flag_of_Hesse.svg"
#         },
#         "DE-NI": {
#             "name": "Lower Saxony",
#             "nativeName": "Niedersachsen",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/81/Flag_of_Lower_Saxony.svg"
#         },
#         "DE-MV": {
#             "name": "Mecklenburg-Vorpommern",
#             "nativeName": "Mecklenburg-Vorpommern",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/c/ce/Flag_of_Mecklenburg-Western_Pomerania.svg"
#         },
#         "DE-NW": {
#             "name": "North Rhine-Westphalia",
#             "nativeName": "Nordrhein-Westfalen",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/84/Flag_of_North_Rhine-Westphalia.svg"
#         },
#         "DE-RP": {
#             "name": "Rhineland-Palatinate",
#             "nativeName": "Rheinland-Pfalz",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/b/b7/Flag_of_Rhineland-Palatinate.svg"
#         },
#         "DE-SL": {
#             "name": "Saarland",
#             "nativeName": "Saarland",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/f/f7/Flag_of_Saarland.svg"
#         },
#         "DE-SN": {
#             "name": "Saxony",
#             "nativeName": "Sachsen",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/f/fd/Flag_of_Saxony.svg"
#         },
#         "DE-ST": {
#             "name": "Saxony-Anhalt",
#             "nativeName": "Sachsen-Anhalt",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/c/c2/Flag_of_Saxony-Anhalt_(state).svg"
#         },
#         "DE-SH": {
#             "name": "Schleswig-Holstein",
#             "nativeName": "Schleswig-Holstein",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/b/b4/Flag_of_Schleswig-Holstein.svg"
#         },
#         "DE-TH": {
#             "name": "Thuringia",
#             "nativeName": "Thüringen",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/b/bd/Flag_of_Thuringia.svg"
#         },
#         "DE-BY": {
#             "name": "Bavaria",
#             "nativeName": "Bayern",
#             "flag": ""
#         }
#     }
# }
# - Hungary
# {
#     "name": "Hungary",
#     "nativeName": "Magyarország",
#     "regions": {
#         "HU-BU": {
#             "name": "Budapest",
#             "nativeName": "Budapest",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/d/d5/Flag_of_Budapest_(2011-).svg"
#         },
#         "HU-BA": {
#             "name": "Baranya",
#             "nativeName": "Baranya vármegye",
#             "flag": ""
#         },
#         "HU-BZ": {
#             "name": "Borsod-Abaúj-Zemplén",
#             "nativeName": "Borsod-Abaúj-Zemplén vármegye",
#             "flag": ""
#         },
#         "HU-BK": {
#             "name": "Bács-Kiskun",
#             "nativeName": "Bács-Kiskun vármegye",
#             "flag": ""
#         },
#         "HU-BE": {
#             "name": "Békés",
#             "nativeName": "Békés vármegye",
#             "flag": ""
#         },
#         "HU-CS": {
#             "name": "Csongrád-Csanád",
#             "nativeName": "Csongrád-Csanád vármegye",
#             "flag": ""
#         },
#         "HU-FE": {
#             "name": "Fejér",
#             "nativeName": "Fejér vármegye",
#             "flag": ""
#         },
#         "HU-GS": {
#             "name": "Győr-Moson-Sopron",
#             "nativeName": "Győr-Moson-Sopron vármegye",
#             "flag": ""
#         },
#         "HU-HB": {
#             "name": "Hajdú-Bihar",
#             "nativeName": "Hajdú-Bihar vármegye",
#             "flag": ""
#         },
#         "HU-HE": {
#             "name": "Heves",
#             "nativeName": "Heves vármegye",
#             "flag": ""
#         },
#         "HU-JN": {
#             "name": "Jász-Nagykun-Szolnok",
#             "nativeName": "Jász-Nagykun-Szolnok vármegye",
#             "flag": ""
#         },
#         "HU-KE": {
#             "name": "Komárom-Esztergom",
#             "nativeName": "Komárom-Esztergom vármegye",
#             "flag": ""
#         },
#         "HU-NO": {
#             "name": "Nógrád",
#             "nativeName": "Nógrád vármegye",
#             "flag": ""
#         },
#         "HU-PE": {
#             "name": "Pest",
#             "nativeName": "Pest vármegye",
#             "flag": ""
#         },
#         "HU-SO": {
#             "name": "Somogy",
#             "nativeName": "Somogy vármegye",
#             "flag": ""
#         },
#         "HU-SZ": {
#             "name": "Szabolcs-Szatmár-Bereg",
#             "nativeName": "Szabolcs-Szatmár-Bereg vármegye",
#             "flag": ""
#         },
#         "HU-TO": {
#             "name": "Tolna",
#             "nativeName": "Tolna vármegye",
#             "flag": ""
#         },
#         "HU-VA": {
#             "name": "Vas",
#             "nativeName": "Vas vármegye",
#             "flag": ""
#         },
#         "HU-VE": {
#             "name": "Veszprém",
#             "nativeName": "Veszprém vármegye",
#             "flag": ""
#         },
#         "HU-ZA": {
#             "name": "Zala",
#             "nativeName": "Zala vármegye",
#             "flag": ""
#         }
#     }
# }
# - Indonesia
# {
#     "name": "Indonesia",
#     "nativeName": "Indonesia",
#     "regions": {
#         "ID-AC": {
#             "name": "Aceh",
#             "nativeName": "Aceh",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/3/36/Flag_of_Aceh,_Indonesia.svg"
#         },
#         "ID-BA": {
#             "name": "Bali",
#             "nativeName": "Bali",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/a/a3/Flag_of_Bali.svg"
#         },
#         "ID-BB": {
#             "name": "Bangka Belitung Islands",
#             "nativeName": "Kepulauan Bangka Belitung",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/1/1d/Flag_of_Bangka-Belitung.svg"
#         },
#         "ID-BT": {
#             "name": "Banten",
#             "nativeName": "Banten",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/88/Flag_of_Banten,_Indonesia.svg"
#         },
#         "ID-BE": {
#             "name": "Bengkulu",
#             "nativeName": "Bengkulu",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/e/ec/Flag_of_Bengkulu.svg"
#         },
#         "ID-JT": {
#             "name": "Central Java",
#             "nativeName": "Jawa Tengah",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/2/2d/Flag_of_Central_Java.svg"
#         },
#         "ID-KT": {
#             "name": "Central Kalimantan",
#             "nativeName": "Kalimantan Tengah",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/9/9c/Flag_of_Central_Kalimantan.svg"
#         },
#         "ID-ST": {
#             "name": "Central Sulawesi",
#             "nativeName": "Sulawesi Tengah",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/f/f1/Flag_of_Central_Sulawesi.svg"
#         },
#         "ID-JI": {
#             "name": "East Java",
#             "nativeName": "Jawa Timur",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/3/3d/Flag_of_East_Java.svg"
#         },
#         "ID-KI": {
#             "name": "East Kalimantan",
#             "nativeName": "Kalimantan Timur",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/88/Flag_of_East_Kalimantan.svg"
#         },
#         "ID-NT": {
#             "name": "East Nusa Tenggara",
#             "nativeName": "Nusa Tenggara Timur",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/5/57/Flag_of_East_Nusa_Tenggara.svg"
#         },
#         "ID-GO": {
#             "name": "Gorontalo",
#             "nativeName": "Gorontalo",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/8f/Flag_of_Gorontalo.svg"
#         },
#         "ID-PE": {
#             "name": "Highland Papua",
#             "nativeName": "Papua Pegunungan",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Flag_of_Highland_Papua_Province.png/143px-Flag_of_Highland_Papua_Province.png"
#         },
#         "ID-JA": {
#             "name": "Jambi",
#             "nativeName": "Jambi",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/8d/Flag_of_Jambi.svg"
#         },
#         "ID-LA": {
#             "name": "Lampung",
#             "nativeName": "Lampung",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/0/09/Flag_of_Lampung.svg"
#         },
#         "ID-KU": {
#             "name": "North Kalimantan",
#             "nativeName": "Kalimantan Utara",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/4/4b/Flag_of_North_Kalimantan.svg"
#         },
#         "ID-MU": {
#             "name": "North Maluku",
#             "nativeName": "Maluku Utara",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/f/f2/Flag_of_North_Maluku.svg"
#         },
#         "ID-SA": {
#             "name": "North Sulawesi",
#             "nativeName": "Sulawesi Utara",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/b/ba/Flag_of_North_Sulawesi.svg"
#         },
#         "ID-SU": {
#             "name": "North Sumatra",
#             "nativeName": "Sumatera Utara",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/f/f3/Flag_of_North_Sumatra.svg"
#         },
#         "ID-PA": {
#             "name": "Papua",
#             "nativeName": "Papua",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/e/ec/Flag_of_Papua_2.svg"
#         },
#         "ID-RI": {
#             "name": "Riau",
#             "nativeName": "Riau",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/a/a8/Flag_of_Riau.svg"
#         },
#         "ID-KR": {
#             "name": "Riau Islands",
#             "nativeName": "Kepulauan Riau",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/a/aa/Flag_of_Riau_Islands.svg"
#         },
#         "ID-SG": {
#             "name": "Southeast Sulawesi",
#             "nativeName": "Sulawesi Tenggara",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/a/ac/Flag_of_Southeast_Sulawesi.svg"
#         },
#         "ID-KS": {
#             "name": "South Kalimantan",
#             "nativeName": "Kalimantan Selatan",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/3/31/Flag_of_South_Kalimantan.svg"
#         },
#         "ID-SN": {
#             "name": "South Sulawesi",
#             "nativeName": "Sulawesi Selatan",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/8d/Flag_of_South_Sulawesi.svg"
#         },
#         "ID-SS": {
#             "name": "South Sumatra",
#             "nativeName": "Sumatera Selatan",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/a/ab/Flag_of_South_Sumatra_(vectorised).svg"
#         },
#         "ID-JB": {
#             "name": "West Java",
#             "nativeName": "Jawa Barat",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/4/41/Flag_of_West_Java_(vectorised).svg"
#         },
#         "ID-KB": {
#             "name": "West Kalimantan",
#             "nativeName": "Kalimantan Barat",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/8b/Flag_of_West_Kalimantan.svg"
#         },
#         "ID-NB": {
#             "name": "West Nusa Tenggara",
#             "nativeName": "Nusa Tenggara Barat",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/1/1f/Flag_of_West_Nusa_Tenggara.svg"
#         },
#         "ID-PB": {
#             "name": "West Papua",
#             "nativeName": "Papua Barat",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/0/01/Flag_of_West_Papua_(vectorised).svg"
#         },
#         "ID-SR": {
#             "name": "West Sulawesi",
#             "nativeName": "Sulawesi Barat",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/9/95/Flag_of_West_Sulawesi.svg"
#         },
#         "ID-SB": {
#             "name": "West Sumatra",
#             "nativeName": "Sumatera Barat",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/6/64/Flag_of_West_Sumatra.svg"
#         },
#         "ID-YO": {
#             "name": "Special Region of Yogyakarta",
#             "nativeName": "Daerah Istimewa Yogyakarta",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/7/70/Flag_of_Yogyakarta.svg"
#         },
#         "ID-JK": {
#             "name": "Jakarta",
#             "nativeName": "Daerah Khusus Ibukota Jakarta",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/8e/Flag_of_Jakarta_(vectorised).svg"
#         },
#         "ID-PT": {
#             "name": "Central Papua",
#             "nativeName": "Papua Tengah",
#             "flag": ""
#         },
#         "ID-MA": {
#             "name": "Maluku Islands",
#             "nativeName": "Maluku",
#             "flag": ""
#         },
#         "ID-PS": {
#             "name": "South Papua",
#             "nativeName": "Papua Selatan",
#             "flag": ""
#         },
#         "ID-PSW": {
#             "name": "Southwest Papua",
#             "nativeName": "Papua Barat Daya",
#             "flag": ""
#         }
#     }
# }
# - South Korea
# {
#     "name": "South Korea",
#     "nativeName": "Hanguk 한국 Namhan 남한",
#     "regions": {
#         "KR-11": {
#             "name": "Seoul",
#             "nativeName": "서울",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/c/ca/Flag_of_Seoul.svg"
#         },
#         "KR-26": {
#             "name": "Busan",
#             "nativeName": "부산",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/b/b1/Flag_of_Busan.svg"
#         },
#         "KR-27": {
#             "name": "Daegu",
#             "nativeName": "대구",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/6/65/Flag_of_Daegu.svg"
#         },
#         "KR-30": {
#             "name": "Daejeon",
#             "nativeName": "대전",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/5/53/Flag_of_Daejeon.svg"
#         },
#         "KR-29": {
#             "name": "Gwangju",
#             "nativeName": "광주",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/5/59/Flag_of_Gwangju.svg"
#         },
#         "KR-28": {
#             "name": "Incheon",
#             "nativeName": "인천",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/0/0c/Flag_of_Incheon.svg"
#         },
#         "KR-31": {
#             "name": "Ulsan",
#             "nativeName": "울산",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/e/ef/Flag_of_Ulsan.svg"
#         },
#         "KR-43": {
#             "name": "North Chungcheong",
#             "nativeName": "충청북도",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/7/7d/Flag_of_North_Chungcheong_Province.svg"
#         },
#         "KR-44": {
#             "name": "South Chungcheong",
#             "nativeName": "충청남도",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/1/1c/Flag_of_South_Chungcheong_Province.svg"
#         },
#         "KR-42": {
#             "name": "Gangwon",
#             "nativeName": "강원특별자치도",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/f/fe/Flag_of_Gangwon_Province.svg"
#         },
#         "KR-41": {
#             "name": "Gyeonggi",
#             "nativeName": "경기도",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/d/db/Flag_of_Gyeonggi_Province.svg"
#         },
#         "KR-47": {
#             "name": "North Gyeongsang",
#             "nativeName": "경상북도",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/e/ef/Flag_of_North_Gyeongsang_Province.svg"
#         },
#         "KR-48": {
#             "name": "South Gyeongsang",
#             "nativeName": "경상남도",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/a/ae/Flag_of_South_Gyeongsang_Province.svg"
#         },
#         "KR-45": {
#             "name": "North Jeolla",
#             "nativeName": "전라북도",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/2/2a/Flag_of_North_Jeolla_Province.svg"
#         },
#         "KR-46": {
#             "name": "South Jeolla",
#             "nativeName": "전라남도",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/5/58/Flag_of_South_Jeolla_Province.svg"
#         },
#         "KR-49": {
#             "name": "Jeju",
#             "nativeName": "제주특별자치도",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/b/b9/Flag_of_Jeju_Province.svg"
#         },
#         "KR-50": {
#             "name": "Sejong",
#             "nativeName": "세종",
#             "flag": ""
#         }
#     }
# }
# - Latvia
# {
#     "name": "Latvia",
#     "nativeName": "Latvija",
#     "regions": {
#         "K": {
#             "name": "Courland",
#             "nativeName": "Kurzeme",
#             "flag": ""
#         },
#         "L": {
#             "name": "Latgale",
#             "nativeName": "Latgale",
#             "flag": ""
#         },
#         "V": {
#             "name": "Vidzeme",
#             "nativeName": "Vidzeme",
#             "flag": ""
#         },
#         "Z": {
#             "name": "Zemgale",
#             "nativeName": "Zemgale",
#             "flag": ""
#         }
#     }
# }
# - Mexico
# {
#     "name": "Mexico",
#     "nativeName": "Mēxihco",
#     "regions": {
#         "MX-AGU": {
#             "name": "Aguascalientes",
#             "nativeName": "Aguascalientes",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/1/1b/Flag_of_Aguascalientes.svg"
#         },
#         "MX-BCN": {
#             "name": "Baja California",
#             "nativeName": "Baja California",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/2/27/Flag_of_Baja_California.svg"
#         },
#         "MX-BCS": {
#             "name": "Baja California Sur",
#             "nativeName": "Baja California Sur",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/9/9c/Flag_of_Baja_California_Sur.svg"
#         },
#         "MX-CAM": {
#             "name": "Campeche",
#             "nativeName": "Campeche",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/3/37/Flag_of_Campeche.svg"
#         },
#         "MX-CHP": {
#             "name": "Chiapas",
#             "nativeName": "Chiapas",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/1/1a/Flag_of_Chiapas.svg"
#         },
#         "MX-CHH": {
#             "name": "Chihuahua",
#             "nativeName": "Chihuahua",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/1/1b/Flag_of_Chihuahua.svg"
#         },
#         "MX-COA": {
#             "name": "Coahuila",
#             "nativeName": "Coahuila",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/d/d2/Flag_of_Coahuila.svg"
#         },
#         "MX-COL": {
#             "name": "Colima",
#             "nativeName": "Colima",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/5/52/Flag_of_Colima.svg"
#         },
#         "MX-DUR": {
#             "name": "Durango",
#             "nativeName": "Durango",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/7/70/Flag_of_Durango.svg"
#         },
#         "MX-GUA": {
#             "name": "Guanajuato",
#             "nativeName": "Guanajuato",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/e/e0/Flag_of_Guanajuato.svg"
#         },
#         "MX-GRO": {
#             "name": "Guerrero",
#             "nativeName": "Guerrero",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/b/b8/Flag_of_Guerrero.svg"
#         },
#         "MX-HID": {
#             "name": "Hidalgo",
#             "nativeName": "Hidalgo",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/0/0d/Flag_of_Hidalgo.svg"
#         },
#         "MX-JAL": {
#             "name": "Jalisco",
#             "nativeName": "Jalisco",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/2/2b/Flag_of_Jalisco.svg"
#         },
#         "MX-CMX": {
#             "name": "Mexico",
#             "nativeName": "Ciudad de México",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/b/b7/Flag_of_the_State_of_Mexico.svg"
#         },
#         "MX-MIC": {
#             "name": "Michoacán",
#             "nativeName": "Michoacán",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/0/02/Flag_of_Michoacan.svg"
#         },
#         "MX-MOR": {
#             "name": "Morelos",
#             "nativeName": "Morelos",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/f/fd/Flag_of_Morelos.svg"
#         },
#         "MX-NAY": {
#             "name": "Nayarit",
#             "nativeName": "Nayarit",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/a/ac/Flag_of_Nayarit.svg"
#         },
#         "MX-NLE": {
#             "name": "Nuevo León",
#             "nativeName": "Nuevo León",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/8/80/Flag_of_Nuevo_Leon.svg"
#         },
#         "MX-OAX": {
#             "name": "Oaxaca",
#             "nativeName": "Oaxaca",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/b/b2/Flag_of_Oaxaca.svg"
#         },
#         "MX-PUE": {
#             "name": "Puebla",
#             "nativeName": "Puebla",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/c/cd/Flag_of_Puebla.svg"
#         },
#         "MX-QUE": {
#             "name": "Querétaro",
#             "nativeName": "Querétaro",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/1/18/Flag_of_Queretaro.svg"
#         },
#         "MX-ROO": {
#             "name": "Quintana Roo",
#             "nativeName": "Quintana Roo",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/a/a0/Flag_of_Quintana_Roo.svg"
#         },
#         "MX-SLP": {
#             "name": "San Luis Potosí",
#             "nativeName": "San Luis Potosí",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/9/99/Flag_of_San_Luis_Potosi.svg"
#         },
#         "MX-SIN": {
#             "name": "Sinaloa",
#             "nativeName": "Sinaloa",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/c/cc/Flag_of_Sinaloa.svg"
#         },
#         "MX-SON": {
#             "name": "Sonora",
#             "nativeName": "Sonora",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/6/69/Flag_of_Sonora.svg"
#         },
#         "MX-TAB": {
#             "name": "Tabasco",
#             "nativeName": "Tabasco",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Flag_of_Tabasco.svg"
#         },
#         "MX-TAM": {
#             "name": "Tamaulipas",
#             "nativeName": "Tamaulipas",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/9/9f/Flag_of_Tamaulipas.svg"
#         },
#         "MX-TLA": {
#             "name": "Tlaxcala",
#             "nativeName": "Tlaxcala",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/2/26/Flag_of_Tlaxcala.svg"
#         },
#         "MX-VER": {
#             "name": "Veracruz",
#             "nativeName": "Veracruz",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/6/6a/Flag_of_Veracruz.svg"
#         },
#         "MX-YUC": {
#             "name": "Yucatán",
#             "nativeName": "Yucatán",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/9/9b/Flag_of_Yucatan.svg"
#         },
#         "MX-ZAC": {
#             "name": "Zacatecas",
#             "nativeName": "Zacatecas",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/9/9f/Flag_of_Zacatecas.svg"
#         },
#         "MX-MEX": {
#             "name": "State of Mexico",
#             "nativeName": "Estado de México",
#             "flag": ""
#         }
#     }
# }
# - Norway
# {
#     "name": "Norway",
#     "nativeName": "Norge",
#     "regions": {
#         "NO-15": {
#             "name": "Møre og Romsdal",
#             "nativeName": "Møre og Romsdal",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/0/08/Flag_of_Møre_og_Romsdal.svg"
#         },
#         "NO-18": {
#             "name": "Nordland",
#             "nativeName": "Nordland",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/7/75/Flag_of_Nordland.svg"
#         },
#         "NO-03": {
#             "name": "Oslo",
#             "nativeName": "Oslo",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/2/21/Flag_of_Oslo.svg"
#         },
#         "NO-11": {
#             "name": "Rogaland",
#             "nativeName": "Rogaland",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/3/3e/Flag_of_Rogaland.svg"
#         },
#         "NO-50": {
#             "name": "Trøndelag",
#             "nativeName": "Trøndelag",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/f/fb/Flag_of_Nord-Trøndelag.svg"
#         },
#         "NO-38": {
#             "name": "Vestfold og Telemark",
#             "nativeName": "Vestfold og Telemark",
#             "flag": "https://upload.wikimedia.org/wikipedia/commons/a/af/Flag_of_Vestfold_and_Telemark.svg"
#         },
#         "NO-30": {
#             "name": "Viken",
#             "nativeName": "Viken",
#             "flag": ""
#         },
#         "NO-34": {
#             "name": "Innlandet",
#             "nativeName": "Innlandet",
#             "flag": ""
#         },
#         "NO-42": {
#             "name": "Agder",
#             "nativeName": "Agder",
#             "flag": ""
#         },
#         "NO-46": {
#             "name": "Vestland",
#             "nativeName": "Vestland",
#             "flag": ""
#         },
#         "NO-54": {
#             "name": "Troms og Finnmark",
#             "nativeName": "Troms og Finnmark",
#             "flag": ""
#         }
#     }
# }
# - Peru
# {
#     "name": "Peru",
#     "nativeName": "Piruw",
#     "regions": {
#         "PE-AMA": {
#             "name": "Department of Amazonas",
#             "nativeName": "Amazonas",
# ...
#             "name": "Abay Region",
#             "nativeName": "Абай облысы",
#             "flag": ""
#         },
#         "KZ-11": {
#             "name": "Akmola Region",
#             "nativeName": "Ақмола облысы",
#             "flag": ""
#         },
#         "KZ-19": {
#             "name": "Almaty Region",
#             "nativeName": "Алматы облысы",
#             "flag": ""
#         },
#         "KZ-75": {
#             "name": "Almaty",
#             "nativeName": "Алматы",
#             "flag": ""
#         },
#         "KZ-15": {
#             "name": "Aqtöbe region",
#             "nativeName": "Ақтөбе облысы",
#             "flag": ""
#         },
#         "KZ-71": {
#             "name": "Astana",
#             "nativeName": "Астана",
#             "flag": ""
#         },
#         "KZ-23": {
#             "name": "Atyrau Region",
#             "nativeName": "Атырау облысы",
#             "flag": ""
#         },
#         "KZ-63": {
#             "name": "East Kazakhstan Region",
#             "nativeName": "Шығыс Қазақстан облысы",
#             "flag": ""
#         },
#         "KZ-31": {
#             "name": "Jambyl Region",
#             "nativeName": "Жамбыл облысы",
#             "flag": ""
#         },
#         "KZ-33": {
#             "name": "Jetisu Region",
#             "nativeName": "Жетісу облысы",
#             "flag": ""
#         },
#         "KZ-35": {
#             "name": "Karaganda Region",
#             "nativeName": "Қарағанды облысы",
#             "flag": ""
#         },
#         "KZ-39": {
#             "name": "Kostanay Region",
#             "nativeName": "Қостанай облысы",
#             "flag": ""
#         },
#         "KZ-43": {
#             "name": "Kyzylorda Region",
#             "nativeName": "Қызылорда облысы",
#             "flag": ""
#         },
#         "KZ-47": {
#             "name": "Mangystau Region",
#             "nativeName": "Маңғыстау облысы",
#             "flag": ""
#         },
#         "KZ-59": {
#             "name": "North Kazakhstan Region",
#             "nativeName": "Солтүстік Қазақстан облысы",
#             "flag": ""
#         },
#         "KZ-55": {
#             "name": "Pavlodar Region",
#             "nativeName": "Павлодар облысы",
#             "flag": ""
#         },
#         "KZ-79": {
#             "name": "Shymkent",
#             "nativeName": "Шымкент",
#             "flag": ""
#         },
#         "KZ-61": {
#             "name": "Turkistan Region",
#             "nativeName": "Түркістан облысы",
#             "flag": ""
#         },
#         "KZ-62": {
#             "name": "Ulytau Region",
#             "nativeName": "Ұлытау облысы",
#             "flag": ""
#         },
#         "KZ-27": {
#             "name": "West Kazakhstan Region",
#             "nativeName": "Батыс Қазақстан облысы",
#             "flag": ""
#         }
#     }
# }
# - Singapore
# {
#     "name": "Singapore",
#     "regions": {
#         "SG-01": {
#             "name": "Central Singapore",
#             "nativeName": "Central",
#             "flag": ""
#         },
#         "SG-02": {
#             "name": "Northeast Singapore",
#             "nativeName": "Northeast",
#             "flag": ""
#         },
#         "SG-03": {
#             "name": "Northwest Singapore",
#             "nativeName": "Northwest",
#             "flag": ""
#         },
#         "SG-04": {
#             "name": "Southeast Singapore",
#             "nativeName": "Southeast",
#             "flag": ""
#         },
#         "SG-05": {
#             "name": "Southwest Singapore",
#             "nativeName": "Southwest",
#             "flag": ""
#         }
#     }
# }
# - Turkey
# {
#     "name": "Turkey",
#     "regions": {
#         "TR-EGE": {
#             "name": "Aegean Region",
#             "nativeName": "Ege Bölgesi",
#             "flag": ""
#         },
#         "TR-KAR": {
#             "name": "Black Sea Region",
#             "nativeName": "Karadeniz Bölgesi",
#             "flag": ""
#         },
#         "TR-ICA": {
#             "name": "Central Anatolia Region",
#             "nativeName": "İç Anadolu Bölgesi",
#             "flag": ""
#         },
#         "TR-DOA": {
#             "name": "Eastern Anatolia Region",
#             "nativeName": "Doğu Anadolu Bölgesi",
#             "flag": ""
#         },
#         "TR-MRM": {
#             "name": "Marmara Region",
#             "nativeName": "Marmara Bölgesi",
#             "flag": ""
#         },
#         "TR-AKD": {
#             "name": "Mediterranean Region",
#             "nativeName": "Akdeniz Bölgesi",
#             "flag": ""
#         },
#         "TR-GUA": {
#             "name": "Southeastern Anatolia Region",
#             "nativeName": "Güneydoğu Anadolu Bölgesi",
#             "flag": ""
#         }
#     }
# }
# - Taiwan
# {
#     "name": "Taiwan",
#     "regions": {
#         "TW-CHA": {
#             "name": "Changhua County",
#             "nativeName": "彰化縣",
#             "flag": ""
#         },
#         "TW-CYQ": {
#             "name": "Chiayi County",
#             "nativeName": "嘉義縣",
#             "flag": ""
#         },
#         "TW-CYI": {
#             "name": "Chiayi",
#             "nativeName": "嘉義市",
#             "flag": ""
#         },
#         "TW-HSQ": {
#             "name": "Hsinchu County",
#             "nativeName": "新竹縣",
#             "flag": ""
#         },
#         "TW-HSZ": {
#             "name": "Hsinchu",
#             "nativeName": "新竹市",
#             "flag": ""
#         },
#         "TW-HUA": {
#             "name": "Hualien County",
#             "nativeName": "花蓮縣",
#             "flag": ""
#         },
#         "TW-KHH": {
#             "name": "Kaohsiung",
#             "nativeName": "高雄市",
#             "flag": ""
#         },
#         "TW-KEE": {
#             "name": "Keelung",
#             "nativeName": "基隆市",
#             "flag": ""
#         },
#         "TW-KIN": {
#             "name": "Kinmen",
#             "nativeName": "金門縣",
#             "flag": ""
#         },
#         "TW-LIE": {
#             "name": "Lienchiang County",
#             "nativeName": "連江縣",
#             "flag": ""
#         },
#         "TW-MIA": {
#             "name": "Miaoli County",
#             "nativeName": "苗栗縣",
#             "flag": ""
#         },
#         "TW-NAN": {
#             "name": "Nantou County",
#             "nativeName": "南投縣",
#             "flag": ""
#         },
#         "TW-NWT": {
#             "name": "New Taipei",
#             "nativeName": "新北市",
#             "flag": ""
#         },
#         "TW-PEN": {
#             "name": "Penghu",
#             "nativeName": "澎湖縣",
#             "flag": ""
#         },
#         "TW-PIF": {
#             "name": "Pingtung County",
#             "nativeName": "屏東縣",
#             "flag": ""
#         },
#         "TW-TXG": {
#             "name": "Taichung",
#             "nativeName": "臺中市",
#             "flag": ""
#         },
#         "TW-TNN": {
#             "name": "Tainan",
#             "nativeName": "臺南市",
#             "flag": ""
#         },
#         "TW-TPE": {
#             "name": "Taipei",
#             "nativeName": "臺北市",
#             "flag": ""
#         },
#         "TW-TTT": {
#             "name": "Taitung County",
#             "nativeName": "臺東縣",
#             "flag": ""
#         },
#         "TW-TAO": {
#             "name": "Taoyuan City",
#             "nativeName": "桃園市",
#             "flag": ""
#         },
#         "TW-ILA": {
#             "name": "Yilan County",
#             "nativeName": "宜蘭縣",
#             "flag": ""
#         },
#         "TW-YUN": {
#             "name": "Yunlin County",
#             "nativeName": "雲林縣",
#             "flag": ""
#         }
#     }
# }
# - Vietnam
# {
#     "name": "Vietnam",
#     "regions": {
#         "VN-44": {
#             "name": "An Giang Province",
#             "nativeName": "Tỉnh An Giang",
#             "flag": ""
#         },
#         "VN-43": {
#             "name": "Bà Rịa - Vũng Tàu Province",
#             "nativeName": "Tỉnh Bà Rịa - Vũng Tàu",
#             "flag": ""
#         },
#         "VN-57": {
#             "name": "Bình Dương Province",
#             "nativeName": "Tỉnh Bình Dương",
#             "flag": ""
#         },
#         "VN-58": {
#             "name": "Bình Phước Province",
#             "nativeName": "Tỉnh Bình Phước",
#             "flag": ""
#         },
#         "VN-40": {
#             "name": "Bình Thuận Province",
#             "nativeName": "Tỉnh Bình Thuận",
#             "flag": ""
#         },
#         "VN-31": {
#             "name": "Bình Định Province",
#             "nativeName": "Tỉnh Bình Định",
#             "flag": ""
#         },
#         "VN-55": {
#             "name": "Bạc Liêu Province",
#             "nativeName": "Tỉnh Bạc Liêu",
#             "flag": ""
#         },
#         "VN-54": {
#             "name": "Bắc Giang Province",
#             "nativeName": "Tỉnh Bắc Giang",
#             "flag": ""
#         },
#         "VN-53": {
#             "name": "Bắc Kạn Province",
#             "nativeName": "Tỉnh Bắc Kạn",
#             "flag": ""
#         },
#         "VN-56": {
#             "name": "Bắc Ninh province",
#             "nativeName": "Tỉnh Bắc Ninh",
#             "flag": ""
#         },
#         "VN-50": {
#             "name": "Bến Tre Province",
#             "nativeName": "Tỉnh Bến Tre",
#             "flag": ""
#         },
#         "VN-04": {
#             "name": "Cao Bằng Province",
#             "nativeName": "Tỉnh Cao Bằng",
#             "flag": ""
#         },
#         "VN-59": {
#             "name": "Cà Mau Province",
#             "nativeName": "Tỉnh Cà Mau",
#             "flag": ""
#         },
#         "VN-CT": {
#             "name": "Cần Thơ",
#             "nativeName": "Thành phố Cần Thơ",
#             "flag": ""
#         },
#         "VN-30": {
#             "name": "Gia Lai Province",
#             "nativeName": "Tỉnh Gia Lai",
#             "flag": ""
#         },
#         "VN-14": {
#             "name": "Hoà Bình province",
#             "nativeName": "Tỉnh Hòa Bình",
#             "flag": ""
#         },
#         "VN-03": {
#             "name": "Hà Giang Province",
#             "nativeName": "Tỉnh Hà Giang",
#             "flag": ""
#         },
#         "VN-63": {
#             "name": "Hà Nam Province",
#             "nativeName": "Tỉnh Hà Nam",
#             "flag": ""
#         },
#         "VN-HN": {
#             "name": "Hà Nội",
#             "nativeName": "Thành phố Hà Nội",
#             "flag": ""
#         },
#         "VN-23": {
#             "name": "Hà Tĩnh Province",
#             "nativeName": "Tỉnh Hà Tĩnh",
#             "flag": ""
#         },
#         "VN-66": {
#             "name": "Hưng Yên Province",
#             "nativeName": "Tỉnh Hưng Yên",
#             "flag": ""
#         },
#         "VN-61": {
#             "name": "Hải Dương Province",
#             "nativeName": "Tỉnh Hải Dương",
#             "flag": ""
#         },
#         "VN-HP": {
#             "name": "Hải Phòng",
#             "nativeName": "Thành phố Hải Phòng",
#             "flag": ""
#         },
#         "VN-73": {
#             "name": "Hậu Giang Province",
#             "nativeName": "Tỉnh Hậu Giang",
#             "flag": ""
#         },
#         "VN-SG": {
#             "name": "Hồ Chí Minh City",
#             "nativeName": "Thành phố Hồ Chí Minh",
#             "flag": ""
#         },
#         "VN-34": {
#             "name": "Khánh Hòa Province",
#             "nativeName": "Tỉnh Khánh Hòa",
#             "flag": ""
#         },
#         "VN-47": {
#             "name": "Kiên Giang Province",
#             "nativeName": "Tỉnh Kiên Giang",
#             "flag": ""
#         },
#         "VN-28": {
#             "name": "Kon Tum Province",
#             "nativeName": "Tỉnh Kon Tum",
#             "flag": ""
#         },
#         "VN-01": {
#             "name": "Lai Châu Province",
#             "nativeName": "Tỉnh Lai Châu",
#             "flag": ""
#         },
#         "VN-41": {
#             "name": "Long An Province",
#             "nativeName": "Tỉnh Long An",
#             "flag": ""
#         },
#         "VN-02": {
#             "name": "Lào Cai Province",
#             "nativeName": "Tỉnh Lào Cai",
#             "flag": ""
#         },
#         "VN-35": {
#             "name": "Lâm Đồng Province",
#             "nativeName": "Tỉnh Lâm Đồng",
#             "flag": ""
#         },
#         "VN-09": {
#             "name": "Lạng Sơn Province",
#             "nativeName": "Tỉnh Lạng Sơn",
#             "flag": ""
#         },
#         "VN-67": {
#             "name": "Nam Định Province",
#             "nativeName": "Tỉnh Nam Định",
#             "flag": ""
#         },
#         "VN-22": {
#             "name": "Nghệ An Province",
#             "nativeName": "Tỉnh Nghệ An",
#             "flag": ""
#         },
#         "VN-18": {
#             "name": "Ninh Bình Province",
#             "nativeName": "Tỉnh Ninh Bình",
#             "flag": ""
#         },
#         "VN-36": {
#             "name": "Ninh Thuận Province",
#             "nativeName": "Tỉnh Ninh Thuận",
#             "flag": ""
#         },
#         "VN-68": {
#             "name": "Phú Thọ Province",
#             "nativeName": "Tỉnh Phú Thọ",
#             "flag": ""
#         },
#         "VN-32": {
#             "name": "Phú Yên Province",
#             "nativeName": "Tỉnh Phú Yên",
#             "flag": ""
#         },
#         "VN-24": {
#             "name": "Quảng Bình Province",
#             "nativeName": "Tỉnh Quảng Bình",
#             "flag": ""
#         },
#         "VN-27": {
#             "name": "Quảng Nam Province",
#             "nativeName": "Tỉnh Quảng Nam",
#             "flag": ""
#         },
#         "VN-29": {
#             "name": "Quảng Ngãi Province",
#             "nativeName": "Tỉnh Quảng Ngãi",
#             "flag": ""
#         },
#         "VN-13": {
#             "name": "Quảng Ninh Province",
#             "nativeName": "Tỉnh Quảng Ninh",
#             "flag": ""
#         },
#         "VN-25": {
#             "name": "Quảng Trị Province",
#             "nativeName": "Tỉnh Quảng Trị",
#             "flag": ""
#         },
#         "VN-52": {
#             "name": "Sóc Trăng Province",
#             "nativeName": "Tỉnh Sóc Trăng",
#             "flag": ""
#         },
#         "VN-05": {
#             "name": "Sơn La Province",
#             "nativeName": "Tỉnh Sơn La",
#             "flag": ""
#         },
#         "VN-21": {
#             "name": "Thanh Hoá Province",
#             "nativeName": "Tỉnh Thanh Hóa",
#             "flag": ""
#         },
#         "VN-20": {
#             "name": "Thái Bình Province",
#             "nativeName": "Tỉnh Thái Bình",
#             "flag": ""
#         },
#         "VN-69": {
#             "name": "Thái Nguyên Province",
#             "nativeName": "Tỉnh Thái Nguyên",
#             "flag": ""
#         },
#         "VN-26": {
#             "name": "Thừa Thiên Huế Province",
#             "nativeName": "Tỉnh Thừa Thiên Huế",
#             "flag": ""
#         },
#         "VN-46": {
#             "name": "Tiền Giang Province",
#             "nativeName": "Tỉnh Tiền Giang",
#             "flag": ""
#         },
#         "VN-51": {
#             "name": "Trà Vinh Province",
#             "nativeName": "Tỉnh Trà Vinh",
#             "flag": ""
#         },
#         "VN-07": {
#             "name": "Tuyên Quang Province",
#             "nativeName": "Tỉnh Tuyên Quang",
#             "flag": ""
#         },
#         "VN-37": {
#             "name": "Tây Ninh Province",
#             "nativeName": "Tỉnh Tây Ninh",
#             "flag": ""
#         },
#         "VN-49": {
#             "name": "Vĩnh Long Province",
#             "nativeName": "Tỉnh Vĩnh Long",
#             "flag": ""
#         },
#         "VN-70": {
#             "name": "Vĩnh Phúc Province",
#             "nativeName": "Tỉnh Vĩnh Phúc",
#             "flag": ""
#         },
#         "VN-06": {
#             "name": "Yên Bái Province",
#             "nativeName": "Tỉnh Yên Bái",
#             "flag": ""
#         },
#         "VN-71": {
#             "name": "Điện Biên Province",
#             "nativeName": "Tỉnh Điện Biên",
#             "flag": ""
#         },
#         "VN-DN": {
#             "name": "Đà Nẵng",
#             "nativeName": "Thành phố Đà Nẵng",
#             "flag": ""
#         },
#         "VN-33": {
#             "name": "Đăk Lăk Province",
#             "nativeName": "Tỉnh Đăk Lăk",
#             "flag": ""
#         },
#         "VN-72": {
#             "name": "Đăk Nông Province",
#             "nativeName": "Tỉnh Đăk Nông",
#             "flag": ""
#         },
#         "VN-39": {
#             "name": "Đồng Nai Province",
#             "nativeName": "Tỉnh Đồng Nai",
#             "flag": ""
#         },
#         "VN-45": {
#             "name": "Đồng Tháp Province",
#             "nativeName": "Tỉnh Đồng Tháp",
#             "flag": ""
#         }
#     }
# }
