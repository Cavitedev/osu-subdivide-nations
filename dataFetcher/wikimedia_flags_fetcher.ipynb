# %% [markdown]
# # Wikimedia flags Fetcher
#
# Retrieves the flags from: https://commons.wikimedia.org/wiki/Flags_of_country_subdivisions

# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import copy

# %%
url = "https://commons.wikimedia.org/wiki/Flags_of_country_subdivisions"

# %%
def parseUrl(url):
    response = requests.get(url)


    if response.status_code == 200:
        soup = BeautifulSoup(response.content, "html.parser")
        return soup
        
    else:
        print("Failed to fetch the webpage")

# %%
parsed = parseUrl(url)

# %%
content = parsed.find(id="mw-content-text").find("div") 

flagsRaw = {

}
country = ""
for element in content.children:

    if element.name == "h2":
        titleText = element.find("span").text
        if titleText == "" or titleText == "See also":
            continue
        country = titleText
        flagsRaw[country] = []
    elif element.name == "table":
        if country == "":
            continue
        flagsAnchor = element.findAll(class_= "mw-file-description")
        for flagAnchor in flagsAnchor:
            name = flagAnchor.attrs['title']
            flagImg = flagAnchor.find(class_="mw-file-element") 
            flagRaw = flagImg.attrs['src']
            flag: str = flagRaw.replace("thumb/", "")

            matchEnd = ".svg"
            svgIndex = flag.find(matchEnd)
            if svgIndex == -1:
                flag = flagRaw
            else:   
                flag = flag[:svgIndex+len(matchEnd)]



            flag = {
                "name": name,
                "flag": flag,
                "flagRaw": flagRaw
            }

            flagsRaw[country].append(flag)

# %% [markdown]
# ## Check the svg links status

# %%
# session = requests.Session()

# for key, value in flags.items():
#     for flag in value:
#         response = session.head(flag['flag'])
#         status_code = response.status_code
#         print(flag)
#         print("Status code:", status_code)
#         time.sleep(1)

# %%
json_data = json.dumps(flagsRaw, indent=4, ensure_ascii=False).encode('utf8')
file_path = "out/flags_raw.json"
with open(file_path, "w") as json_file:
    json_file.write(json_data)

print("JSON data has been saved to", file_path)
# Out:
# JSON data has been saved to out/flags_raw.json

# %%
flags = {
    country: [
        {key: value for key, value in county.items() if key != 'flagRaw'}
        for county in counties
    ]
    for country, counties in flagsRaw.items()
}

# %% [markdown]
# ## Convert names to ISO 3166 codes

# %%
countriesJsonPath = "./in/countries.json"

with open(countriesJsonPath, "r", encoding="utf-8") as json_file:
    countriesJson = json.load(json_file)

# %%
FlagsCodes = {} 

for country, regions in flags.items():

    for countryJson in countriesJson:
        if countryJson["name"] == country:
            code = countryJson["alpha-2"]
            break
    FlagsCodes[code] = {
        "name": country,
        "regions": regions
    }

# %%
flags = FlagsCodes

# %% [markdown]
# ## Add ISO 3166-2 codes to regions
#
# Using Open Street Maps API: https://nominatim.openstreetmap.org/ui/search.html

# %%
urlSearch = "https://nominatim.openstreetmap.org/search.php?q=$1&countrycodes=$2&format=jsonv2"
def getRegionURL(regionName,countryCode):
    return urlSearch.replace("$1",regionName).replace("$2",countryCode)

urlReverseId = "https://nominatim.openstreetmap.org/details.php?osmtype=R&osmid=$1&format=json"
def getReverseIdURL(id):
    return urlReverseId.replace("$1",id)

def fetchData(api_url):
    try:
        response = requests.get(api_url)

        if response.status_code == 200:

            data = response.json()
            return data
        else:
            print(f"Request failed with status code: {response.status_code}")
    except requests.exceptions.RequestException as e:
        print("An error occurred:", e)

# %%
flagsRegionCodes = copy.deepcopy(FlagsCodes)


def addResult(regionsMap, region, name, matchData):
    id = matchData['osm_id']
    detailsUrl = getReverseIdURL(str(id))
    print(id)
    detailsData = fetchData(detailsUrl)

    if detailsData is None:
        print("No details data")
        print(region)
        return False
                

    isoCode = detailsData['names'].get('ISO3166-2')

    if isoCode is None:
        print("No ISO Code")
        print(region)
        return False    

    nativeName = detailsData['names'].get('name')

    if isoCode in regionsMap:
        print("ISO code already exists ISO: " +isoCode)
        print(region)
        return False
                

    regionsMap[isoCode] = {
                "name": name,
                "nativeName": nativeName,
                "flag": region['flag']
            }
    return True

for countryCode, country in FlagsCodes.items():
    print(countryCode)
    regionsMap = {}

    for region in country['regions']:
        name = region['name']
        api_url = getRegionURL(name, countryCode)

        data = fetchData(api_url)
        if data:
            it = (d for d in data if d.get("type") == "administrative")

            matchData = next(it, None)
                
            while matchData:
                suceed = addResult(regionsMap, region, name, matchData)
                if not suceed:
                    matchData = next(it, None)
                    if matchData is not None:
                        print("Trying next match")
                else:
                    matchData = None
            
        else:
            print("No match data")
    
    flagsRegionCodes[countryCode]['regions'] = regionsMap
# Out:
# AL
# 1252289
# 1249872
# 1250609
# 1252589
# 1759889
# 1250098
# 1255521
# AD
# 2804753
# 2804754
# 2804755
# 2804756
# 2804757
# 2804758
# No match data
# AQ
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# AR
# 1224652
# 4683201
# No ISO Code
# {'name': 'Buenos Aires Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/15/Bandera_de_la_Provincia_de_Buenos_Aires.svg'}
# 6587642
# No ISO Code
# {'name': 'Chaco Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/33/Bandera_de_la_Provincia_del_Chaco.svg'}
# 153548
# 153551
# 6413250
# No ISO Code
# {'name': 'Misiones Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/ce/Bandera_de_la_Provincia_de_Misiones.svg'}
# 1606727
# 153547
# 16155061
# No ISO Code
# {'name': 'San Juan Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Bandera_de_la_Provincia_de_San_Juan.svg'}
# Trying next match
# 4764377
# No ISO Code
# {'name': 'San Juan Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Bandera_de_la_Provincia_de_San_Juan.svg'}
# Trying next match
# 13458434
# No ISO Code
# {'name': 'San Juan Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Bandera_de_la_Provincia_de_San_Juan.svg'}
# Trying next match
# 5836465
# No ISO Code
# {'name': 'San Juan Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Bandera_de_la_Provincia_de_San_Juan.svg'}
# Trying next match
# 12015555
# No ISO Code
# {'name': 'San Juan Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Bandera_de_la_Provincia_de_San_Juan.svg'}
# Trying next match
# 15755048
# No ISO Code
# {'name': 'San Juan Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Bandera_de_la_Provincia_de_San_Juan.svg'}
# Trying next match
# 9561511
# No ISO Code
# {'name': 'San Juan Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Bandera_de_la_Provincia_de_San_Juan.svg'}
# 16214600
# No ISO Code
# {'name': 'San Luis Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/0e/Bandera_de_la_Provincia_de_San_Luis.svg'}
# 153549
# 153550
# AU
# 2316593
# 2316595
# 2316596
# 2369652
# 2316741
# 2316598
# 2354197
# 2316594
# 2177207
# No ISO Code
# {'name': 'Christmas Island', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/67/Flag_of_Christmas_Island.svg'}
# Trying next match
# 11716751
# No ISO Code
# {'name': 'Christmas Island', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/67/Flag_of_Christmas_Island.svg'}
# 82636
# No ISO Code
# {'name': 'Cocos (Keeling) Islands', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/74/Flag_of_the_Cocos_%28Keeling%29_Islands.svg'}
# Trying next match
# 11716757
# No ISO Code
# {'name': 'Cocos (Keeling) Islands', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/74/Flag_of_the_Cocos_%28Keeling%29_Islands.svg'}
# 2574988
# No ISO Code
# {'name': 'Norfolk Island', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/48/Flag_of_Norfolk_Island.svg'}
# AT
# 76909
# 52345
# 77189
# 86538
# No ISO Code
# {'name': 'Salzburg', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b5/Flag_of_Salzburg_%28state%29.svg'}
# Trying next match
# 86539
# 35183
# 52343
# 102303
# 109166
# 74942
# BH
# 3028094
# 3028095
# No match data
# No match data
# BY
# 59189
# 163244
# No ISO Code
# {'name': 'Gomel Region', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/49/Flag_of_Homyel_Voblast.svg'}
# 59275
# 59752
# 59162
# 59506
# 59195
# BE
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# BA
# No match data
# 2528145
# 2528143
# BR
# 326266
# 303781
# 331463
# 332476
# 362413
# 302635
# 54882
# 334443
# 332924
# 333597
# 334051
# 315173
# 185579
# 301464
# 297640
# 303702
# 302819
# 2697338
# No ISO Code
# {'name': 'Rio de Janeiro', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/73/Bandeira_do_estado_do_Rio_de_Janeiro.svg'}
# Trying next match
# 57963
# 242762
# No ISO Code
# {'name': 'Rio Grande do Sul', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/63/Bandeira_do_Rio_Grande_do_Sul.svg'}
# Trying next match
# 7337824
# No ISO Code
# {'name': 'Rio Grande do Sul', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/63/Bandeira_do_Rio_Grande_do_Sul.svg'}
# 325866
# 326287
# 296584
# 298285
# No ISO Code
# {'name': 'São Paulo', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/2b/Bandeira_do_estado_de_S%C3%A3o_Paulo.svg'}
# Trying next match
# 298204
# 303940
# 336819
# 421151
# CA
# 391186
# 390867
# 390841
# 68942
# 391196
# 390558
# 68841
# 391115
# 61549
# 391178
# 391220
# 390840
# 391455
# CL
# 240932
# 296378
# 269826
# No ISO Code
# {'name': 'Arica y Parinacota Region', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/fa/Flag_of_Arica_y_Parinacota%2C_Chile.svg'}
# 271889
# 305693
# 252891
# 231672
# 274991
# 274988
# 239882
# 198848
# 7421025
# 206487
# 238393
# 198847
# CN
# 10264792
# No ISO Code
# {'name': 'Hong Kong', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/5b/Flag_of_Hong_Kong.svg'}
# Trying next match
# 913110
# 1867188
# No match data
# No match data
# No match data
# No match data
# 9636531
# No ISO Code
# {'name': 'Tainan', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/7d/Flag_of_Tainan_City.svg'}
# 3152417
# No ISO Code
# {'name': 'Taoyuan', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f1/Flag_of_Taoyuan_City.svg'}
# Trying next match
# 13294117
# No ISO Code
# {'name': 'Taoyuan', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f1/Flag_of_Taoyuan_City.svg'}
# Trying next match
# 15676664
# No ISO Code
# {'name': 'Taoyuan', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f1/Flag_of_Taoyuan_City.svg'}
# Trying next match
# 15904244
# No ISO Code
# {'name': 'Taoyuan', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f1/Flag_of_Taoyuan_City.svg'}
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# 2755765
# No ISO Code
# {'name': 'Yilan County', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b4/Flag_of_Yilan_County.svg'}
# No match data
# No match data
# CO
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# 12893646
# KM
# No match data
# CR
# 3222933
# 3223054
# 6336200
# No ISO Code
# {'name': 'Guanacaste Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/04/Bandera_de_la_Provincia_de_Guanacaste.svg'}
# 3221947
# 3223056
# 3223028
# 3223004
# HR
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# DK
# No match data
# 1320608
# 1319935
# 1319936
# 1320370
# 1319978
# DO
# 53161
# 14761638
# No match data
# No match data
# 7405546
# No ISO Code
# {'name': 'San Pedro de Macorís Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/7
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# MC
# No match data
# MN
# 270075
# 3382266
# 270052
# 270073
# 270091
# 269886
# 270050
# 270054
# 270095
# 269885
# 270055
# 7304614
# No ISO Code
# {'name': 'Khövsgöl Province', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/72/Mn_flag_kh%C3%B6vsg%C3%B6l_aimag_2014.svg'}
# 270051
# 270092
# 270074
# 270089
# 269874
# 3382267
# 270059
# 4074177
# 270090
# ME
# 8881697
# No ISO Code
# {'name': 'Bar', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/07/Flag_of_Bar%2C_Montenegro.svg'}
# 12434568
# No ISO Code
# {'name': 'Bijelo Polje', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/61/Flag_of_Bijelo_Polje.png/200px-Flag_of_Bijelo_Polje.png'}
# Trying next match
# 12512551
# No ISO Code
# {'name': 'Bijelo Polje', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/61/Flag_of_Bijelo_Polje.png/200px-Flag_of_Bijelo_Polje.png'}
# 2187904
# No ISO Code
# {'name': 'Herceg Novi', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Flag_of_Herceg_Novi.jpg/150px-Flag_of_Herceg_Novi.jpg'}
# 11497014
# No ISO Code
# {'name': 'Nikšić', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e2/Flag_of_Nik%C5%A1i%C4%87.gif/200px-Flag_of_Nik%C5%A1i%C4%87.gif'}
# 2319536
# 8882104
# No ISO Code
# {'name': 'Podgorica', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/65/Flag_of_Podgorica%2C_Montenegro.svg'}
# 2319539
# 12492506
# No ISO Code
# {'name': 'Tivat', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/ff/Flag_of_Tivat.svg'}
# 3750229
# No ISO Code
# {'name': 'Tuzi', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/fc/Flag_of_Tuzi.svg'}
# MM
# 5996473
# 5996474
# 5996479
# 5996480
# 5996484
# 5996486
# 5996487
# 5996475
# 5996476
# 5996477
# 5996478
# 5996481
# 5996485
# 5996482
# 7200536
# No ISO Code
# {'name': 'Danu Self-Administered Zone', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/e8/Flag_of_the_Danu_people.svg'}
# 6833794
# No ISO Code
# {'name': 'Kokang Self-Administered Zone', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/41/Flag_of_Kokang_Self-Administered_Zone.svg'}
# 7183862
# No ISO Code
# {'name': 'Naga Self-Administered Zone', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/01/Flag_of_Naga_Self-Administered_Zone.png/160px-Flag_of_Naga_Self-Administered_Zone.png'}
# 7200810
# No ISO Code
# {'name': 'Pa Laung Self-Administered Zone', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/e3/Flag_of_the_Palaung_people.svg'}
# 7200537
# No ISO Code
# {'name': "Pa'O Self-Administered Zone", 'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/28/Flag_of_the_Pa-O_National_Organisation.svg'}
# 7160199
# No ISO Code
# {'name': 'Wa Self-Administered Division', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/48/Flag_of_Wa_State.svg'}
# NL
# 1231749
# 1216719
# 47796
# No ISO Code
# {'name': 'Netherlands', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/20/Flag_of_the_Netherlands.svg'}
# Trying next match
# 2323309
# No ISO Code
# {'name': 'Netherlands', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/2/20/Flag_of_the_Netherlands.svg'}
# 1231790
# 47540
# 47407
# 47381
# 47554
# 409863
# No ISO Code
# {'name': 'Groningen', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/0/01/Flag_Groningen.svg'}
# Trying next match
# 47826
# 47793
# 47696
# 47654
# 47608
# 47772
# 1433619
# No ISO Code
# {'name': 'Utrecht', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/
 'flag': 'https://upload.wikimedia.org/wikipedia/commons/1/11/Flag_of_Cebu_%28province%29.svg'}
# Trying next match
# 1506936
# 1513151
# 1507283
# 1507313
# 1513050
# 3304098
# 1507095
# 1507007
# 1506373
# 1506802
# 52303
# 1504744
# 1504724
# 1506774
# 1504761
# 52300
# 1504722
# 1503483
# 1513179
# 1513166
# 1506532
# 1506331
# 1506350
# 1513208
# 1513190
# 52301
# 1506913
# 1506914
# 1506364
# 52306
# 52305
# 1506320
# 1506328
# 1506669
# 1504669
# 1504701
# 1504500
# 52302
# 1504641
# 1506343
# 1506416
# 1513098
# 3604058
# 1504631
# 1513131
# 1506605
# 1513160
# 1513292
# 1507031
# 1507067
# 52307
# 1513298
# 1504691
# 1513211
# 1513233
# 1513227
# PL
# 130971
# 223407
# 224459
# 224458
# 224457
# 130919
# 130969
# 130935
# 224460
# 224461
# 130975
# 224462
# 130957
# 3805705
# No ISO Code
# {'name': 'Świętokrzyskie Voivodeship', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/6/69/POL_wojew%C3%B3dztwo_%C5%9Bwi%C4%99tokrzyskie_flag.svg'}
# Trying next match
# 130914
# 223408
# 104401
# PT
# 1629146
# 1629145
# RO
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# SK
# 2265296
# No ISO Code
# {'name': 'Banská Bystrica', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/ff/Banskobystricky_vlajka.svg'}
# Trying next match
# 2265245
# No ISO Code
# {'name': 'Banská Bystrica', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/ff/Banskobystricky_vlajka.svg'}
# 1702499
# No ISO Code
# {'name': 'Bratislava', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4c/Bratislavsky_vlajka.svg'}
# 1690324
# No ISO Code
# {'name': 'Košice', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/32/Kosicky_vlajka.svg'}
# 2210192
# No ISO Code
# {'name': 'Nitra', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/ea/Nitriansky_vlajka.svg'}
# Trying next match
# 2273339
# No ISO Code
# {'name': 'Nitra', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/ea/Nitriansky_vlajka.svg'}
# Trying next match
# 2210095
# No ISO Code
# {'name': 'Nitra', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/e/ea/Nitriansky_vlajka.svg'}
# 2320257
# No ISO Code
# {'name': 'Prešov', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4d/Presovsky_vlajka.svg'}
# Trying next match
# 2320148
# No ISO Code
# {'name': 'Prešov', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4d/Presovsky_vlajka.svg'}
# 1799254
# No ISO Code
# {'name': 'Trenčín', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/51/Trenciansky_vlajka.svg'}
# Trying next match
# 388267
# 2204009
# No ISO Code
# {'name': 'Trnava', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d4/Trnavsky_vlajka.svg'}
# Trying next match
# 2386617
# No ISO Code
# {'name': 'Trnava', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d4/Trnavsky_vlajka.svg'}
# Trying next match
# 2203958
# No ISO Code
# {'name': 'Trnava', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d4/Trnavsky_vlajka.svg'}
# 1859537
# No ISO Code
# {'name': 'Žilina', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/d8/Zilinsky_vlajka.svg'}
# Trying next match
# 388269
# SB
# 2536258
# 2536259
# 11916914
# 2536261
# 2536262
# 2536263
# 2536264
# 2536265
# 11916824
# 2536278
# SO
# 14278313
# 13702729
# No ISO Code
# {'name': 'Galmudug', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/9b/Flag_of_Galmudug_State_of_Somalia_%282015%29.svg'}
# 13702730
# No ISO Code
# {'name': 'Hirshabelle', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/18/Hirshabeelle.png/179px-Hirshabeelle.png'}
# 13702732
# No ISO Code
# {'name': 'Jubaland', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/a6/Flag_of_Jubaland_%28Somalia%29.svg'}
# 13702728
# No ISO Code
# {'name': 'Puntland', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/7/7a/Flag_of_Puntland.svg'}
# 13702731
# No ISO Code
# {'name': 'South West', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/8b/Flag_of_South_West_State_of_Somalia.svg'}
# 3586169
# No ISO Code
# {'name': 'Somaliland', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4d/Flag_of_Somaliland.svg'}
# Trying next match
# 13316065
# No ISO Code
# {'name': 'Somaliland', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/4/4d/Flag_of_Somaliland.svg'}
# ZA
# 349556
# SS
# 2190479
# 2190482
# 2190481
# No match data
# 2190520
# 2190519
# 2190518
# 2190521
# 2190484
# 2190483
# 13550425
# No ISO Code
# {'name': 'Greater Pibor Administrative Area', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Greater_Pibor_Administrative_Area.png/153px-Flag_of_Greater_Pibor_Administrative_Area.png'}
# 13550743
# No ISO Code
# {'name': 'Ruweng Administrative Area', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6f/Flag_of_Ruweng.png/155px-Flag_of_Ruweng.png'}
# No match data
# ES
# 349044
# 349045
# 349033
# 348981
# 349042
# 349048
# 6426101
# 349052
# 349041
# 349053
# 349050
# 349036
# 348991
# 349055
# 349047
# 349027
# 349043
# 1822781
# No ISO Code
# {'name': 'Ceuta', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/fd/Flag_Ceuta.svg'}
# Trying next match
# 1154756
# 7523933
# No ISO Code
# {'name': 'Melilla', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/f/f7/Flag_of_Melilla.svg'}
# Trying next match
# 1154757
# LK
# 4630835
# 4630810
# 4630836
# 4630837
# 3237344
# 4630838
# 4630839
# 4630840
# 4630841
# SD
# 3851428
# No ISO Code
# {'name': 'Khartoum', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/50/Flag_of_Khartoum_State.png/150px-Flag_of_Khartoum_State.png'}
# Trying next match
# 3774673
# 4669808
# No ISO Code
# {'name': 'Kassala', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/46/Flag_of_Kassala_State.png/142px-Flag_of_Kassala_State.png'}
# Trying next match
# 3774665
# 3774668
# 3774675
# No match data
# 3774671
# No match data
# SR
# No match data
# SE
# 54413
# 52834
# 941530
# 52832
# 54403
# 52826
# 54374
# 54417
# 54412
# 52824
# 54409
# 54391
# 54386
# 54220
# 54223
# 52825
# 52827
# 54221
# 54367
# 54222
# 940675
# CH
# 1686359
# 1686649
# 1686666
# 1686366
# 1699639
# 1682378
# No ISO Code
# {'name': 'Bern', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/3/30/Flag_of_Canton_of_Bern.svg'}
# Trying next match
# 1686344
# 1698314
# 1685488
# No ISO Code
# {'name': 'Geneva', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/8/83/Flag_of_Canton_of_Geneva.svg'}
# Trying next match
# 1702419
# 1685673
# 1686631
# 1697347
# 1682891
# No ISO Code
# {'name': 'Lucerne', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/d/db/Flag_of_Canton_of_Lucerne.svg'}
# Trying next match
# 1685677
# 1685519
# No ISO Code
# {'name': 'Neuchâtel', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/5/57/Flag_of_Canton_of_Neuch%C3%A2tel.svg'}
# Trying next match
# 1702420
# 1686449
# 1686448
# 1683703
# No ISO Code
# {'name': 'Schaffhausen', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b0/Flag_of_Canton_of_Schaffhausen.svg'}
# Trying next match
# 1696112
# 1688583
# 1701133
# 1683941
# No ISO Code
# {'name': 'St. Gallen', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/a/a1/Flag_of_Canton_of_Sankt_Gallen.svg'}
# Trying next match
# 1687006
# 1693811
# 1687730
# 1693971
# 1686699
# 1702421
# 1686447
# 1682248
# No ISO Code
# {'name': 'Zürich', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/9/9b/Flag_of_Canton_of_Z%C3%BCrich.svg'}
# Trying next match
# 1690227
# TH
# 2746948
# 1908765
# 92277
# 2934602
# 1908766
# 1908767
# 1908768
# 1908769
# 1908770
# 1908771
# 1908772
# 1908773
# 1908774
# 1908775
# 1908776
# 1908777
# 1908778
# 1908779
# 1908781
# 1908782
# 1908783
# 1908784
# 1908785
# 1908786
# 2934603
# 1908787
# 1908788
# 1908789
# 1908790
# 1908791
# 1908792
# 1908793
# 1908794
# 1925819
# 1908795
# 1908796
# 1908797
# 1908798
# 1908799
# 1908800
# 1908801
# 1908802
# 1908803
# 1908804
# 1908805
# 1908806
# 1908807
# 2934604
# 1908808
# 1908809
# 1908810
# 1908811
# 1908812
# 1908813
# 2934605
# 1908814
# 1908815
# 1908816
# 1908817
# 1908818
# 1908819
# 1908820
# 1908821
# 1908822
# 1908823
# 1908824
# 1908825
# 1908826
# 1908827
# 1908828
# 1908829
# 1908830
# 1908831
# 2934606
# 1908832
# 1908872
# 1908873
# UA
# 91278
# 71249
# 72526
# 101746
# 71973
# 72488
# 71254
# 71022
# 90742
# 101859
# 71248
# 71971
# 72380
# 72635
# 72634
# 91294
# 71236
# 71250
# 72525
# 90726
# 71064
# 72489
# 30719657
# Request failed with status code: 404
# No details data
# {'name': 'Zaporizhzhia Oblast', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/b/b8/Flag_of_Zaporizhia_Oblast.svg'}
# 71245
# 421866
# 1574364
# 72639
# AE
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# UY
# 1617618
# 1625171
# 1656175
# 1650769
# 1646018
# 1645684
# 1635164
# 1635124
# 2473675
# No ISO Code
# {'name': 'Maldonado', 'flag': 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/52/Flag_of_Maldonado_Department.png/150px-Flag_of_Maldonado_Department.png'}
# Trying next match
# 1635117
# 1662387
# 1662476
# 1627812
# 1653142
# 1614733
# 1635189
# 1646600
# 1640982
# UZ
# 196241
# VU
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# No match data
# YE
# No match data
# No match data
# No match data
# No match data
# No match data
# ZW
# An error occurred: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search.php?q=Bulawayo&countrycodes=ZW&format=jsonv2 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D2C2ABB2B0>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
# No match data
# 318467

# %%
flags = flagsRegionCodes

# %% [markdown]
# ## Save final flags

# %%
json_data = json.dumps(flags, indent=4, ensure_ascii=False).encode('utf8').decode()
file_path = "out/flags.json"
with open(file_path, "w") as json_file:
    json_file.write(json_data)

print("JSON data has been saved to", file_path)
# Out:
# JSON data has been saved to out/flags.json
